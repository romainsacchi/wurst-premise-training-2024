# %% [markdown]
# <div>
#     <table>
#         <tr>
#             <td>
#                     <h1>Brightway2 seminar</h1>
#                     Chris Mutel <a href="https://www.psi.ch/">(PSI)</a>
#                     Pascal Lesage <a href="http://www.ciraig.org/en/">(CIRAIG)</a>
#             </td>
#         </tr>
#     </div>
#
# # Brightway modules: bw2io, bw2data, bw2calc
#
# *The following content is taken and adapted from [the course materials dispensed at the 2022 Brightcon conference](https://github.com/Depart-de-Sentier/teaching-material/tree/main/beginners/Projects%2C%20databases%2C%20exchanges%2C%20activities). If you need additional notebooks, go to this repository*.
#
#
# <div class="alert alert-info">
# Note: we will be using Brightway2, not Brightway25. From the user end side, very little differ between the two.
# </div>

# %% [markdown]
# **Brightway2 documentation** 👉 [https://docs.brightway.dev/en/legacy/index.html](https://docs.brightway.dev/en/legacy/index.html)
#
# **Brightway25 documentation** 👉 [https://docs.brightway.dev/en/latest/index.html](https://docs.brightway.dev/en/latest/index.html)

# %% [markdown]
# ### Learning objectives
#   - Learn about the general structure of Brightway and its most importand abstractions: projects, databases, activities and exchanges
#   - Learn how to find objects (notably activities and exchanges), assign them to variables and work with them using their associated methods
#   - Learn about how simple LCA calculations are done (one product, one impact category), and specifically how the different matrices are built and used
#   - Learn how to extract information from the matrices (inputs or results) and translate them into nice, human-readable objects
#   - Learn different ways to carry out comparative LCAs
#   - Learn different ways to carry out LCAs with multiple impact categories

# %% [markdown]
# ### Content
#
# #### 1) Getting started
# ##### 1.1) Jupyter lab / notebooks and Brightway2
#   - A quick tour of jupyter lab / notebooks
#   - Accessing Brightway2 libraries
#
# ##### 1.2) Projects
#   - Concept
#   - Creating a new project, or switching to an existing project
#   - Contents of a project
#
#
# ##### 1.3) bw2_setup(), biosphere3 database and LCIA methods
#   - bw2_setup()
#   - biosphere3 database and a first look at database objects
#   - Getting activities from codes or keys
#   - Methods
#   - Looking up elementary flows (list comprehensions, search)
#   - Searching for methods
#   - Nice display of data in methods
#
# ##### 1.4) LCI databases
#   - Importing (succinct)
#   - LCI activities
#   - Looking up activities
#   - LCI exchanges
#   - Loaded LCI databases
#
# #### 2) My first LCA - simplest case:
# ##### 2.1) General syntax of LCA calculations
#
# ##### 2.2) The `demand` attribute
#
# ##### 2.3) Reminder of the system that needs to be solved in calculating an LCI
#
# ##### 2.4) Building the matrices
#
#   - $A$ matrix
#   - $B$ matrix
#   - $f$ (demand array)
#
# ##### 2.5) Solution to the inventory calculation
#
#   - Supply array
#   - Inventory matrix
#
# ##### 2.6) Life Cycle Impact Assessment
#
#   - `.lcia()` method
#   - Simple contribution analysis
#
# #### 3) My second LCA - comparative LCA:
#
# #### 4) My third LCA - Multiple impact categories
#
# #### 5) My first and third LCAs revisited with MultiLCA

# %% [markdown]
# ### 1) Getting started

# %% [markdown]
# #### 1.1) Jupyter lab / notebooks and accessing Brightway2

# %% [markdown]
# This teaching material was produced with the intention to be used in Jupyter Notebooks.

# %% [markdown]
# For installation instructions, consult the [brightway documentation](https://docs.brightway.dev/en/legacy/content/installation/installation.html)

# %% [markdown]
# <div class="alert alert-info">
# This notebook is meant to run with a specific conda (and python) environment.
#     Make sure you have started Jupyter Notebooks or Jupyter Lab from the conda
#     environment where the brightway2 modules are installed.
# </div>

# %% [markdown]
# ##### Accessing Brightway2 libraries

# %% [markdown]
# The different modules in Brightway2 are Python libraries. This means that, to use them, you can use any environment from which you normally use Python (Idle, command prompt, Spyder or, as is the case today, Jupyter Notebooks).
#
# We will favour Jupyter Notebooks in this course because it allows us to integrate code and text. It will also allow us to provide code snippets for you to complete.

# %% [markdown]
# Like all other Python packages, you need to `import` Brightway2 modules. We will here import it as `bw`. This means that, to access a **method** or **function** from the brightway2 modules, the prefix `bw.` needs to be added.

# %%
import brightway2 as bw

# %% [markdown]
# Alternatively, we can import the Brightway's sub-modules directly:

# %%
import bw2io, bw2data, bw2calc

# %% [markdown]
# We're also going to be using the following libraries:

# %%
import os               # to use "operating system dependent functionality"
import numpy as np      # "the fundamental package for scientific computing with Python"
import pandas as pd     # "high-performance, easy-to-use data structures and data analysis tools" for Python

# %% [markdown]
# #### 1.2) Projects

# %% [markdown]
# ##### Concept

# %% [markdown]
# The top-level containent in Brightway2 is the project (see [here](https://2.docs.brightway.dev/intro.html#projects) for a description and [here](https://2.docs.brightway.dev/technical/bw2data.html#projects) for the **technical docs about projects**). A project contains LCI databases, LCIA methods and other less often used objects. Objects from one project do not interract with objects within other projects. By analogy, projects are like databases in other LCA software.
# When you first launch Brightway2, you will be in the `default` project. You can check this using the `current` property of the `projects` object:

# %%
bw.projects
# Out:
# Brightway2 projects manager with 16 objects:
# 	arezoo
# 	bw25
# 	coursePSI
# 	default
# 	ei38
# 	ei39
# 	new
# 	new4
# 	polyviz
# 	psi1
# 	strat_metals
# 	test
# 	testbio
# 	testbio2
# 	testbio3
# 	uvek
# Use `projects.report()` to get a report on all projects.

# %%
bw.projects.set_current("coursePSI")

# %% [markdown]
# ##### Creating a new project, or switching to an existing project

# %% [markdown]
# Let's create a new project for this seminar, unsurprisingly called "bw2_seminar_2017". There are two ways of doing this:
# * `projects.create_project('brightcon22')` will create the project, but you will remain in your current project.
# * `projects.set_current('brightcon22')` will switch you to the project passed as argument, and create it first if it doesn't exist.  Let's do the latter:

# %%
# The name of the project is entered as string; 
# it doesn't really have any restrictions, so can include spaces, 
# special characters, other languages, or even emoji.

# %% [markdown]
# You can always see what projects you have on your computer by running `list(bw.projects)`. Unless you have worked with Brightway2 before on your computer, your list should contain two projects: 'default' and 'bw2_seminar_2017'.

# %% [markdown]
# _**Exercise**_: list the projects on your computer.

# %%
bw.projects
# Out:
# Brightway2 projects manager with 16 objects:
# 	arezoo
# 	bw25
# 	coursePSI
# 	default
# 	ei38
# 	ei39
# 	new
# 	new4
# 	polyviz
# 	psi1
# 	strat_metals
# 	test
# 	testbio
# 	testbio2
# 	testbio3
# 	uvek
# Use `projects.report()` to get a report on all projects.

# %% [markdown]
# Like in all Python modules, you can get additionnal information on the `projects` object and associated properties and methods by typing `help(projects)`. The [docs](https://docs.brightwaylca.org/technical/bw2data.html#projects) are of course more verbose.

# %% [markdown]
# ##### Contents of a project

# %% [markdown]
# One property of `projects` is its location, given by `projects.dir`:

# %%
bw.projects.dir
# Out:
# '/Users/romain/Library/Application Support/Brightway3/coursePSI.ad34cb91313c17c13fa891538321d355'

# %% [markdown]
# <div class="alert alert-info">
#     Try to locate your project directory on your computer.
# </div>

# %% [markdown]
# First things first: **do not panic**! You can use Brightway2 for years without ever opening this directory, but we will discuss some of these files later.
#
# It is simply interesting to note that, for now, all the directories are empty except the `lci` directory, which contains an empty database.

# %% [markdown]
# All in all, the project takes up about 150KB.
# Its now time to start populating the project.

# %% [markdown]
# #### 1.3) bw2setup(), biosphere3 database and LCIA methods

# %% [markdown]
# ##### bw2setup()

# %% [markdown]
# The first thing you should do is add flow and LCIA methods. This is done by running the `bw2setup` function:

# %%
bw.bw2setup()
# Out:
# Writing activities to SQLite3 database:
# Creating default biosphere
#
# Applying strategy: normalize_units
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: ensure_categories_are_tuples
# Applied 3 strategies in 0.00 seconds
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 03/19/2024 10:09:25
#   Finished: 03/19/2024 10:09:26
#   Total time elapsed: 00:00:00
#   CPU %: 73.00
#   Memory %: 2.90
# Created database: biosphere3
# Creating default LCIA methods
#
# Wrote 762 LCIA methods with 227223 characterization factors
# Creating core data migrations

# %%
bw.databases
# Out:
# Databases dictionary with 1 object(s):
# 	biosphere3

# %% [markdown]
# The output tells us that bw2_setup created some very useful things:
#   - Created a database called "biosphere3": this database contains elementary flows (called biosphere exchanges in Brightway2)
#   - **762** impact assessment methods  (with bw2data version 3.6.6)
#
# <div class="alert alert-info">
#     Note: The biosphere database contains all "natural" flows human-made activities connect to. E.g., CO2 emissions, ore in ground, etc.
# </div>
#
# It also created some a `mapping` between the imported exchanges and some integer: more on this later.
# The whole directory now takes up 157MB.

# %% [markdown]
# ##### biosphere3 database and a first look at database objects

# %% [markdown]
# <div class="alert alert-info">
#     Note: You can always list the databases inside a project by simply typing 'bw.databases'. This accesses the 'database.json' file in your 'project.dir' (I learned the latter by typing `databases?`, you should try it too.)
# </div>

# %%
bio = bw.Database("biosphere3")

# %%
bio
# Out:
# Brightway2 SQLiteBackend: biosphere3

# %% [markdown]
# While not impossible to interact with the data at this level, you probably never will unless you are developping some funky program. Instead, it is strongly recommended to learn to work with `abstractions`.

# %% [markdown]
# To access a database in Brightway, you use the `Database` initialization method (again, you can type `Database?` for more information - this is the last time I'll mention this.

# %% [markdown]
# It doesn't actually return anything other than information about the Backend.
# However, there are many properties and functions associated with this database object.  These are found [here](https://2.docs.brightway.dev/technical/bw2data.html#databasechooser). We can also have a look through the autocomplete. Let's assign the database to a variable:

# %% [markdown]
# Let's check the my_bio `type`:

# %%
type(bio)
# Out:
# bw2data.backends.peewee.database.SQLiteBackend

# %% [markdown]
# Let's check its length:

# %%
len(bio)
# Out:
# 4709

# %% [markdown]
# This is exactly the number of items we saw had been added to databases.db
# Given this, what do you think is going on?

# %% [markdown]
# If you type `my_bio.` and click on tab, you should get a list of properties and methods associated with database objects. Try this now:

# %%
bio.random(filters=True, true_random=True)
# Out:
# 'Acetic acid, trifluoro-' (kilogram, None, ('air',))

# %% [markdown]
# Some of the more basic ones we will be using now are :
#   - `random()` - returns a random activity in the database
#   - `get(*valid_exchange_tuple*)` - returns an activity, but you must know the activity key
#   - `load()` - loads the whole database as a dictionary.
#   - `make_searchable` - allows searching of the database (by default, it is already searchable)
#   - `search` - search the database
#
# Lets start with `random`:

# %%
random_bio = bio.random()
random_bio
# Out:
# 'Zinc-65' (kilo Becquerel, None, ('air',))

# %% [markdown]
# This returns a biosphere activity, but without assigning it to a variable, there is not much we can do with it directly.

# %% [markdown]
# Note: It may seem counter-intuitive for elementary *flows* to be considered *activities* in Brightway, but it is no mistake.
# LCA models are made up of **nodes** (activities) that are linked by **edges** (exchanges). The biosphere activities are the nodes *outside* the technosphere. Emissions and resource extractions are modelled as exchanges between activities in the technosphere (part of the product system) and these biosphere activities.
#
# More on this later.

# %% [markdown]
# For now, let's assign another random activity to a variable:

# %%
random_bio.as_dict()
# Out:
# {'categories': ('air',),
#  'code': '4aed2261-0461-4014-be23-cf83de76a3b4',
#  'CAS number': '013982-39-3',
#  'name': 'Zinc-65',
#  'database': 'biosphere3',
#  'unit': 'kilo Becquerel',
#  'type': 'emission'}

# %% [markdown]
# We can get the type of the object that was returned from the database:

# %%
type(random_bio)
# Out:
# bw2data.backends.peewee.proxies.Activity

# %% [markdown]
# The type is an **activity proxy**. Activity proxies allow us to interact with the content of the database.

# %% [markdown]
# In Brightway, we *almost* always work with `Activity` or `Exchange` objects.

# %% [markdown]
# To see what the activity contains, we can convert it to a dictionary:

# %%
random_bio.as_dict()

# %% [markdown]
# ##### Getting activities from codes or keys

# %% [markdown]
# We can see that the activities in the biosphere3 database have unique **codes**, which we can use with the `get` function:

# %%
bio.get(random_bio["code"])
# Out:
# 'Plutonium-238' (kilo Becquerel, None, ('air', 'low population density, long-term'))

# %% [markdown]
# Activities can also be "gotten" via `get_activity`, but the argument is the activity **key**, consisting of a tuple with two elements: the database name, and the activity code.

# %% [markdown]
# **Exercise:** Use `bw.get_activity()` to retrieve the random biosphere activity.

# %%
random_bio["code"]
# Out:
# '3ae6e5bb-fdd6-424a-be6f-80e7240ad8b7'

# %%
bw.get_activity(random_bio.key)
# Out:
# 'Zinc-65' (kilo Becquerel, None, ('air',))

# %% [markdown]
# You can always find (or return) the key to an activity using the `.key` property.

# %%
random_bio.key
# Out:
# ('biosphere3', '4aed2261-0461-4014-be23-cf83de76a3b4')

# %% [markdown]
# ##### Searching for activities

# %% [markdown]
# Let's say we are looking for a specific elementary flow, we can use the `search` method of the database (see [here](https://docs.brightwaylca.org/technical/bw2data.html#default-backend-databases-stored-in-a-sqlite-database) for more details on using search):

# %%
bio.search("carbon dioxide")
# Out:
# ['Carbon dioxide, fossil' (kilogram, None, ('air', 'urban air close to ground')),
#  'Carbon dioxide, fossil' (kilogram, None, ('air', 'low population density, long-term')),
#  'Carbon dioxide, fossil' (kilogram, None, ('air',)),
#  'Carbon dioxide, fossil' (kilogram, None, ('air', 'non-urban air or from high stacks')),
#  'Carbon dioxide, in air' (kilogram, None, ('natural resource', 'in air')),
#  'Carbon dioxide, fossil' (kilogram, None, ('air', 'lower stratosphere + upper troposphere')),
#  'Carbon dioxide, non-fossil' (kilogram, None, ('air', 'low population density, long-term')),
#  'Carbon dioxide, non-fossil' (kilogram, None, ('air', 'urban air close to ground')),
#  'Carbon dioxide, non-fossil' (kilogram, None, ('air',)),
#  'Carbon dioxide, non-fossil' (kilogram, None, ('air', 'lower stratosphere + upper troposphere')),
#  'Carbon dioxide, non-fossil' (kilogram, None, ('air', 'non-urban air or from high stacks')),
#  'Carbon dioxide, from soil or biomass stock' (kilogram, None, ('air',)),
#  'Carbon dioxide, from soil or biomass stock' (kilogram, None, ('air', 'lower stratosphere + upper troposphere')),
#  'Carbon dioxide, from soil or biomass stock' (kilogram, None, ('air', 'urban air close to ground')),
#  'Carbon dioxide, to soil or biomass stock' (kilogram, None, ('soil',)),
#  'Carbon dioxide, to soil or biomass stock' (kilogram, None, ('soil', 'industrial')),
#  'Carbon dioxide, to soil or biomass stock' (kilogram, None, ('soil', 'agricultural')),
#  'Carbon dioxide, from soil or biomass stock' (kilogram, None, ('air', 'non-urban air or from high stacks')),
#  'Carbon dioxide, from soil or biomass stock' (kilogram, None, ('air', 'low population density, long-term')),
#  'Carbon dioxide, to soil or biomass stock' (kilogram, None, ('soil', 'forestry')),
#  'Carbon dioxide, non-fossil, resource correction' (kilogram, None, ('natural resource', 'in air'))]

# %% [markdown]
# It is also possible to use "filters" to narrow searches, e.g.

# %%
bio.search("carbon dioxide, fossil", filter={"categories": "urban", "name": "fossil"})
# Out:
# Excluding 7 filtered results
# ['Carbon dioxide, fossil' (kilogram, None, ('air', 'urban air close to ground')),
#  'Carbon dioxide, fossil' (kilogram, None, ('air', 'non-urban air or from high stacks')),
#  'Carbon dioxide, non-fossil' (kilogram, None, ('air', 'urban air close to ground')),
#  'Carbon dioxide, non-fossil' (kilogram, None, ('air', 'non-urban air or from high stacks'))]

# %% [markdown]
# The database object is also iterable, allowing "home-made" searches through list comprehensions. This approach is better because one can add as many criteria as wanted:

# %%
[
    flow for flow in bio
    if "Carbon dioxide" in flow["name"]
    and ", fossil" in flow["name"]
    and flow["categories"] == ('air', 'lower stratosphere + upper troposphere')
]
# Out:
# ['Carbon dioxide, fossil' (kilogram, None, ('air', 'lower stratosphere + upper troposphere'))]

# %% [markdown]
# Activities returned by searches or list comprehensions can be assigned to variables, but to do so, one needs to identify the activity by index. Based on the above, I can refine my filters to ensure the list comprehension only returns one activity, and then choose it without fear of choosing the wrong one..

# %%
co2 = [
    flow for flow in bio
    if "Carbon dioxide" in flow["name"]
    and ", fossil" in flow["name"]
    and flow["categories"] == ('air', 'lower stratosphere + upper troposphere')
][0]

# %%
co2
# Out:
# 'Carbon dioxide, fossil' (kilogram, None, ('air', 'lower stratosphere + upper troposphere'))

# %% [markdown]
# **Exercise**: look for and assign to a variable an emission of nitrous oxide emitted to air in the "urban air" subcompartment.

# %%
co2.as_dict()
# Out:
# {'categories': ('air', 'lower stratosphere + upper troposphere'),
#  'code': '16eeda8a-1ea2-408e-ab37-2648495058dd',
#  'CAS number': '000124-38-9',
#  'name': 'Carbon dioxide, fossil',
#  'database': 'biosphere3',
#  'unit': 'kilogram',
#  'type': 'emission'}

# %%
len(bio)
# Out:
# 4709

# %%
set(list(f["categories"] for f in bio))
# Out:
# {('air',),
#  ('air', 'low population density, long-term'),
#  ('air', 'lower stratosphere + upper troposphere'),
#  ('air', 'non-urban air or from high stacks'),
#  ('air', 'urban air close to ground'),
#  ('economic', 'primary production factor'),
#  ('inventory indicator', 'output flow'),
#  ('inventory indicator', 'resource use'),
#  ('inventory indicator', 'waste'),
#  ('natural resource', 'biotic'),
#  ('natural resource', 'fossil well'),
#  ('natural resource', 'in air'),
#  ('natural resource', 'in ground'),
#  ('natural resource', 'in water'),
#  ('natural resource', 'land'),
#  ('soil',),
#  ('soil', 'agricultural'),
#  ('soil', 'forestry'),
#  ('soil', 'industrial'),
#  ('water',),
#  ('water', 'fossil well'),
#  ('water', 'ground-'),
#  ('water', 'ground-, long-term'),
#  ('water', 'ocean'),
#  ('water', 'surface water')}

# %% [markdown]
# Let's leave the biosphere database here for now.

# %% [markdown]
# ##### Methods

# %% [markdown]
# bw2_setup() also installed LCIA methods.

# %%
bw.methods
# Out:
# Methods dictionary with 762 objects, including:
# 	('CML v4.8 2016', 'acidification', 'acidification (incl. fate, average Europe total, A&B)')
# 	('CML v4.8 2016', 'climate change', 'global warming potential (GWP100)')
# 	('CML v4.8 2016', 'ecotoxicity: freshwater', 'freshwater aquatic ecotoxicity (FAETP inf)')
# 	('CML v4.8 2016', 'ecotoxicity: marine', 'marine aquatic ecotoxicity (MAETP inf)')
# 	('CML v4.8 2016', 'ecotoxicity: terrestrial', 'terrestrial ecotoxicity (TETP inf)')
# 	('CML v4.8 2016', 'energy resources: non-renewable', 'abiotic depletion potential (ADP): fossil fuels')
# 	('CML v4.8 2016', 'eutrophication', 'eutrophication (fate not incl.)')
# 	('CML v4.8 2016', 'human toxicity', 'human toxicity (HTP inf)')
# 	('CML v4.8 2016', 'material resources: metals/minerals', 'abiotic depletion potential (ADP): elements (ultimate reserves)')
# 	('CML v4.8 2016', 'ozone depletion', 'ozone layer depletion (ODP steady state)')
# Use `list(this object)` to get the complete list.

# %% [markdown]
# One can load a random method:

# %%
bw.methods.random()
# Out:
# ('ReCiPe 2016 v1.03, endpoint (E)',
#  'ecosystem quality',
#  'ecotoxicity: freshwater')

# %%
type(bw.methods.random())
# Out:
# tuple

# %%
method = bw.Method(('ReCiPe 2016 v1.03, endpoint (E)', 'ecosystem quality', 'ecotoxicity: freshwater'))

# %%
method
# Out:
# Brightway2 Method: ReCiPe 2016 v1.03, endpoint (E): ecosystem quality: ecotoxicity: freshwater

# %% [markdown]
# Here, the random method returns the tuple by which the method is identified. To get to an actual method, the following syntax is used:

# %% [markdown]
# Of course, a random method is probably not useful except to play around. To find an actual method, one can again use list comprehensions. Let's say I am interested in using the IPCC2013 100 years method:

# %%
bw.databases
# Out:
# Databases dictionary with 1 object(s):
# 	biosphere3

# %%
type(bw.Database("biosphere3"))
# Out:
# bw2data.backends.peewee.database.SQLiteBackend

# %%
type(list(bw.methods)[0])
# Out:
# tuple

# %%
type(bw.Method(('CML v4.8 2016', 'acidification', 'acidification (incl. fate, average Europe total, A&B)')))
# Out:
# bw2data.method.Method

# %%
[
    m for m in bw.methods
    if "ipcc" not in m[0].lower()
    and "2021" in m[0]
    and "100" in m[2]
    and "biogenic" not in m[2]
]
# Out:
# [('Ecological Scarcity 2021 no LT',
#   'climate change no LT',
#   'global warming potential (GWP100) no LT'),
#  ('Ecological Scarcity 2021',
#   'climate change',
#   'global warming potential (GWP100)')]

# %% [markdown]
# I am interested in the second of these, and will assign it to a variable. I can will refine my search until there is one element in my list and then choose it by subscripting.

# %%
ipcc = bw.Method(('IPCC 2021',
  'climate change',
  'global warming potential (GWP100)'))
ipcc
# Out:
# Brightway2 Method: IPCC 2021: climate change: global warming potential (GWP100)

# %%
ipcc.metadata
# Out:
# {'description': '',
#  'filename': 'LCIA_Implementation_3.9.xlsx',
#  'unit': 'kg CO2-Eq',
#  'abbreviation': 'ipcc-2021cg.53430e09e305748933330bd00b612547',
#  'num_cfs': 5}

# %%
ipcc.load()
# Out:
# [(('biosphere3', '892f10da-7bf2-42b3-b171-221989661a05'), 0.006),
#  (('biosphere3', 'f9749677-9c9f-4678-ab55-c607dfdc2cb9'), 1),
#  (('biosphere3', '4cadbc9f-0472-4bb9-a942-df5b90e37878'), 20.6),
#  (('biosphere3', '9ea11aea-7cb7-4b38-b936-a42c2a4bac97'), 0.437),
#  (('biosphere3', 'fa0c2bee-8dd9-4f8a-8489-b1f3b43de958'), 1530),
#  (('biosphere3', '818cee9e-231c-4b53-8ed2-47a0001802d5'), 161),
#  (('biosphere3', 'f43b2b80-f5a6-4d31-9980-0754305a978d'), 5810),
#  (('biosphere3', '033d3a16-e1a2-4ce8-8769-f4ea867801ca'), 860),
#  (('biosphere3', '393d0862-04cc-45ae-8d08-9dc2a4461b35'), 164),
#  (('biosphere3', '468bebea-17ee-49d3-b11d-c603d91c67c8'), 1.3),
#  (('biosphere3', '400be66e-4383-482a-93e3-c005e96de261'), 2300),
#  (('biosphere3', 'db907ff7-6cf0-4f88-9376-116262dfad6d'), 90.4),
#  (('biosphere3', '27f61651-96a5-45c7-9873-832626cf6905'), 597),
#  (('biosphere3', '15e54d5b-aba2-40a6-9aa8-aa2b8c432129'), 9600),
#  (('biosphere3', 'df5dd437-2e12-4af6-8f7a-9c8224857dc5'), 12400),
#  (('biosphere3', '5d1701c5-c4ef-49c7-8a68-ce7c255eee9f'), 3740),
#  (('biosphere3', 'd2d4b344-3c58-4b0c-868a-ac0bdb2027dc'), 6.34),
#  (('biosphere3', '0e7c1a7b-cd98-4f8d-a619-a687d3e2cb48'), 0.044),
#  (('biosphere3', '4bf1c333-419b-4278-ac14-247c8bf563d6'), 2.43),
#  (('biosphere3', '816c43d1-bc30-4a72-81db-08cb6be4da4f'), 1930),
#  (('biosphere3', '18ddd879-5496-4419-8ab7-e0d3864d977d'), 7200),
#  (('biosphere3', '8ca6c84b-7f56-47e6-8d17-4f2dbc49a943'), 1960),
#  (('biosphere3', '5fa05c4f-8766-41ff-9dd1-fa47c0b7ea48'), 79.4),
#  (('biosphere3', '43bc4fc0-bfeb-46d6-b3de-f69c3ccd622a'), 16200),
#  (('biosphere3', '2716807d-0266-48ff-bb7a-6e6c5fbfd5c5'), 11.2),
#  (('biosphere3', '31a3e44c-4098-461e-aba2-f79540e05087'), 12500),
#  (('biosphere3', '3c8af80d-7ff8-43f4-b1a7-cef73b1b4682'), 160),
#  (('biosphere3', 'c9028b09-c12d-421b-9944-7d145e196ebc'), 771),
#  (('biosphere3', '5f7aad3d-566c-4d0d-ad59-e765f971aa0f'), 29.8),
#  (('biosphere3', '370447a7-70d1-47bd-8577-0a32c4f53570'), 5.54),
#  (('biosphere3', 'baf58fc9-573c-419c-8c16-831ac03203b9'), 27),
#  (('biosphere3', '5c97dd6c-aaa5-4477-aaf8-dbd0674499c4'), 2200),
#  (('biosphere3', 'dfe1da1e-7756-4f7e-a393-6d5e2342a962'), 7380),
#  (('biosphere3', '33a69662-583b-45b8-8cb9-94f59fca9133'), 6230),
#  (('biosphere3', '8f87dcf1-0177-4d62-bea0-a5dd8647ef8c'), 14600),
#  (('biosphere3', 'f3f34697-7231-4575-aaf5-e35b972d329a'), 0.481),
#  (('biosphere3', '1fdc280a-34d3-4513-b110-3f526b17c443'), 17400),
#  (('biosphere3', '98c66fdb-091d-46e9-a533-686f821e8f6a'), 0.02),
#  (('biosphere3', '856c9aa2-c20c-49a8-9417-c71bdb5f17b0'), 25200),
#  (('biosphere3', 'fa5512cf-04a2-4014-8e96-d3e2d137f0df'), 0.006),
#  (('biosphere3', 'f4a1e10b-ed51-433e-a2f5-2a99f231a5e5'), 0.006),
#  (('biosphere3', '66ff5d22-17e2-4112-b486-3ea4e0191fba'), 0.006),
#  (('biosphere3', '982b0510-96ac-4bcb-a758-e98006b95f4d'), 0.006),
#  (('biosphere3', 'aa7cac3a-3625-41d4-bc54-33e2cf11ec46'), 1),
#  (('biosphere3', 'e259263c-d1f1-449f-bb9b-73c6d0a32a00'), 1),
#  (('biosphere3', '16eeda8a-1ea2-408e-ab37-2648495058dd'), 1),
#  (('biosphere3', '349b29d1-3e58-4c66-98b9-9d1a076efd2e'), 1),
#  (('biosphere3', 'fa9b9736-6de8-4bd6-ba22-1bd78c798373'), 20.6),
#  (('biosphere3', '78259cf2-1bb2-41ec-941c-9d70909df094'), 20.6),
#  (('biosphere3', '98af3079-fb76-488d-8afe-713814e14d36'), 20.6),
#  (('biosphere3', 'fbf6ab3a-74e3-4cbe-b61d-959728bdce46'), 20.6),
#  (('biosphere3', 'e7e0031e-791d-42f4-b26c-ec322db637bc'), 0.437),
#  (('biosphere3', '823106de-a29a-481f-8647-728a19b9294d'), 0.437),
#  (('biosphere3', '6cfec9aa-691b-4be2-940d-56e73fda16de'), 0.437),
#  (('biosphere3', '8e30c990-5ed4-4f94-9d0e-2f5e4ff1a1f9'), 0.437),
#  (('biosphere3', '16fcd4f9-0bb8-4b84-8334-3ffb1a17aa74'), 1530),
#  (('biosphere3', '647ae26f-f2fe-44cb-ac81-39bb7736f28e'), 1530),
#  (('biosphere3', '75fe1a2c-49fa-49e4-90f1-8f102508a96d'), 1530),
#  (('biosphere3', 'e87f039d-d9ce-4242-ac18-c9284cc80f3d'), 1530),
#  (('biosphere3', '99585564-bfce-4845-9aaa-2f24b8f26a41'), 161),
#  (('biosphere3', 'f8ee4881-a003-4e18-aa2a-d9daf97d76f7'), 161),
#  (('biosphere3', '9e7d019f-c8c0-4631-9bbb-ced3e081c90d'), 161),
#  (('biosphere3', 'ce6294f5-2ed7-46ee-a967-33e265e34455'), 161),
#  (('biosphere3', '5253e322-7de5-42aa-9167-daf22ff44031'), 5810),
#  (('biosphere3', 'bf580c6b-1b4d-429d-bed7-1e335920941f'), 5810),
#  (('biosphere3', '5eb2d548-1694-496d-b3bd-a439984fca7d'), 5810),
#  (('biosphere3', 'e86bfec2-1025-4fa2-90b1-81e35e621e91'), 5810),
#  (('biosphere3', 'd2025041-20ee-41bb-b2c8-47631e839ff0'), 6520),
#  (('biosphere3', '416eedbd-a7b4-4693-8031-9bfaa2f20ebc'), 860),
#  (('biosphere3', 'b018c97d-8fea-4258-b4d3-6a65669c77f4'), 860),
#  (('biosphere3', '8c193650-c4ae-4e9a-b25b-eaa7b2b9ea2d'), 860),
#  (('biosphere3', '843fd145-61ac-4fa7-a608-ce4ac4d88d49'), 860),
#  (('biosphere3', '1c4a106a-53bc-40f5-bcae-d30ab191dbfe'), 164),
#  (('biosphere3', '94ca9e00-5268-4663-a0cd-25026c7c6b53'), 164),
#  (('biosphere3', 'fff3d2db-2784-4044-a6a2-2bc7242456ee'), 164),
#  (('biosphere3', '9cf9bf0e-86fe-42c0-90cc-bfed96fbdc8f'), 164),
#  (('biosphere3', '89324b2f-1e73-4eb1-9716-96b9be0349ac'), 1.3),
#  (('biosphere3', 'ba3120e9-7412-4517-812c-752edeac5472'), 1.3),
#  (('biosphere3', 'cab70244-9e25-42d3-b31e-ddabfd3eeb67'), 1.3),
#  (('biosphere3', '03758df7-503a-400e-bc7b-ec05825761a5'), 1.3),
#  (('biosphere3', '95b6f6da-49f9-413d-8ff5-5342d6cff588'), 2300),
#  (('biosphere3', '50432644-8568-444e-b7e7-8e37a7e1f3e3'), 2300),
#  (('biosphere3', '1652c2e3-c6c5-49e1-9ad1-34c188087ca6'), 2300),
#  (('biosphere3', 'ba781ac6-cdf1-4a09-86b5-76b19ed3438b'), 2300),
#  (('biosphere3', '2cbc6042-2cee-4668-8017-d7f805d9029e'), 90.4),
#  (('biosphere3', 'f322122f-3059-4cfb-8754-efc82548e7f0'), 90.4),
#  (('biosphere3', '2fff3bda-1eec-4166-9969-bc9e757c8e8e'), 90.4),
#  (('biosphere3', '050da0cd-2957-45a9-ae7a-ace372083fe5'), 90.4),
#  (('biosphere3', '71a6ea76-6642-4573-bed2-c1884e6792fd'), 597),
#  (('biosphere3', '0bf92802-8b5e-43f5-a261-95c06bd5c551'), 597),
#  (('biosphere3', '9b7e5cbf-e1eb-420d-ad43-248df23457ee'), 597),
#  (('biosphere3', '60268f3d-468b-487e-acb1-24d7250cb6b3'), 597),
#  (('biosphere3', '6f8ce7a4-d66a-4593-9314-51778aa09d4b'), 9600),
#  (('biosphere3', '4925cde1-9f43-43d3-bcf1-4865b8de6634'), 9600),
#  (('biosphere3', '30533fd3-b19c-44fc-9a88-fb6b12409b47'), 9600),
#  (('biosphere3', 'ec8789e5-d140-4ca8-b7ef-b3abfd044414'), 9600),
#  (('biosphere3', '8f3e0579-d07d-48c9-b41a-fb559728f9c0'), 12400),
#  (('biosphere3', 'b7e0bddf-7b8a-43f4-9319-6f4b3d9fa65a'), 12400),
#  (('biosphere3', '7f62f535-e81a-476c-9c39-4d59f289db1a'), 12400),
#  (('biosphere3', 'acc39720-dda7-4b3a-80c7-c6394cad4191'), 12400),
#  (('biosphere3', '84386543-b148-465b-9265-ad638c12e263'), 3740),
#  (('biosphere3', 'dc9520c7-6e4a-42fb-b1f6-9fa8f34667a4'), 3740),
#  (('biosphere3', '40022b1f-8906-4c54-a074-bf1a3fc9b13f'), 3740),
#  (('biosphere3', '281e1011-f121-4d5b-ad4d-22d562b2c2cd'), 3740),
#  (('biosphere3', '754028fd-e650-4804-922e-694a764ba578'), 6.34),
#  (('biosphere3', 'd88b5aeb-d589-4847-b2d4-80ba6a227ab7'), 6.34),
#  (('biosphere3', 'a8a2f53b-c6d2-4302-a59f-502bd7e242fc'), 6.34),
#  (('biosphere3', '9bc66656-9f37-44bc-ae0b-5d5243b8137e'), 6.34),
#  (('biosphere3', '22698b26-ab11-43eb-a48f-3e46863555cc'), 0.044),
#  (('biosphere3', 'd56ddb2e-5087-4118-8359-64fb6cb513f9'), 0.044),
#  (('biosphere3', '2e1396a2-b8e0-4f4a-89c7-11c4ee4733c1'), 0.044),
#  (('biosphere3', '57bdb443-d4a6-423d-8024-959b8261d02e'), 27),
#  (('biosphere3', '6c977009-5c4e-4901-a4c1-ab20389cb972'), 27),
#  (('biosphere3', '258263a0-6be3-4439-bd84-efee0498b849'), 27),
#  (('biosphere3', 'da1157e2-7593-4dfd-80dd-a3449b37a4d8'), 27),
#  (('biosphere3', '701cda28-4722-431c-b52f-05a735ef5ed3'), 2.43),
#  (('biosphere3', '09e231fa-b1c2-4d63-9c57-7ea0e2210858'), 2.43),
#  (('biosphere3', '6bdb666d-e227-4f57-9b1d-d25009d3c44b'), 2.43),
#  (('biosphere3', '8c283de2-50d3-40c8-8bff-1e172c3398f8'), 2.43),
#  (('biosphere3', '494eb62d-3e16-4a81-b344-6d6dfd9fd4e2'), 1930),
#  (('biosphere3', '06a4fedf-dab4-4ef1-90df-1d0ce8fe6477'), 1930),
#  (('biosphere3', '50f528ca-45e7-42d0-b399-998ea63ddabf'), 1930),
#  (('biosphere3', 'ee31ac2a-9336-4ed6-8077-9663003bc2f9'), 1930),
#  (('biosphere3', '82957257-07f3-4536-ac8b-175cb2353c75'), 7200),
#  (('biosphere3', '96b52062-5e2f-40de-921a-f443c08862e4'), 7200),
#  (('biosphere3', 'cf719b78-9834-4649-a1dd-8554c366c83f'), 7200),
#  (('biosphere3', '4ac2ffc3-312e-4e2d-88c4-2630d4a73d8c'), 7200),
#  (('biosphere3', '56b7d3b6-83d7-42b0-a65b-5ad23e29db47'), 1960),
#  (('biosphere3', '9b505d7c-4239-40e0-9dbe-55d38f3b85b3'), 1960),
#  (('biosphere3', '26991da1-c263-4707-9f85-78685acc94dc'), 1960),
#  (('biosphere3', '18c582fe-7336-4138-8797-2db8b7a754c7'), 1960),
#  (('biosphere3', '46ecffe9-d6c6-4763-b575-dd73d5bdd727'), 79.4),
#  (('biosphere3', '8b1912e7-fa62-4fa7-9d33-46da503ad788'), 79.4),
#  (('biosphere3', '41f45128-cebe-4ece-aafa-7406a5c98775'), 79.4),
#  (('biosphere3', '5eafb840-6f50-418d-98bd-27b86f75613c'), 79.4),
#  (('biosphere3', '23a9f33d-dbab-4fcc-8f49-1df731b0b827'), 16200),
#  (('biosphere3', '5dfb74d2-fa15-4f2d-bf7c-5aa45a41ec7f'), 16200),
#  (('biosphere3', 'b9c1ac70-e2eb-4fcd-bc63-befa92866af5'), 16200),
#  (('biosphere3', 'e06e2e1e-ad87-49e2-a184-f2d1c48b7b46'), 16200),
#  (('biosphere3', 'd4b61c6c-a620-4a91-afc6-ca87ef97b55a'), 11.2),
#  (('biosphere3', 'f903c2fb-71bf-4568-99fc-6aa7ed7bc922'), 11.2),
#  (('biosphere3', 'b328d33e-9a9f-407d-a767-5c64ccdc163f'), 11.2),
#  (('biosphere3', '432a3326-73f8-4752-bc4d-06b7b4b1243c'), 11.2),
#  (('biosphere3', 'e93ba406-3df8-4e34-be54-0d556b2bb629'), 12500),
#  (('biosphere3', '31f8976a-6f7d-487e-a850-eb495dbf0351'), 12500),
#  (('biosphere3', '1013b9ec-a7b5-459c-be3d-74f61b9ce06e'), 12500),
#  (('biosphere3', 'c0e8ec60-a5ae-432e-97a5-cf76b6247a00'), 12500),
#  (('biosphere3', '727835b8-c650-4d46-882f-35b2a366b559'), 160),
#  (('biosphere3', '34de4196-871a-4db8-a182-589ab780a935'), 160),
#  (('biosphere3', 'de8d76cb-7216-4e6f-8bf2-8cdf76e99902'), 160),
#  (('biosphere3', '04a6edb8-624a-484e-8f85-d771657adae7'), 160),
#  (('biosphere3', '8fbe2c56-c213-4501-b95e-ff57a76fbd6f'), 771),
#  (('biosphere3', '33a791a2-a1e7-446b-b25a-b3be6159bae4'), 771),
#  (('biosphere3', '20d0fc73-b9ce-4001-ac15-893b30ed10a3'), 771),
#  (('biosphere3', '151212b4-079b-43a2-96d5-a6eef59166ac'), 771),
#  (('biosphere3', '70ef743b-3ed5-4a6d-b192-fb6d62378555'), 29.8),
#  (('biosphere3', 'f3bd723a-5276-4ae8-9860-b89537351a90'), 29.8),
#  (('biosphere3', '6b1b495b-70ee-4be6-b1c2-3031aa4d6add'), 29.8),
#  (('biosphere3', '0795345f-c7ae-410c-ad25-1845784c75f5'), 29.8),
#  (('biosphere3', 'ed63abd0-7cc6-4825-8759-b367e560fe95'), 5.54),
#  (('biosphere3', '246c87af-4495-4977-8d39-eae397c1c8f1'), 5.54),
#  (('biosphere3', '0f70e720-127e-44dc-bb85-438158235ab6'), 5.54),
#  (('biosphere3', '18ea247b-edc2-43fe-89bd-cedd04102bcc'), 5.54),
#  (('biosphere3', '0f9f3e17-eb81-4adb-8170-049bc6b66728'), 2200),
#  (('biosphere3', 'ba5c9458-44df-4d93-a7c3-9389f65166d8'), 2200),
#  (('biosphere3', '6c833956-6302-47c3-8abc-7ecae92266fb'), 2200),
#  (('biosphere3', '86d12e70-0c64-4ecf-ba52-114fa0c5d402'), 2200),
#  (('biosphere3', 'b353e7d2-5b94-4b6e-a3e5-de0a10bef851'), 7380),
#  (('biosphere3', 'e59a199f-d4ed-4d43-82b1-71c4a8fae867'), 7380),
#  (('biosphere3', '6d023c39-c04e-4305-b2e4-adc89b53e708'), 7380),
#  (('biosphere3', '33681770-a0e1-4ce8-93c3-941fd607fa5f'), 7380),
#  (('biosphere3', 'a916ca1b-4ece-4630-a563-ae3253efc04f'), 6230),
#  (('biosphere3', '3feb6415-ae50-4bb7-b9d1-c18d99f8a87f'), 6230),
#  (('biosphere3', '6e61b542-5681-44f4-afcb-e30368bca420'), 6230),
#  (('biosphere3', '51e99a55-bcdb-4d18-9484-6de4b142e09d'), 6230),
#  (('biosphere3', '5e2e1740-1bb9-4157-b816-6cb5aa006437'), 14600),
#  (('biosphere3', 'dc78690a-2b0a-49fc-8272-b811fb25ff6c'), 14600),
#  (('biosphere3', 'a3724600-89c1-4f35-97c9-0de3adbadc8b'), 14600),
#  (('biosphere3', 'e5ba3517-a93f-422e-9ce2-f1007fcf6c06'), 14600),
#  (('biosphere3', '1dfddbaf-11aa-4001-89e7-1303b3a95e02'), 0.481),
#  (('biosphere3', '10e38581-58c8-4b27-85a4-6db6a83286ba'), 0.481),
#  (('biosphere3', '4394c871-7245-4bfc-8e9d-9a875e81b7ee'), 0.481),
#  (('biosphere3', 'bce77a75-c399-4fa6-94ab-90d0e704ebde'), 0.481),
#  (('biosphere3', 'f8cf5fd7-9f94-4870-9e6a-768deae9b766'), 17400),
#  (('biosphere3', '4c097625-506e-4dfc-a170-75fda90cf7cb'), 17400),
#  (('biosphere3', 'fdf090d7-ee05-4f33-8b7f-5504c718c3cd'), 17400),
#  (('biosphere3', 'e79e03c3-5b19-45f6-b3f3-bf710c6663d2'), 17400),
#  (('biosphere3', '9beb60a3-3a8c-4345-9a0e-107eec2f709f'), 0.02),
#  (('biosphere3', 'abb87cf5-9e30-4d02-987c-7643510b7013'), 0.02),
#  (('biosphere3', 'aec794cd-e559-46f6-a2a0-7f4ef195144c'), 0.02),
#  (('biosphere3', '3a6c936c-0276-4f11-9d98-1bd011387a6e'), 0.02),
#  (('biosphere3', 'c7c769bb-89b9-4459-afed-e3acecd39339'), 25200),
#  (('biosphere3', 'acbae70a-5450-448f-9038-c403cb496e1a'), 25200),
#  (('biosphere3', '44e4d1ce-fa79-4ed5-93f9-445c4ff8df2e'), 25200),
#  (('biosphere3', '35d1dff5-b535-4628-9826-4a8fce08a1f2'), 25200),
#  (('biosphere3', 'e2ccc98a-6d4e-443b-b11f-d16f32782833'), 9220),
#  (('biosphere3', '9541a975-800f-4fed-9edf-28f6e411a015'), 29.8),
#  (('biosphere3', 'f757365c-c6fd-41fe-ad32-3594ccd97ef0'), 29.8),
#  (('biosphere3', 'e4e9febc-07c1-403d-8d3a-6707bb4d96e6'), 1),
#  (('biosphere3', 'ef4566f0-60d5-4bbe-a2cb-7268a81fecd4'), 29.8),
#  (('biosphere3', 'e1c597cc-14cb-4ebb-af07-7a93a5b77d34'), 1),
#  (('biosphere3', '375bc95e-6596-4aa1-9716-80ff51b9da77'), -1),
#  (('biosphere3', '7f0ba7c9-341e-413d-80f6-8753727d65d1'), 29.8),
#  (('biosphere3', '6d89125e-e9b7-4d7e-a1fc-ada45dbd8815'), 1),
#  (('biosphere3', '78eb1859-abd9-44c6-9ce3-f3b5b33d619c'), 1),
#  (('biosphere3', 'e8787b5e-d927-446d-81a9-f56977bbfeb4'), 1),
#  (('biosphere3', '299c6564-426e-48c3-b516-fdf301d12127'), 29.8),
#  (('biosphere3', '259cf8d6-6ea8-4ccf-84b7-23c930a5b2b3'), -1),
#  (('biosphere3', '60d424f7-d5a9-4549-9540-da06684bc3bb'), -1),
#  (('biosphere3', '8ae4d8bb-3e4b-4825-8325-94696d7a64fd'), -1),
#  (('biosphere3', 'a0950325-06dc-5ca0-84b6-983c9e6ccf74'), 0.044),
#  (('biosphere3', 'f2e4394f-61bb-5493-983d-d3d5b7b96a41'), 0.052),
#  (('biosphere3', '8a3a44e4-e2f1-476d-9e9e-a90fda263fe3'), 9430),
#  (('biosphere3', '7d05319a-1260-45e0-8872-d5ff1712ea7e'), 9430),
#  (('biosphere3', '1e060d5a-cd41-4f30-9c93-272403b7e004'), 9430),
#  (('biosphere3', '1584734d-c5c8-42a5-aa51-0f6a92a9cc0d'), 9430),
#  (('biosphere3', 'cacfd448-6c2d-4061-9363-fd506b979f25'), 6520),
#  (('biosphere3', '53b87932-00c8-4bf4-b519-ecd3c401ed4d'), 6520),
#  (('biosphere3', '47c12d99-c2dc-41cf-bad1-cd31c2fe0421'), 6520),
#  (('biosphere3', '3b30d058-02ef-4ed2-b357-5fc1a45c63e7'), 9430),
#  (('biosphere3', '9b132374-dce2-4ce0-86aa-53201b30f617'), 6520),
#  (('biosphere3', '6dc1b46f-ee89-4495-95c4-b8a637bcd6cb'), 273),
#  (('biosphere3', 'afd6d670-bbb0-4625-9730-04088a5b035e'), 273),
#  (('biosphere3', '81305cda-63f1-4c1a-99c6-2c2568550ec4'), 273),
#  (('biosphere3', '473826ae-125a-4b02-8c8e-c84322491d80'), 273),
#  (('biosphere3', '20185046-64bb-4c09-a8e7-e8a9e144ca98'), 273)]

# %%
bw.get_activity(('biosphere3', '20185046-64bb-4c09-a8e7-e8a9e144ca98')).as_dict()
# Out:
# {'categories': ('air',),
#  'code': '20185046-64bb-4c09-a8e7-e8a9e144ca98',
#  'CAS number': '010024-97-2',
#  'name': 'Dinitrogen monoxide',
#  'database': 'biosphere3',
#  'unit': 'kilogram',
#  'type': 'emission'}

# %% [markdown]
# Of course, if I know exactly the method I want, and I know the syntax, I can simply type it out: `('IPCC 2021', 'climate change', 'GWP 100a')`

# %%
GWP_dict = {bw.get_activity(ef[0])["name"]: ef[1] for ef in ipcc.load()}
GWP_dict
# Out:
# {'Butane': 0.006,
#  'Carbon dioxide, fossil': 1,
#  'Chloroform': 20.6,
#  'Ethane': 0.437,
#  'Ethane, 1,1,1,2-tetrafluoro-, HFC-134a': 1530,
#  'Ethane, 1,1,1-trichloro-, HCFC-140': 161,
#  'Ethane, 1,1,1-trifluoro-, HFC-143a': 5810,
#  'Ethane, 1,1-dichloro-1-fluoro-, HCFC-141b': 860,
#  'Ethane, 1,1-difluoro-, HFC-152a': 164,
#  'Ethane, 1,2-dichloro-': 1.3,
#  'Ethane, 1-chloro-1,1-difluoro-, HCFC-142b': 2300,
#  'Ethane, 2,2-dichloro-1,1,1-trifluoro-, HCFC-123': 90.4,
#  'Ethane, 2-chloro-1,1,1,2-tetrafluoro-, HCFC-124': 597,
#  'Ethane, chloropentafluoro-, CFC-115': 9600,
#  'Ethane, hexafluoro-, HFC-116': 12400,
#  'Ethane, pentafluoro-, HFC-125': 3740,
#  'Tetrachloroethylene': 6.34,
#  'Trichloroethylene': 0.044,
#  'Methane, bromo-, Halon 1001': 2.43,
#  'Methane, bromochlorodifluoro-, Halon 1211': 1930,
#  'Methane, bromotrifluoro-, Halon 1301': 7200,
#  'Methane, chlorodifluoro-, HCFC-22': 1960,
#  'Methane, chloro-fluoro-, HCFC-31': 79.4,
#  'Methane, chlorotrifluoro-, CFC-13': 16200,
#  'Methane, dichloro-, HCC-30': 11.2,
#  'Methane, dichlorodifluoro-, CFC-12': 12500,
#  'Methane, dichlorofluoro-, HCFC-21': 160,
#  'Methane, difluoro-, HFC-32': 771,
#  'Methane, fossil': 29.8,
#  'Methane, monochloro-, R-40': 5.54,
#  'Methane, non-fossil': 27,
#  'Methane, tetrachloro-, R-10': 2200,
#  'Methane, tetrafluoro-, R-14': 7380,
#  'Methane, trichlorofluoro-, CFC-11': 6230,
#  'Methane, trifluoro-, HFC-23': 14600,
#  'Monochloroethane': 0.481,
#  'Nitrogen fluoride': 17400,
#  'Propane': 0.02,
#  'Sulfur hexafluoride': 25200,
#  'Ethane, 1,1,2-trichloro-1,2,2-trifluoro-, CFC-113': 6520,
#  'Perfluoropentane': 9220,
#  'Methane, from soil or biomass stock': 29.8,
#  'Carbon dioxide, from soil or biomass stock': 1,
#  'Carbon dioxide, to soil or biomass stock': -1,
#  'Bromopropane': 0.052,
#  'Ethane, 1,2-dichloro-1,1,2,2-tetrafluoro-, CFC-114': 9430,
#  'Dinitrogen monoxide': 273}

# %%
pd.DataFrame.from_dict(GWP_dict, orient="index", columns=["factor"])
# Out:
#                                                        factor
# Butane                                                  0.006
# Carbon dioxide, fossil                                  1.000
# Chloroform                                             20.600
# Ethane                                                  0.437
# Ethane, 1,1,1,2-tetrafluoro-, HFC-134a               1530.000
# Ethane, 1,1,1-trichloro-, HCFC-140                    161.000
# Ethane, 1,1,1-trifluoro-, HFC-143a                   5810.000
# Ethane, 1,1-dichloro-1-fluoro-, HCFC-141b             860.000
# Ethane, 1,1-difluoro-, HFC-152a                       164.000
# Ethane, 1,2-dichloro-                                   1.300
# Ethane, 1-chloro-1,1-difluoro-, HCFC-142b            2300.000
# Ethane, 2,2-dichloro-1,1,1-trifluoro-, HCFC-123        90.400
# Ethane, 2-chloro-1,1,1,2-tetrafluoro-, HCFC-124       597.000
# Ethane, chloropentafluoro-, CFC-115                  9600.000
# Ethane, hexafluoro-, HFC-116                        12400.000
# Ethane, pentafluoro-, HFC-125                        3740.000
# Tetrachloroethylene                                     6.340
# Trichloroethylene                                       0.044
# Methane, bromo-, Halon 1001                             2.430
# Methane, bromochlorodifluoro-, Halon 1211            1930.000
# Methane, bromotrifluoro-, Halon 1301                 7200.000
# Methane, chlorodifluoro-, HCFC-22                    1960.000
# Methane, chloro-fluoro-, HCFC-31                       79.400
# Methane, chlorotrifluoro-, CFC-13                   16200.000
# Methane, dichloro-, HCC-30                             11.200
# Methane, dichlorodifluoro-, CFC-12                  12500.000
# Methane, dichlorofluoro-, HCFC-21                     160.000
# Methane, difluoro-, HFC-32                            771.000
# Methane, fossil                                        29.800
# Methane, monochloro-, R-40                              5.540
# Methane, non-fossil                                    27.000
# Methane, tetrachloro-, R-10                          2200.000
# Methane, tetrafluoro-, R-14                          7380.000
# Methane, trichlorofluoro-, CFC-11                    6230.000
# Methane, trifluoro-, HFC-23                         14600.000
# Monochloroethane                                        0.481
# Nitrogen fluoride                                   17400.000
# Propane                                                 0.020
# Sulfur hexafluoride                                 25200.000
# Ethane, 1,1,2-trichloro-1,2,2-trifluoro-, CFC-113    6520.000
# Perfluoropentane                                     9220.000
# Methane, from soil or biomass stock                    29.800
# Carbon dioxide, from soil or biomass stock              1.000
# Carbon dioxide, to soil or biomass stock               -1.000
# Bromopropane                                            0.052
# Ethane, 1,2-dichloro-1,1,2,2-tetrafluoro-, CFC-114   9430.000
# Dinitrogen monoxide                                   273.000

# %% [markdown]
# Again, there are a bunch of methods associated with a method object. You can access these by typing ipcc_2013_method. and clicking tab.
# For example, metadata:

# %% [markdown]
# Question: where is this metadata?

# %% [markdown]
# Let's use the `load` method to see what is in the object:

# %% [markdown]
# This contains tuples with (elementary flow, characterization factors).

# %% [markdown]
# ##### Nice display of data in methods

# %% [markdown]
# **Exercise:** Create a dictionary with keys = elementary flow names and values = characterization factors for the `IPCC GWP100` method (including long-term emissions).
#
# Bonus (optional): Generate a Pandas Series with the resulting dictionary.

# %% [markdown]
# Enough said for now about methods.

# %% [markdown]
# #### 1.4) LCI databases

# %% [markdown]
# Outside of the classes, you would probably use the following code to "import" ecoinvent into your brightway installation:
#
# On a "recent" computer, this can take a few minutes to be finished.

# %%
fp = r"/Users/romain/Documents/ecoinvent 3.9.1_cutoff_ecoSpold02/datasets"

ei39 = bw.SingleOutputEcospold2Importer(fp, "ecoinvent 3.9.1 cutoff")
ei39.apply_strategies()
ei39.statistics()
# Out:
# Extracting XML data from 21238 datasets
# Extracted 21238 datasets in 20.35 seconds
# Applying strategy: normalize_units
# Applying strategy: update_ecoinvent_locations
# Applying strategy: remove_zero_amount_coproducts
# Applying strategy: remove_zero_amount_inputs_with_no_activity
# Applying strategy: remove_unnamed_parameters
# Applying strategy: es2_assign_only_product_with_amount_as_reference_product
# Applying strategy: assign_single_product_as_activity
# Applying strategy: create_composite_code
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: fix_ecoinvent_flows_pre35
# Applying strategy: drop_temporary_outdated_biosphere_flows
# Applying strategy: link_biosphere_by_flow_uuid
# Applying strategy: link_internal_technosphere_by_composite_code
# Applying strategy: delete_exchanges_missing_activity
# Applying strategy: delete_ghost_exchanges
# Applying strategy: remove_uncertainty_from_negative_loss_exchanges
# Applying strategy: fix_unreasonably_high_lognormal_uncertainties
# Applying strategy: convert_activity_parameters_to_list
# Applying strategy: add_cpc_classification_from_single_reference_product
# Applying strategy: delete_none_synonyms
# Applying strategy: set_lognormal_loc_value
# Applied 21 strategies in 3.61 seconds
# 21238 datasets
# 674593 exchanges
# 0 unlinked exchanges
# (21238, 674593, 0)

# %%
ei39.write_database()
# Out:
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:15
# Title: Writing activities to SQLite3 database:
#   Started: 03/19/2024 11:06:10
#   Finished: 03/19/2024 11:06:25
#   Total time elapsed: 00:00:15
#   CPU %: 98.80
#   Memory %: 19.72
# Created database: ecoinvent 3.9.1 cutoff
# Brightway2 SQLiteBackend: ecoinvent 3.9.1 cutoff

# %% [markdown]
# Other code to import LCI databases in other formats are found [here](https://github.com/brightway-lca/brightway2-io/tree/master/bw2io/importers). We'll explore this later.

# %% [markdown]
# *We created* a new project, so let's make sure we set it as the "current" project.

# %%
bw.databases
# Out:
# Databases dictionary with 2 object(s):
# 	biosphere3
# 	ecoinvent 3.9.1 cutoff

# %% [markdown]
# To access the actual database, you need to use the Database method:

# %% [markdown]
# Let's assign the database to a variable and see what we can do:

# %%
ei = bw.Database("ecoinvent 3.9.1 cutoff")
ei
# Out:
# Brightway2 SQLiteBackend: ecoinvent 3.9.1 cutoff

# %%
len(ei)
# Out:
# 21238

# %% [markdown]
# Again, we can get an idea of useful methods and attributes by typing eidb. and Tab. Do this now.

# %%
ei.

# %% [markdown]
# ##### LCI activities

# %% [markdown]
# In the context of LCI databases, activities are the nodes "within the technosphere". They are therefore the columns in the technosphere matrix $A$.
# There are different ways to get access to an activity. Let's use the `random()` method for now to explore a random activity in the ecoinvent database.

# %%
act = ei.random()
act
# Out:
# 'hardwood forestry, eucalyptus ssp., planted forest management' (kilogram, BR-MG, None)

# %%
act
# Out:
# 'market for waste concrete, not reinforced' (kilogram, CH, None)

# %%
list(act.keys())
# Out:
# ['comment',
#  'classifications',
#  'activity type',
#  'activity',
#  'database',
#  'filename',
#  'location',
#  'name',
#  'synonyms',
#  'parameters',
#  'authors',
#  'type',
#  'reference product',
#  'flow',
#  'unit',
#  'production amount',
#  'code']

# %% [markdown]
# To see what is stored in an activity object, let's convert our random act in a dictionary:

# %% [markdown]
# Notice one important thing: **no exchanges**!
# Indeed, the exchanges and the activities are stored in two different tables of the `databases.db` database.
# It is possible, however, to iterate through the exchanges of the activities.

# %% [markdown]
# ##### Searching and getting LCI activities

# %% [markdown]
# Searching and getting LCI activities is done exactly the same way as for activities in the biosphere3 database:

# %%
ei.search("electricity production")
# Out:
# ['electricity production, oil' (kilowatt hour, CO, None),
#  'electricity production, oil' (kilowatt hour, IN-UT, None),
#  'electricity production, oil' (kilowatt hour, IN-WB, None),
#  'electricity production, oil' (kilowatt hour, IN-JK, None),
#  'electricity production, oil' (kilowatt hour, IN-GJ, None),
#  'electricity production, oil' (kilowatt hour, IN-MZ, None),
#  'electricity production, oil' (kilowatt hour, IN-NL, None),
#  'electricity production, oil' (kilowatt hour, IN-AS, None),
#  'electricity production, oil' (kilowatt hour, IN-MP, None),
#  'electricity production, oil' (kilowatt hour, IN-OR, None),
#  'electricity production, oil' (kilowatt hour, IN-MN, None),
#  'electricity production, oil' (kilowatt hour, IN-TN, None),
#  'electricity production, oil' (kilowatt hour, IN-HP, None),
#  'electricity production, oil' (kilowatt hour, IN-SK, None),
#  'electricity production, oil' (kilowatt hour, IN-RJ, None),
#  'electricity production, oil' (kilowatt hour, IN-MH, None),
#  'electricity production, oil' (kilowatt hour, IN-DL, None),
#  'electricity production, oil' (kilowatt hour, IN-KL, None),
#  'electricity production, oil' (kilowatt hour, IN-BR, None),
#  'electricity production, oil' (kilowatt hour, IN-GA, None),
#  'electricity production, oil' (kilowatt hour, CA-NS, None),
#  'electricity production, oil' (kilowatt hour, CA-MB, None),
#  'electricity production, oil' (kilowatt hour, CA-NT, None),
#  'electricity production, oil' (kilowatt hour, CA-SK, None),
#  'electricity production, oil' (kilowatt hour, CA-AB, None)]

# %% [markdown]
# **Exercise:** Return an activity for electricity production, coal-fired power plants in Germany

# %%
act = [
    a for a in ei
    if "electricity production" in a["name"]
    and "coal" in a["name"]
    and a["location"] == "DE"
][0]
act
# Out:
# 'electricity production, hard coal' (kilowatt hour, DE, None)

# %%
act.as_dict()
# Out:
# {'comment': 'This dataset represents the production of high voltage electricity in an average hard coal power plant in Germany in 2012. "Hard coal" includes anthracite, coking coal and other bituminous coal according to the definition of the IEA electricity information 2014.\nAll exchanges in this dataset except for emissions of SO2, NOx and particles are production-weighted averages of the figures in the datasets in ecoinvent version two, which are valid for the following 14 countries: AT, BE, ES, FR, IT, NL, PT, DE, CZ, HR, PL, SK, CN, US. The exception values are production-weighted averages of version 2 countries and the new countries in version 3 (AU, CA, CL, ID, IN, KR, MX, MY, PE, RU, TH, TR, TW, TZ, UA, ZA)\nComments on the inventory data of emissions: \n- For the assessment of main characteristics (sulphur and ash content of coal, efficiency of the plant) and CO2 a bottom-up approach has been used. It consists in the collection of information about single plants.\n- The size distribution of particle emissions has been derived from German data. \n - Halogene emissions have been estimated on the basis of the content of the species in the country-specific coal input mix, assuming average retention rates. \n- For CO and particle emissions average values for the former UCTE are included (Union for the Coordination of the Transmission of Electricity, since 2009 replaced by ENTSO-E European Network of Transmission System Operators for Electricity).   \n - The country specific emission depend on the share of DeNOx. \n - Emissions of trace elements were calculated by means of a formula (CORINAIR) using the ash content in the country-specific coal input mix and average transfer coefficients for coal power plants, taking into account the share of DeSOx installed. \n - Emission of uranium and thorium radioactive isotopes were assumed proportional to the corresponding element emitted with particles; the other non-gaseous radioactive isotopes of the uranium and thorium decay chain were assumed proportional to the emitted U-238 or Th-232.  \n- The emission of gaseous radon and K-40 are taken from the literature.\nIEA. 2014. Electricity Information 2014. ISBN 978-92-64-21692-1. International Energy Agency (IEA), Paris Cedex (FR)\nEuropean Environment Agency (1991) CORINAIR Inventory; VOC"s Default Emission Factors\nGeography:  Country-specific data.\nTechnology:  POWER PLANT:\nHard coal power plant input is a market mix of 100MWe power plants (representing all power plants with a capacity <250MWe and 7% of installed capacity) and 500MWe power plants (representing all power plants with a capacity >250MWe and 93% of installed capacity). Please note that in contrast to ecoinvent v2, the two power plant types do not exist anymore as single datasets. Along with (Röder et al. 2004), lifetime of these power plants is assumed to be 150’000 full load hours. Whereas European hard coal power plants are assumed to be operated in mid-load mode with 4000 full load hours per year (corresponding to a lifetime of 37.5 years) (Röder et al. 2004), a capacity factor (average US) of 66% is documented (eGRID 2006), corresponding to about 5800 full load hours per year, or a lifetime of about 26 years.\nAverage installed technology.\n - Share of installed capacity with desulfurisation 2% (rough estimation based on sulfur mass balance\n - Average efficiency of desulfurisation installations: 92% (rough estimation based on Dones et al. 27\n - Share of installed capacity with denitrification (primary and/or secondary installations): 73% (figure based on IEA 212 )\n - Average efficiency of denitrification installations: 8% (estimation based on Dones et al. 27, p.128. Valid for selective catalytic reaction systems)\n - Share of installed capacity with particle filters: 98% (figure based on IEA 212 )\n - Average efficiency of particle filters: 98% (figure based on IEA 212 )\n- IEA 2012. Coal Power Database. International Energy Agency Clean Coal Centre, London \n  ...
#  'classifications': [('EcoSpold01Categories', 'hard coal/power plants'),
#   ('ISIC rev.4 ecoinvent',
#    '3510:Electric power generation, transmission and distribution'),
#   ('CPC', '17100: Electrical energy')],
#  'activity type': 'ordinary transforming activity',
#  'activity': '93174841-7609-568f-aff2-25391d6a9937',
#  'database': 'ecoinvent 3.9.1 cutoff',
#  'filename': '93174841-7609-568f-aff2-25391d6a9937_66c93e71-f32b-4591-901c-55395db5c132.spold',
#  'location': 'DE',
#  'name': 'electricity production, hard coal',
#  'synonyms': ['other bituminous coal', 'anthracite', 'coking coal'],
#  'parameters': [{'description': 'efficiency',
#    'id': '6a0165c7-0fd7-47d6-bfbf-e3fee9aacc42',
#    'unit': 'dimensionless',
#    'comment': 'Literature value/calculated value. Net electrical efficiency based on the lower heating value (LHV). \nFor all OECD countries, the IEA Electricity information 2014 provides data for the year 2012 on fuel input (TJ, Net calorific value NCV) and gross electricity production (GWh) as well as heat production (TJ) in tables 8 and 9 for each country for electricity only and Combined Heat and Power (CHP) plants each. Together with the information on own use (see parameter "losses"), the net electrical efficiency based on the NCV is calculated. \nFor all non-OECD countries, data from the IEA Energy balances of non-OECD countries 2014 have been used. These tables do not always provide information on how much of the electricity has been produced in electricity only and in CHP plants, but often give the total value only. \n\nIEA. 2014. Electricity Information 2014. ISBN 978-92-64-21692-1. International Energy Agency (IEA), Paris Cedex (FR).\nIEA/OECD. 2014. Energy balances of non-OECD countries 2014. International Energy Agency (IEA), Paris Cedex (FR). \n\n',
#    'amount': 0.373,
#    'pedigree': {'reliability': 3,
#     'completeness': 2,
#     'temporal correlation': 1,
#     'geographical correlation': 2,
#     'further technological correlation': 2},
#    'uncertainty type': 2,
#    'loc': -0.986176859338,
#    'scale': 0.057662812973353975,
#    'scale without pedigree': 0.02449489742783178,
#    'name': 'efficiency'},
#   {'description': 'factor: input of MJ for the production of 1 kWh',
#    'id': 'ec714add-6ec4-45ee-b96c-97a442e646e7',
#    'unit': 'MJ/kWh',
#    'comment': 'Calculated value. 3.6 MJ = 1kWh.\nnan',
#    'amount': 9.6514745308311,
#    'uncertainty type': 0,
#    'loc': 9.6514745308311,
#    'name': 'factor_MJ_kWh'},
#   {'description': 'fraction, cooling water, to air',
#    'id': 'd1efa4be-e613-43fd-9d73-e8b92b39b283',
#    'unit': 'dimensionless',
#    'comment': 'Calculated\nnan',
#    'amount': 0.0251073890313343,
#    'pedigree': {'reliability': 2,
#     'completeness': 3,
#     'temporal correlation': 2,
#     'geographical correlation': 2,
#     'further technological correlation': 1},
#    'uncertainty type': 2,
#    'loc': -3.68459309245,
#    'scale': 0.20353132437047622,
#    'scale without pedigree': 0.2,
#    'name': 'fraction_CW_to_air'},
#   {'description': 'fraction, process water, to air',
#    'id': 'daadf2d4-7bbb-4f69-8ab5-58df4c1685eb',
#    'unit': 'dimensionless',
#    'comment': 'Literature value. In case when no industry/process specific data are available, default evaporation fraction value is used. This value is 15% and is based on literature (Statistics Canada, 2007 & Shaffer, K.H., 2008, Consumptive water use in the Great Lakes Basin, USGS & Shiklomanov, 2003, World Water Resources at the Beginning of the 21st Century) and has been approved by an expert.\nnan',
#    'amount': 0.15,
#    'pedigree': {'reliability': 4,
#     'completeness': 4,
#     'temporal correlation': 3,
#     'geographical correlation': 2,
#     'further technological correlation': 4},
#    'uncertainty type': 2,
#    'loc': -1.89711998489,
#    'scale': 0.30335622624235026,
#    'scale without pedigree': 0.2,
#    'name': 'fraction_PW_to_air'},
#   {'description': 'fraction, water, completely softened, to air',
#    'id': 'a6208a3b-d42f-476b-b52d-f12a68ecb755',
#    'unit': 'dimensionless',
#    'comment': 'Calculated value. See comment in the other parametres present in this dataset. Water, completely softened is considered to be always used as process water, thus process water fractions to air are applied to all water, completely softened input flows to calculate the amount of water consumed in the processes.\nnan',
#    'amount': 0.15,
#    'pedigree': {'reliability': 4,
#     'completeness': 4,
#     'temporal correlation': 3,
#     'geographical correlation': 2,
#     'further technological correlation': 4},
#    'uncertainty type': 2,
#    'loc': -1.89711998489,
#    'scale': 0.30335622624235026,
#    'scale without pedigree': 0.2,
#    'name': 'fraction_WCS_to_air'},
#   {'description': 'fraction, water, decarbonised, to air',
#    'id': '68b1bd9b-e466-4d80-9da1-eb76644717dc',
#    'unit': 'dimensionless',
#    'comment': 'Calculated value. See comments in the other parametres present in this dataset. Decarbonised water is considered to be always used as cooling water, thus cooling water fractions to air are applied to all carbonised water input flows to calculate the amount of water consumed in the processes.\nnan',
#    'amount': 0.0251073890313343,
#    'pedigree': {'reliability': 2,
#     'completeness': 3,
#     'temporal correlation': 2,
#     'geographical correlation': 2,
#     'further technological correlation': 1},
#    'uncertainty type': 2,
#    'loc': -3.68459309245,
#    'scale': 0.20353132437047622,
#    'scale without pedigree': 0.2,
#    'name': 'fraction_WDC_to_air'},
#   {'description': 'gross electricity production',
#    'id': '8ce7c260-eef4-467b-833a-7754240d2626',
#    'unit': 'kilowatt hour',
#    'comment': 'Literature value/statistics. Taken from the IEA electricity information 2014, table 1.3. \nIEA. 2014. Electricity Information 2014. ISBN 978-92-64-21692-1. International Energy Agency (IEA), Paris Cedex (FR).\nnan',
#    'amount': 101508000000.0,
#    'pedigree': {'reliability': 2,
#     'completeness': 1,
#     'temporal correlation': 1,
#     'geographical correlation': 1,
#     'further technological correlation': 1},
#    'uncertainty type': 2,
#    'loc': 25.3434034501,
#    'scale': 0.034641016151377546,
#    'scale without pedigree': 0.02449489742783178,
#    'name': 'gross_electricity'},
#   {'description': 'losses from gross electricity production',
#    'id': '22325219-5239-4f09-a250-5b20c7fe50d2',
#    'unit': 'dimensionless',
#    'comment': 'Calculated value. Own use of electricity plants in this country in 2012. For the OECD countries, the OECD iLibrary provides gross and net electricity values for the specific sector "Total Fuel Combustion", from which the loss value is being calculated. This value is then applied to all fossil fuel datasets, as no data on a more detailed level were available.\n\nOECD. 2014. IEA Electricity Information Statistics: OECD - Electricity and heat generation. OECD iLibrary. Online database. DOI : 10.1787/elect-data-en \nnan',
#    'amount': 0.07,
#    'pedigree': {'reliability': 3,
#     'completeness': 2,
#     'temporal correlation': 2,
#     'geographical correlation': 2,
#     'further technological correlation': 2},
#    'uncertainty type': 2,
#    'loc': -2.65926003693,
#    'scale': 0.05937171043518958,
#    'scale without pedigree': 0.02449489742783178,
#    'name': 'losses_gross_net'},
#   {'description': 'once-through and cooling pond cooling systems as a fraction of all cooling syste',
#    'id': 'be17ac58-cf6a-406a-98b8-1e283bf7adc1',
#    'unit': 'dimensionless',
#    'comment': 'Calculated as an average of data available for Europe (Floerke, 2008, Future changes of freshwater needs in the electricity production sector) and USA (NERL, 2011, Estimating freshwater needs to meet future thermoelectric generation requirements).\nnan',
#    'amount': 0.73,
#    'pedigree': {'reliability': 4,
#     'completeness': 4,
#     'temporal correlation': 3,
#     'geographical correlation': 2,
#     'further technological correlation': 4},
#    'uncertainty type': 2,
#    'loc': -0.31471074484,
#    'scale': 0.30335622624235026,
#    'scale without pedigree': 0.2,
#    'name': 'once_through_andCP_CS_fractio_from_allCS'},
#   {'description': 'recirculating cooling system as a fraction of all cooling systems',
#    'id': 'b7e87ab1-d4af-4b4e-8b28-a4797252c930',
#    'unit': 'dimensionless',
#    'comment': 'Calculated as an average of data available for Europe (Floerke, 2008, Future changes of freshwater needs in the electricity production sector) and USA (NERL, 2011, Estimating freshwater needs to meet future thermoelectric generation requirements).\nnan',
#    'amount': 0.27,
#    'pedigree': {'reliability': 4,
#     'completeness': 4,
#     'temporal correlation': 3,
#     'geographical correlation': 2,
#     'further technological correlation': 4},
#    'uncertainty type': 2,
#    'loc': -1.30933331998,
#    'scale': 0.30335622624235026,
#    'scale without pedigree': 0.2,
#    'name': 'recirculating_CS_fraction_from_allCS'},
#   {'description': 'water consumption, electricity production from hard coal, once-through and cooli',
#    'id': '5011d7d7-0847-4d5d-b317-ee5dddc3ae82',
#    'unit': 'm3/kWh',
#    'comment': 'Estimated based on literature (Scown, 2011, Water Footprint of U.S. Transportation Fuels, SI). The amount of water consumed while burning lignite and peat is assumed to be the same as in case of coal.\nnan',
#    'amount': 0.0014,
#    'pedigree': {'reliability': 4,
#     'completeness': 4,
#     'temporal correlation': 3,
#     'geographical correlation': 2,
#     'further technological correlation': 4},
#    'uncertainty type': 2,
#    'loc': -6.57128304236,
#    'scale': 0.30335622624235026,
#    'scale without pedigree': 0.2,
#    'name': 'WConsumption_EP_HC_once_through_andCP_CS'},
#   {'description': 'water consumption, electricity production from hard coal, recirculating CS',
#    'id': '708f3168-f2c7-43f5-825a-d48c92c247c0',
#    'unit': 'm3/kWh',
#    'comment': 'Estimated based on literature (Scown, 2011, Water Footprint of U.S. Transportation Fuels, SI). The amount of water consumed while burning lignite and peat is assumed to be the same as in case of coal.\nnan',
#    'amount': 0.0018,
#    'pedigree': {'reliability': 4,
#     'completeness': 4,
#     'temporal correlation': 3,
#     'geographical correlation': 2,
#     'further technological correlation': 4},
#    'uncertainty type': 2,
#    'loc': -6.31996861408,
#    'scale': 0.30335622624235026,
#    'scale without pedigree': 0.2,
#    'name': 'WConsumption_EP_HC_recirculatingCS'},
#   {'description': 'water withdrawal, electricity production from hard coal, once-through and coolin',
#    'id': '5169c540-98f3-4666-a018-d12fd3965b54',
#    'unit': 'm3/kWh',
#    'comment': 'Estimated based on literature (Scown, 2011, Water Footprint of U.S. Transportation Fuels, SI). The amount of water withdrawn while burning lignite and peat is assumed to be the same as in case of coal.\nnan',
#    'amount': 0.0815,
#    'pedigree': {'reliability': 4,
#     'completeness': 4,
#     'temporal correlation': 3,
#     'geographical correlation': 2,
#     'further technological correlation': 4},
#    'uncertainty type': 2,
#    'loc': -2.50715225874,
#    'scale': 0.30335622624235026,
#    'scale without pedigree': 0.2,
#    'name': 'WWithdrawal_EP_HC_once_through_andCP_CS'},
#   {'description': 'water withdrawal, electricity production from hard coal, recirculating CS',
#    'id': '0b050f3d-0478-4760-957c-bb8d0ad08666',
#    'unit': 'm3/kWh',
#    'comment': 'Estimated based on literature (Scown, 2011, Water Footprint of U.S. Transportation Fuels, SI). The amount of water withdrawn while burning lignite and peat is assumed to be the same as in case of coal.\nnan',
#    'amount': 0.0021,
#    'pedigree': {'reliability': 4,
#     'completeness': 4,
#     'temporal correlation': 3,
#     'geographical correlation': 2,
#     'further technological correlation': 4},
#    'uncertainty type': 2,
#    'loc': -6.16581793425,
#    'scale': 0.30335622624235026,
#    'scale without pedigree': 0.2,
#    'name': 'WWithdrawal_EP_HC_recirculating_CS'}],
#  'authors': {'data entry': {'name': 'Karin Treyer',
#    'email': 'karin.treyer@psi.ch'},
#   'data generator': {'name': 'Karin Treyer', 'email': 'karin.treyer@psi.ch'}},
#  'type': 'process',
#  'reference product': 'electricity, high voltage',
#  'flow': '66c93e71-f32b-4591-901c-55395db5c132',
#  'unit': 'kilowatt hour',
#  'production amount': 1.0,
#  'code': 'f30c46c44c2292cee46f9af3c1b8aca5'}

# %%
act.exchanges()
# Out:
# ('ecoinvent 3.9.1 cutoff', 'f30c46c44c2292cee46f9af3c1b8aca5')

# %% [markdown]
# #### LCI exchanges

# %% [markdown]
# **`Exchanges`** are the edges between nodes.
#
# These can be:
#   - an edge between two activities within the technosphere (an element $a_{ij}$ of matrix $A$)
#   - edges between an activity in the technosphere and an activity in the "biosphere" (an element $b_{kj}$ of the biosphere matrix $B$).

# %% [markdown]
# One can iterate through **all** exchanges that have a given activity as `output`

# %%
for e in act.exchanges():
    if e["type"] == "technosphere":
        print(e["name"], e["amount"], e.get("location"), e["type"])
# Out:
# NOx retained, by selective catalytic reduction 0.00225844504021448 None technosphere
# SOx retained, in hard coal flue gas desulfurisation 0.00594530831099196 None technosphere
# chlorine, liquid 9.6514745308311e-05 None technosphere
# hard coal 0.402466487935657 None technosphere
# hard coal ash -0.00253833780160858 None technosphere
# hard coal power plant 1.25469168900804e-11 None technosphere
# light fuel oil 0.000164075067024129 None technosphere
# residue from cooling tower -4.82573726541555e-05 None technosphere
# water, completely softened 0.0579088471849866 None technosphere
# water, decarbonised 1.44772117962467 None technosphere

# %%
1/1.25469168900804e-11/1e6
# Out:
# 79700.85470085489

# %% [markdown]
# One can also iterate through subsets of the exchanges:
#   - Technosphere exchanges: exchanges linking to other activities in the technosphere, `activity.technosphere()`
#   - Biosphere exchanges: AKA elementary flows, linking to activities in the biosphere database `activity.biosphere()`
#   - Production exchange: the reference flow of the activity `activity.production`

# %% [markdown]
# Let's assign a **technosphere exchange** to a variable to learn more about it:

# %% [markdown]
# Again, the type is a proxy (refer to the diagram above about the different translation layers).

# %% [markdown]
# Let's now look at a production exchange

# %% [markdown]
# **Exercise:** Assign a biosphere flow to a variable, and check the following:
#   - Is the output the same as for the technosphere exchange?
#   - From what database does the biosphere exchange come from?
#   - What is the amount of the exchange (i.e. the weight of the edge connecting the two activities)?
#
# NOTE: If you get a ` list index out of range` error when trying to subscript your list comprehension, it means your list comprehension is empty, i.e. that there are no biosphere flows associated with the activity.

# %% [markdown]
# #### Loaded LCI databases

# %% [markdown]
# It is possible to load the entire database into a dictionary.
# This greatly speeds up work if you need to iterate over all activities or exchanges. The resulting object is quite big, so you should do this only if the gain in efficiency is worth it.

# %% [markdown]
# ## 2) My first LCA

# %% [markdown]
# Brightway has a so-called LCA object.
# It is instantiated using `LCA(args)`.
# The only required argument is a functional unit, described by a dictionary with keys = activities and values = amounts (more [here](https://docs.brightwaylca.org/lca.html#specifying-a-functional-unit)).
# A second argument that is often passed is an LCIA method, passed using the method tuple.

# %% [markdown]
# ### 2.1) General syntax of LCA calculations

# %% [markdown]
# Let's create our first LCA object using our random activity and our IPCC method.

# %%
ipcc
# Out:
# Brightway2 Method: IPCC 2021: climate change: global warming potential (GWP100)

# %%
act
# Out:
# 'electricity production, hard coal' (kilowatt hour, DE, None)

# %%
ipcc.name
# Out:
# ('IPCC 2021', 'climate change', 'global warming potential (GWP100)')

# %%
lca = bw.LCA({act: 1}, method=ipcc.name)

# %% [markdown]
# The steps to get to the impact score are as follows:

# %% [markdown]
# Let's not take a closer look at the LCA object and its methods/attributes. We'll do this by creating a new LCA object:

# %%
lca.lci()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/bw/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.58e+13)
#   warnings.warn(msg, UmfpackWarning)

# %%
lca.lcia()

# %%
lca.score
# Out:
# 1.0545383927068062

# %%
act_dict, _, _ = lca.reverse_dict()

# %%
act_dict
# Out:
# {0: ('ecoinvent 3.9.1 cutoff', 'f32ba57ebce8c08759275f740a88f370'),
#  1: ('ecoinvent 3.9.1 cutoff', '73a4483e483a28e471ceffb1e6ef8b0d'),
#  2: ('ecoinvent 3.9.1 cutoff', 'fb126ed85de69f5cac7f991f022d9b5c'),
#  3: ('ecoinvent 3.9.1 cutoff', '10302c31d0d4a1816bd8bb0032c0198f'),
#  4: ('ecoinvent 3.9.1 cutoff', 'bad56a905eb6f8bed4e273051a455157'),
#  5: ('ecoinvent 3.9.1 cutoff', '0d759a754439881bf0f5e934078dcedf'),
#  6: ('ecoinvent 3.9.1 cutoff', '17c9670f75f1b10a3ea8850c4bffdccb'),
#  7: ('ecoinvent 3.9.1 cutoff', '484ed4ed4737fac9849242b16d5a23c7'),
#  8: ('ecoinvent 3.9.1 cutoff', '6ea399ff612d73f5a4cde92a17992053'),
#  9: ('ecoinvent 3.9.1 cutoff', '2840342713a23d57067cb420745eb251'),
#  10: ('ecoinvent 3.9.1 cutoff', '6caa34be583700c562617d1cc473c1b5'),
#  11: ('ecoinvent 3.9.1 cutoff', '7d2e14ef80a94cebc66c3cff7c989496'),
#  12: ('ecoinvent 3.9.1 cutoff', '362c5d4e230434904ed2821d5ac1098c'),
#  13: ('ecoinvent 3.9.1 cutoff', 'ba4b47e0d1f15aff29e8b9ab1e1bb5ba'),
#  14: ('ecoinvent 3.9.1 cutoff', 'fd558441fc3d04fe59887ab30ce51119'),
#  15: ('ecoinvent 3.9.1 cutoff', '74ed92848731568ab051e79ab70c4097'),
#  16: ('ecoinvent 3.9.1 cutoff', '3c7f02be1dda1696aa4ee51a60c77b81'),
#  17: ('ecoinvent 3.9.1 cutoff', '8311780013b1bafd8a33cf5072e04705'),
#  18: ('ecoinvent 3.9.1 cutoff', 'e3a15500c3c58c6c469dbf2f2c49b56f'),
#  19: ('ecoinvent 3.9.1 cutoff', 'e2d3c731f67f8144f90429cd6ac885c8'),
#  20: ('ecoinvent 3.9.1 cutoff', '63ea017e389a07a36765e03be75c2485'),
#  21: ('ecoinvent 3.9.1 cutoff', '5154a90d092791a65100c269137789c7'),
#  22: ('ecoinvent 3.9.1 cutoff', 'cf676ee99b6cdb0905258bb04bb0f3a0'),
#  23: ('ecoinvent 3.9.1 cutoff', '93d98a8dd211ddd167d35cc95eb66f5f'),
#  24: ('ecoinvent 3.9.1 cutoff', 'e4c5b41dcde9685bc2131040d1fd870a'),
#  25: ('ecoinvent 3.9.1 cutoff', 'b755c4ba3685105d26176143c42e2f2a'),
#  26: ('ecoinvent 3.9.1 cutoff', '6257a25404ae9abf31ed548e85475df7'),
#  27: ('ecoinvent 3.9.1 cutoff', '4778fac49b5bffdcf80ad5650fe9b050'),
#  28: ('ecoinvent 3.9.1 cutoff', '161984d1e59b5c2c848ce21c67daae1e'),
#  29: ('ecoinvent 3.9.1 cutoff', 'aa5053ebcc4ba4811d01ea16e8c53692'),
#  30: ('ecoinvent 3.9.1 cutoff', '1e605dd55fe8bc84a3f4d8c1da589270'),
#  31: ('ecoinvent 3.9.1 cutoff', 'f841c8eeaac498721da2c12e6b5316e2'),
#  32: ('ecoinvent 3.9.1 cutoff', 'b843e93f4e81134438fa343a7279110a'),
#  33: ('ecoinvent 3.9.1 cutoff', '32973d509e20ba45e3cc95f7b3e4ab71'),
#  34: ('ecoinvent 3.9.1 cutoff', '6c832cf13947ee8f131fa3c2325a6b91'),
#  35: ('ecoinvent 3.9.1 cutoff', '60eccfb05dccf174b2561c7776f81973'),
#  36: ('ecoinvent 3.9.1 cutoff', '784f73d972061c425989938ae16aaa52'),
#  37: ('ecoinvent 3.9.1 cutoff', 'dfa62d42f9c3335ba32b022da00f477c'),
#  38: ('ecoinvent 3.9.1 cutoff', '4a321fdc8c74b2f471baed263b860d48'),
#  39: ('ecoinvent 3.9.1 cutoff', 'd8b2ce5d2112db0527d898b6ba2530bb'),
#  40: ('ecoinvent 3.9.1 cutoff', 'a605cb1691542a9b643a91adafe8e3fe'),
#  41: ('ecoinvent 3.9.1 cutoff', 'dda50173cd4b455eff6c0f92bfa6a0fb'),
#  42: ('ecoinvent 3.9.1 cutoff', 'b0450625dadb5eb63e4ced0e094f22af'),
#  43: ('ecoinvent 3.9.1 cutoff', '65a59a52f5396ad59802eeb669d42bf5'),
#  44: ('ecoinvent 3.9.1 cutoff', '8c796bb3d2fdce73306e7dcbdf8e595f'),
#  45: ('ecoinvent 3.9.1 cutoff', 'c6d1f05d71cdc9e93615eb8c6c55861c'),
#  46: ('ecoinvent 3.9.1 cutoff', '51c781cb9d00f21fad481dd8f1ae2645'),
#  47: ('ecoinvent 3.9.1 cutoff', '6edc04f5504105cfca6b4949ecf91c85'),
#  48: ('ecoinvent 3.9.1 cutoff', '896aee018828671ac111e4afdf9113b8'),
#  49: ('ecoinvent 3.9.1 cutoff', '76b8a5b3f6bee5ae376b86dfe1d42b84'),
#  50: ('ecoinvent 3.9.1 cutoff', '3a8accbf06701a9a4510fcce80e2c083'),
#  51: ('ecoinvent 3.9.1 cutoff', '514d3fb427d513a540fb5c118201d2e4'),
#  52: ('ecoinvent 3.9.1 cutoff', 'b27eeb91e3020c593cc8a713f1f800d3'),
#  53: ('ecoinvent 3.9.1 cutoff', '2747c5af40950e8e8402cf7f35c65f7b'),
#  54: ('ecoinvent 3.9.1 cutoff', 'bf81f22a10076a23b162ee1bc5806d75'),
#  55: ('ecoinvent 3.9.1 cutoff', '262e215dfa60eed26973ba459b2db10a'),
#  56: ('ecoinvent 3.9.1 cutoff', '7a910ec794edd8bf61176584f5c241ea'),
#  57: ('ecoinvent 3.9.1 cutoff', '69b287a7cf8ac3fc5ef4235d541cb62b'),
#  58: ('ecoinvent 3.9.1 cutoff', '739947f4c00a96cc479b4d63f7e429f7'),
#  59: ('ecoinvent 3.9.1 cutoff', '055f966750130a6b94d81874c14b913a'),
#  60: ('ecoinvent 3.9.1 cutoff', '13e49a5db063c58aab0304e4dbedf2a4'),
#  61: ('ecoinvent 3.9.1 cutoff', 'b87e62377cece6b8a62df55206e1189c'),
#  62: ('ecoinvent 3.9.1 cutoff', 'b249f628166b17ebcccf3d32c7048c90'),
#  63: ('ecoinvent 3.9.1 cutoff', 'bffb996eaca3b3bd2ea44487dd2b45ea'),
#  64: ('ecoinvent 3.9.1 cutoff', '5d3f18d1d01ccf6c5842ba43d400b808'),
#  65: ('ecoinvent 3.9.1 cutoff', 'a85a72087b9dcaac874b3d6c314dcb09'),
#  66: ('ecoinvent 3.9.1 cutoff', '0418fb60693885b06166390b9f3008f3'),
#  67: ('ecoinvent 3.9.1 cutoff', '04583a14a8acc2843e9b6e5a90bf3ba0'),
#  68: ('ecoinvent 3.9.1 cutoff', 'c0538595a23f519bb3421f85ec6e4d15'),
#  69: ('ecoinvent 3.9.1 cutoff', '671ddeb7e0d1cd30ef7f0955777acf5d'),
#  70: ('ecoinvent 3.9.1 cutoff', 'ea852302635dd9d99a09b1c983cc9f5b'),
#  71: ('ecoinvent 3.9.1 cutoff', '03c763ad66457736ebbd9caa65a373fd'),
#  72: ('ecoinvent 3.9.1 cutoff', '02a188eb9d7d87ffff32703c010faf53'),
#  73: ('ecoinvent 3.9.1 cutoff', '5a6e0edde7c7adb5d248ed73b00e7376'),
#  74: ('ecoinvent 3.9.1 cutoff', '6cca52b10377e29e2617d106d609c210'),
#  75: ('ecoinvent 3.9.1 cutoff', '0955d8f082bfb36f636d7556d0a45e6a'),
#  76: ('ecoinvent 3.9.1 cutoff', 'ec9bded66f51645eec5fcb968593a909'),
#  77: ('ecoinvent 3.9.1 cutoff', '956704e865e662848e5e56482ffcd015'),
#  78: ('ecoinvent 3.9.1 cutoff', '8e3e9f990e51c3986d3aac4ab4225d4a'),
#  79: ('ecoinvent 3.9.1 cutoff', '38555c1eedd89442376428c6bf075891'),
#  80: ('ecoinvent 3.9.1 cutoff', 'd7b541bc86ff085ef8885572608fa059'),
#  81: ('ecoinvent 3.9.1 cutoff', 'f6ae88e4d2648ae99bd42937bd819853'),
#  82: ('ecoinvent 3.9.1 cutoff', '17fd1e13b29b6ddf538b80711b187d50'),
#  83: ('ecoinvent 3.9.1 cutoff', '74b0a39f12606b7747e5b7ed822be57e'),
#  84: ('ecoinvent 3.9.1 cutoff', '6ec1967d6d1c656dec4feb0fb7d7a009'),
#  85: ('ecoinvent 3.9.1 cutoff', 'd39a2c0ea27f3f627f1fbf112a2e082f'),
#  86: ('ecoinvent 3.9.1 cutoff', '83f1b035cdd0b8b268c8a30d6bbf5fc6'),
#  87: ('ecoinvent 3.9.1 cutoff', '31ea7971afe205dacd39e67f0ed05bc3'),
#  88: ('ecoinvent 3.9.1 cutoff', '56938f13bb29678fb0d5186b4daca375'),
#  89: ('ecoinvent 3.9.1 cutoff', '698b12a3fade05d79f3d414c79a931ee'),
#  90: ('ecoinvent 3.9.1 cutoff', '84aa1da9811dc23d8588ab6f43ec232d'),
#  91: ('ecoinvent 3.9.1 cutoff', '4f4d94f579643c0db2fb2d2b7301373c'),
#  92: ('ecoinvent 3.9.1 cutoff', '7cd5ab8265d8f7c282c657ed90e3d8af'),
#  93: ('ecoinvent 3.9.1 cutoff', 'bc4470db8b0ce7b36005b03df4608207'),
#  94: ('ecoinvent 3.9.1 cutoff', 'bd81e54339a8aa1196a6ba266d70db2b'),
#  95: ('ecoinvent 3.9.1 cutoff', '0ad6341e6bd3465d1c34ab5c21a555e9'),
#  96: ('ecoinvent 3.9.1 cutoff', '39b7ba0fe3e85c6540ca6ac6e2faf8f6'),
#  97: ('ecoinvent 3.9.1 cutoff', 'ec38c1e6b792b33796e3ae69d73ac82c'),
#  98: ('ecoinvent 3.9.1 cutoff', 'dd6fabba83be0e67f6abb428d1ad5254'),
#  99: ('ecoinvent 3.9.1 cutoff', 'f332a15b4972392127554c3f2a87944f'),
#  100: ('ecoinvent 3.9.1 cutoff', '366b2ce2a52c20b5ebc3b2c71b9827b6'),
#  101: ('ecoinvent 3.9.1 cutoff', '258dca9f740aaf14496050f2395e463e'),
#  102: ('ecoinvent 3.9.1 cutoff', '55876088ce7c49e7f54a56ec1255ee78'),
#  103: ('ecoinvent 3.9.1 cutoff', '782616a55d84e31b5523f3a8258982e8'),
#  104: ('ecoinvent 3.9.1 cutoff', '3462ed747cfdcacaa52fd69a3ca3cd57'),
#  105: ('ecoinvent 3.9.1 cutoff', 'ffe2005822d3aaf5e99a81a09495c727'),
#  106: ('ecoinvent 3.9.1 cutoff', '245eaef2fb637e428e0425deb295ec37'),
#  107: ('ecoinvent 3.9.1 cutoff', 'dd76a95b5234654590269bde045c4c56'),
#  108: ('ecoinvent 3.9.1 cutoff', '648ca6a8c91e72725e28da0c8b6770d9'),
#  109: ('ecoinvent 3.9.1 cutoff', '89ff757c13dec244573975ac436b2c90'),
#  110: ('ecoinvent 3.9.1 cutoff', 'a5e3a6a206996f0b2efbda04d05a4276'),
#  111: ('ecoinvent 3.9.1 cutoff', 'f73c4db36f8b9510489b7f1c2fb90d29'),
#  112: ('ecoinvent 3.9.1 cutoff', '6e54f9ce32289fbc2a1500dd91210913'),
#  113: ('ecoinvent 3.9.1 cutoff', 'f69130b5b2986046713e9d6b1bfbe860'),
#  114: ('ecoinvent 3.9.1 cutoff', 'a32bb801fd61cb23457e285134d4893b'),
#  115: ('ecoinvent 3.9.1 cutoff', 'c254bf90499807cf43a87369786ced62'),
#  116: ('ecoinvent 3.9.1 cutoff', 'bda07e5ec57ce247244bb00d3ee909e5'),
#  117: ('ecoinvent 3.9.1 cutoff', 'c15a417acce2dc6d301385fc58ac0f5a'),
#  118: ('ecoinvent 3.9.1 cutoff', '5a3ee25228df102236bc2d7bb3a0cf89'),
#  119: ('ecoinvent 3.9.1 cutoff', 'c43e9205c40569ebd53e0a570820b130'),
#  120: ('ecoinvent 3.9.1 cutoff', '258c2fdcc508bb2fa6e5430367ee505a'),
#  121: ('ecoinvent 3.9.1 cutoff', '78850c6bdd3dcb134f4111d956bab936'),
#  122: ('ecoinvent 3.9.1 cutoff', 'd5d28c2d6951102dadb02983a31c1747'),
#  123: ('ecoinvent 3.9.1 cutoff', '4a42df253e405ab7869e7fabebd07130'),
#  124: ('ecoinvent 3.9.1 cutoff', '08ade2e378cf36041ec520867c77f81c'),
#  125: ('ecoinvent 3.9.1 cutoff', 'e891fd812caf651c8e8cabef33212069'),
#  126: ('ecoinvent 3.9.1 cutoff', '35d665cdeccbe8b2c632970ce69968b8'),
#  127: ('ecoinvent 3.9.1 cutoff', '4fb8ae7c7146a26156cb4dda0871c1ce'),
#  128: ('ecoinvent 3.9.1 cutoff', '82cd489a3909cdcb769da2537edee9c4'),
#  129: ('ecoinvent 3.9.1 cutoff', 'aeb7cac6ddf844cd566779c51d77a118'),
#  130: ('ecoinvent 3.9.1 cutoff', '75513360143f653749a5466e629599c9'),
#  131: ('ecoinvent 3.9.1 cutoff', 'dfad8f9f8095a84b71d5e00bebddf384'),
#  132: ('ecoinvent 3.9.1 cutoff', '50ffca50a31dae2f6868fd8bc2dd953b'),
#  133: ('ecoinvent 3.9.1 cutoff', '312e7ae462650171698b611adc78c081'),
#  134: ('ecoinvent 3.9.1 cutoff', '2938f4ae99a87cb70d1819bf28cb12ed'),
#  135: ('ecoinvent 3.9.1 cutoff', '51f753e02ea8b6aba9276a147d6d4176'),
#  136: ('ecoinvent 3.9.1 cutoff', '7ca1379b2e6c0bd9e6473895c523aa7f'),
#  137: ('ecoinvent 3.9.1 cutoff', '524822e267ee5d3f93ce341dc381662c'),
#  138: ('ecoinvent 3.9.1 cutoff', 'cb82a58d8221f774f2c2ad9ecb88c05c'),
#  139: ('ecoinvent 3.9.1 cutoff', '2625cb63569260f7aa001497c1d2ea1f'),
#  140: ('ecoinvent 3.9.1 cutoff', '0ed38d2018ecfc5d0537a368557666cf'),
#  141: ('ecoinvent 3.9.1 cutoff', '8b26ca9c7072ea527436ce057ba77460'),
#  142: ('ecoinvent 3.9.1 cutoff', '79f3471c292c153e6be97a06d050f6a3'),
#  143: ('ecoinvent 3.9.1 cutoff', '57895b5e87a9d131aa609e296c999279'),
#  144: ('ecoinvent 3.9.1 cutoff', '6d5c3a16244a7e34faf2ae5d7603d541'),
#  145: ('ecoinvent 3.9.1 cutoff', '7ec96866b7bbd1bf82435c112d6eba09'),
#  146: ('ecoinvent 3.9.1 cutoff', '93fbce1ae39ba72dae6fe95a0e3d79c1'),
#  147: ('ecoinvent 3.9.1 cutoff', '5e70709bd71d55c88527de46f7267aff'),
#  148: ('ecoinvent 3.9.1 cutoff', '0390dcd0ef5d7227116c51b72a8450b9'),
#  149: ('ecoinvent 3.9.1 cutoff', '77ba65dd636a98256fa2a61f0e1f7a03'),
#  150: ('ecoinvent 3.9.1 cutoff', '6be14d317eff6e3635ae054bae274149'),
#  151: ('ecoinvent 3.9.1 cutoff', 'a8ebeb7b36223eac48a3cc7860c0e711'),
#  152: ('ecoinvent 3.9.1 cutoff', '4b665eedeb1336efb9cbd5b2e0e32f26'),
#  153: ('ecoinvent 3.9.1 cutoff', '2ca88c77da5eca9727e465f331d378d3'),
#  154: ('ecoinvent 3.9.1 cutoff', 'e50a69cbcb58e48661c9f83f5dc32b75'),
#  155: ('ecoinvent 3.9.1 cutoff', '0883b31178629eb56739e6aaacb17552'),
#  156: ('ecoinvent 3.9.1 cutoff', 'c655f5b0ff84702a0077ad38fdf4f750'),
#  157: ('ecoinvent 3.9.1 cutoff', '7e0ceafa28859257a6d73a29cc988669'),
#  158: ('ecoinvent 3.9.1 cutoff', 'ac17a3d6e017444c41eb5ff3be407877'),
#  159: ('ecoinvent 3.9.1 cutoff', 'eba11f081cf123395ba1d3a570dc05e7'),
#  160: ('ecoinvent 3.9.1 cutoff', '12cfc1956a1f6c987cc3b5e26b47c7e2'),
#  161: ('ecoinvent 3.9.1 cutoff', '9dbcd90f3d15a2e44510dac2b0188248'),
#  162: ('ecoinvent 3.9.1 cutoff', '64094aebc0ce24ae9d57d402f923d688'),
#  163: ('ecoinvent 3.9.1 cutoff', '05f3bcea2adc0750ebeb720a82945eac'),
#  164: ('ecoinvent 3.9.1 cutoff', '2c99899c31fcc6421d5ac8bd05bd49ac'),
#  165: ('ecoinvent 3.9.1 cutoff', 'cfe80dd1883ca8df051887be0fdfa4ec'),
#  166: ('ecoinvent 3.9.1 cutoff', '3417e68b559f959ee49e5512abb50846'),
#  167: ('ecoinvent 3.9.1 cutoff', '18f701852c2e41a79563a6f3bc0a10db'),
#  168: ('ecoinvent 3.9.1 cutoff', 'e2ccfeeafd85f5b53f3e8c4371e736fd'),
#  169: ('ecoinvent 3.9.1 cutoff', 'b163fedb6a3ef23bc8990837e3311205'),
#  170: ('ecoinvent 3.9.1 cutoff', 'c9a05ccaffafadfdfdbf7a9559da5146'),
#  171: ('ecoinvent 3.9.1 cutoff', '77de23bfacdd7ae95555f6177b325828'),
#  172: ('ecoinvent 3.9.1 cutoff', 'd187af32d78706a42158a8ed3e09e714'),
#  173: ('ecoinvent 3.9.1 cutoff', '28d064dafa33526445db5d34e073c09d'),
#  174: ('ecoinvent 3.9.1 cutoff', 'baaddee099ca42fc2a54412557711fb5'),
#  175: ('ecoinvent 3.9.1 cutoff', '11373a42f15363b80251656bfcb1e55e'),
#  176: ('ecoinvent 3.9.1 cutoff', '38ffb774e666ebe27a3a6b51c12c1543'),
#  177: ('ecoinvent 3.9.1 cutoff', 'f7920dc2818621d0ef83320dbe12be8f'),
#  178: ('ecoinvent 3.9.1 cutoff', 'dd22be6a9064fc082552a63f737f8961'),
#  179: ('ecoinvent 3.9.1 cutoff', 'a08017ebd5b5ef15e24d98eaa05407ec'),
#  180: ('ecoinvent 3.9.1 cutoff', 'ee563c293050f0a6f70aac72a0824aa2'),
#  181: ('ecoinvent 3.9.1 cutoff', '54d28d7cfde49e7718bdf0bb474b78c1'),
#  182: ('ecoinvent 3.9.1 cutoff', '962ed20c2efd40a454ec189def4ac79e'),
#  183: ('ecoinvent 3.9.1 cutoff', 'e094d462e01474b7a12a56f342bba06e'),
#  184: ('ecoinvent 3.9.1 cutoff', '0e9578f84cf0e867bb6ef1b096afb371'),
#  185: ('ecoinvent 3.9.1 cutoff', '54f538c893808698cb3a89ae67c76c87'),
#  186: ('ecoinvent 3.9.1 cutoff', '36b73a4f4f1c296287a35d32590a65e5'),
#  187: ('ecoinvent 3.9.1 cutoff', '5468040eda7cb574bb395c6e51431245'),
#  188: ('ecoinvent 3.9.1 cutoff', '5c44e4dd2455d1daba57353e1c7344b2'),
#  189: ('ecoinvent 3.9.1 cutoff', '27f8570534cbb46112ebd1d4aaa84690'),
#  190: ('ecoinvent 3.9.1 cutoff', 'cff38930bb53b5d58a2244f27ef7655f'),
#  191: ('ecoinvent 3.9.1 cutoff', 'cbde931953f536b16e29fd800470a7e6'),
#  192: ('ecoinvent 3.9.1 cutoff', 'c8815db465f194491f8e1fd060aa0547'),
#  193: ('ecoinvent 3.9.1 cutoff', '3e51459f8f48c24ebfea06f0cefd707d'),
#  194: ('ecoinvent 3.9.1 cutoff', 'f68e0471e39ebcb406e21c3de53e8073'),
#  195: ('ecoinvent 3.9.1 cutoff', 'dc5898ac8d0d183f80b0c684def1df48'),
#  196: ('ecoinvent 3.9.1 cutoff', '7d27ef4afcef18410965dfd737f81eff'),
#  197: ('ecoinvent 3.9.1 cutoff', '23b593be9cbe8b3a1799fd14460fb283'),
#  198: ('ecoinvent 3.9.1 cutoff', 'f81617979bdf2cc54df8d2b17e018d90'),
#  199: ('ecoinvent 3.9.1 cutoff', 'df67b3d01b68766ae7d013488def9122'),
#  200: ('ecoinvent 3.9.1 cutoff', '2d112858912f55b7968b712cdb4d3e10'),
#  201: ('ecoinvent 3.9.1 cutoff', 'dca984abc15fc56b0685f7e8c5afdd57'),
#  202: ('ecoinvent 3.9.1 cutoff', 'ca831e355d887298471ebae4424e1bed'),
#  203: ('ecoinvent 3.9.1 cutoff', 'd3717baf390878fc3be0cb47b26698fc'),
#  204: ('ecoinvent 3.9.1 cutoff', '1c959df340af2917f9452d89c3b41198'),
#  205: ('ecoinvent 3.9.1 cutoff', '66af82684be47e04e90292a9ad78e8b4'),
#  206: ('ecoinvent 3.9.1 cutoff', 'f492ec9a9193ef9797e387370d7936d3'),
#  207: ('ecoinvent 3.9.1 cutoff', '2af2adb1cd07508db4c7a8b8ea62f0a8'),
#  208: ('ecoinvent 3.9.1 cutoff', '9c9c2a22b1e3c1745410715cc4a9ddb6'),
#  209: ('ecoinvent 3.9.1 cutoff', '9480616fdc4fc86522b48b630392aafa'),
#  210: ('ecoinvent 3.9.1 cutoff', '87f84c1df68c85a74abb2f5c4a8b7969'),
#  211: ('ecoinvent 3.9.1 cutoff', '483de08155f066ff7cd5650fe191a324'),
#  212: ('ecoinvent 3.9.1 cutoff', '90ac1c25d24832dcdbe1d8fc959e0ed8'),
#  213: ('ecoinvent 3.9.1 cutoff', '10fd11246ec8eb9637db4e2769970c09'),
#  214: ('ecoinvent 3.9.1 cutoff', '0e14636caafdac1a1fc484eab51711fb'),
#  215: ('ecoinvent 3.9.1 cutoff', '53cc28bc1c287564653d6c4c8d2bd807'),
#  216: ('ecoinvent 3.9.1 cutoff', 'f75eaead16f844349af5baa0c42ad45c'),
#  217: ('ecoinvent 3.9.1 cutoff', '27f66a2ee1705a0209fff166f9fd7773'),
#  218: ('ecoinvent 3.9.1 cutoff', '7018ea89ad16f57e164dc6c2b2cbf874'),
#  219: ('ecoinvent 3.9.1 cutoff', '1a6b34f15c89099512f64d6f7c9b58cc'),
#  220: ('ecoinvent 3.9.1 cutoff', '820299a10e55f5de669ef96e39aa6640'),
#  221: ('ecoinvent 3.9.1 cutoff', 'c0e71315da729aa6929274169a68aade'),
#  222: ('ecoinvent 3.9.1 cutoff', '786ca8ab899639c4f49e510dc40acb19'),
#  223: ('ecoinvent 3.9.1 cutoff', 'f6f931e77ca5ce3324e3166edb899fea'),
#  224: ('ecoinvent 3.9.1 cutoff', '83fff5892fa1d8e585bad0d7ccd52019'),
#  225: ('ecoinvent 3.9.1 cutoff', '86156d2c70aef7176e380735fb59009f'),
#  226: ('ecoinvent 3.9.1 cutoff', 'b60263d66ad176c18d900de55f495e72'),
#  227: ('ecoinvent 3.9.1 cutoff', 'fa2a7940f44e9fe7e9334a0281fdeb89'),
#  228: ('ecoinvent 3.9.1 cutoff', '0c8d50be661a3636547780b8ccab411e'),
#  229: ('ecoinvent 3.9.1 cutoff', '8e5511f388e4209a542ffabf89782278'),
#  230: ('ecoinvent 3.9.1 cutoff', '695452840bee2bf2c485c4e41d24f5d5'),
#  231: ('ecoinvent 3.9.1 cutoff', '71e2702de9846975cb3b3b80fc6cf40c'),
#  232: ('ecoinvent 3.9.1 cutoff', 'a9405bb2c3d95909304bea8650558149'),
#  233: ('ecoinvent 3.9.1 cutoff', 'bb75a7d0370f2a4976cc26645be67aa5'),
#  234: ('ecoinvent 3.9.1 cutoff', 'a946db2366efe57fefcec0cfb465bb9b'),
#  235: ('ecoinvent 3.9.1 cutoff', '0b51c9284202e6d4001759da269f33fc'),
#  236: ('ecoinvent 3.9.1 cutoff', 'a9808d05d37d2b520a26a1997e130990'),
#  237: ('ecoinvent 3.9.1 cutoff', 'fba6f073372c62c965ccff9926c7b77b'),
#  238: ('ecoinvent 3.9.1 cutoff', 'c353d990a13bdc9dc429777587509385'),
#  239: ('ecoinvent 3.9.1 cutoff', '6d9bd6fb795e1454edd7391eef708ec1'),
#  240: ('ecoinvent 3.9.1 cutoff', 'a967b1301f1e6c5dcc126ad045d6f66a'),
#  241: ('ecoinvent 3.9.1 cutoff', '8ded522e8da51a1248748a4a57c4d710'),
#  242: ('ecoinvent 3.9.1 cutoff', 'bf585acd91a45979fe0fdfd2616ed600'),
#  243: ('ecoinvent 3.9.1 cutoff', '1ce8f8b2627be095f90532423ddcc1af'),
#  244: ('ecoinvent 3.9.1 cutoff', '93e5f8b902408b6dd66a60ccfba71161'),
#  245: ('ecoinvent 3.9.1 cutoff', '2b0d6d112900d406530d5ec72f995707'),
#  246: ('ecoinvent 3.9.1 cutoff', '3a9513fe64e6ad25a4dd92a09827f816'),
#  247: ('ecoinvent 3.9.1 cutoff', 'd9f19145b24ecce90e8d7825fe90a526'),
#  248: ('ecoinvent 3.9.1 cutoff', 'bd940c7d5668468a171998eb5d8f4e67'),
#  249: ('ecoinvent 3.9.1 cutoff', 'aab52f4b17542439afe0c03f63599d80'),
#  250: ('ecoinvent 3.9.1 cutoff', 'c00bcd051405398c8b155a63543e458c'),
#  251: ('ecoinvent 3.9.1 cutoff', '203592d549e6f31d49059368cae39249'),
#  252: ('ecoinvent 3.9.1 cutoff', '751a4c2c16f860965bf727603ff157d6'),
#  253: ('ecoinvent 3.9.1 cutoff', 'f10bd33eb6618cb469ca7eb46bbfc490'),
#  254: ('ecoinvent 3.9.1 cutoff', '6ab97f628888c7d78addf6ffad5c163d'),
#  255: ('ecoinvent 3.9.1 cutoff', 'aae504943c4b051b40ff9a713c1e10ba'),
#  256: ('ecoinvent 3.9.1 cutoff', 'c409e7c1e3e92d9b97487b4feb7e5599'),
#  257: ('ecoinvent 3.9.1 cutoff', '0cf4e7f79be56af8bdf4dda15e69b40c'),
#  258: ('ecoinvent 3.9.1 cutoff', 'fbbc45c575d6004d4ef2227855b434dd'),
#  259: ('ecoinvent 3.9.1 cutoff', '2a484ad3fb21bbebd8fb7fc24da60985'),
#  260: ('ecoinvent 3.9.1 cutoff', '2d2bdea236a392e2d7dbc6c515609315'),
#  261: ('ecoinvent 3.9.1 cutoff', '59051ad3a68c768006093649dc678a9b'),
#  262: ('ecoinvent 3.9.1 cutoff', '2a47d1f45c6b5a6410f707b7330d442e'),
#  263: ('ecoinvent 3.9.1 cutoff', '0810326f53d2c4315c4c1eee2ba0f8d0'),
#  264: ('ecoinvent 3.9.1 cutoff', 'bb89d4c732d09b5f7791ef85c7872f9d'),
#  265: ('ecoinvent 3.9.1 cutoff', '45ac1e0896998a089f71c0f1ed98c481'),
#  266: ('ecoinvent 3.9.1 cutoff', '9c414ed7878be208370f42df027c8b2c'),
#  267: ('ecoinvent 3.9.1 cutoff', 'e939ebac78a74d3d1eca78c67c149257'),
#  268: ('ecoinvent 3.9.1 cutoff', 'e1dbb445694edaab0389d52f76952924'),
#  269: ('ecoinvent 3.9.1 cutoff', 'f157671637dfd8af61386fd96ddf7664'),
#  270: ('ecoinvent 3.9.1 cutoff', '739b62a416c112e2b66a6454e0ada1b5'),
#  271: ('ecoinvent 3.9.1 cutoff', '4a177b6a75d6da7e56c0df90779a922a'),
#  272: ('ecoinvent 3.9.1 cutoff', '495616378b5d9013197ab093e3181662'),
#  273: ('ecoinvent 3.9.1 cutoff', 'a64a5b1006d28078aa1cf248f37ca370'),
#  274: ('ecoinvent 3.9.1 cutoff', 'd0a3754f1562f76ae0fcb6427a16ee10'),
#  275: ('ecoinvent 3.9.1 cutoff', '40f5b7ea9d34ac39279a6d9905ae4fcd'),
#  276: ('ecoinvent 3.9.1 cutoff', '40a86b02b76779987c5abf2683bebbc4'),
#  277: ('ecoinvent 3.9.1 cutoff', 'a1445ce2d21bdc4c646c1fb530588f27'),
#  278: ('ecoinvent 3.9.1 cutoff', '45575acd2a9ee57a6ac807b6404a482b'),
#  279: ('ecoinvent 3.9.1 cutoff', '1e01f5f1d664bbd8cb890b2e6fe9cfdc'),
#  280: ('ecoinvent 3.9.1 cutoff', '699169f674afe839b1cf231aecdbc605'),
#  281: ('ecoinvent 3.9.1 cutoff', '1ef3d6f378d4054d410391a7398fc999'),
#  282: ('ecoinvent 3.9.1 cutoff', '4d8a62b0c0eb971a53a547cab120b176'),
#  283: ('ecoinvent 3.9.1 cutoff', '84ff7f042d2e2fced6e287ec61a2e31a'),
#  284: ('ecoinvent 3.9.1 cutoff', 'c7b2e1c9a769063e5acc60c53a7ca07a'),
#  285: ('ecoinvent 3.9.1 cutoff', '2048b7bdf86357a3e6079cc6a73bb4f9'),
#  286: ('ecoinvent 3.9.1 cutoff', '0fec8433296703fc003ffda8012a17b8'),
#  287: ('ecoinvent 3.9.1 cutoff', '9b671ec044f9424c65befd65ca0c765c'),
#  288: ('ecoinvent 3.9.1 cutoff', '90c153a158b56d17df0659319f67cdae'),
#  289: ('ecoinvent 3.9.1 cutoff', '9d1abbd31e9fd2b03fc891fed1eb5efc'),
#  290: ('ecoinvent 3.9.1 cutoff', '40e88f6835d6c3c5daa8f48cdb8e87ea'),
#  291: ('ecoinvent 3.9.1 cutoff', 'b2456bb2e61063a1a1adc6016c9c7b95'),
#  292: ('ecoinvent 3.9.1 cutoff', '34786547efdd611d64f63eccc8797326'),
#  293: ('ecoinvent 3.9.1 cutoff', '538fd3825d6b93fd230e3e0bbc9182e4'),
#  294: ('ecoinvent 3.9.1 cutoff', '4714c3bfd09f0c1039847a4c10ba98ec'),
#  295: ('ecoinvent 3.9.1 cutoff', '4951099be4ce8c202174aee9e060433c'),
#  296: ('ecoinvent 3.9.1 cutoff', '838e5534b7a4351570fc6a6558033641'),
#  297: ('ecoinvent 3.9.1 cutoff', 'f7785b548968be5826c408fd205aee92'),
#  298: ('ecoinvent 3.9.1 cutoff', '85a4a472a5f74c78301962ac8f7553d3'),
#  299: ('ecoinvent 3.9.1 cutoff', '3d42075432e4849c7582d0e0f196290c'),
#  300: ('ecoinvent 3.9.1 cutoff', '41170ea11aa84c43c27b1aeddb17528f'),
#  301: ('ecoinvent 3.9.1 cutoff', '5a19be8ebfd722643b6e2cecd9cd20c3'),
#  302: ('ecoinvent 3.9.1 cutoff', '90fbe3a0fed39b61781e7af4f3935a03'),
#  303: ('ecoinvent 3.9.1 cutoff', '72eb95566a79709f25360995ee05a07c'),
#  304: ('ecoinvent 3.9.1 cutoff', '302ab5bea8285e6aa37b5f7c8a816ad8'),
#  305: ('ecoinvent 3.9.1 cutoff', 'd1693041a80bdcda096f9c3587c6f5eb'),
#  306: ('ecoinvent 3.9.1 cutoff', 'fad770dee5c9545d47fff577cc896836'),
#  307: ('ecoinvent 3.9.1 cutoff', '41ba742bcdd2655889f0e732f2064723'),
#  308: ('ecoinvent 3.9.1 cutoff', '0c3b8f61860afff479088808ea1b014a'),
#  309: ('ecoinvent 3.9.1 cutoff', '9e7bad5a4749ff00cc91190825d94aa0'),
#  310: ('ecoinvent 3.9.1 cutoff', '853c5efa830301634ef4f24e0060333c'),
#  311: ('ecoinvent 3.9.1 cutoff', '66b9d2c86836e95212702a8621c42f22'),
#  312: ('ecoinvent 3.9.1 cutoff', '61c59bdc19ab6eefd116f504adcc754b'),
#  313: ('ecoinvent 3.9.1 cutoff', '3eca85ab277c4e62088f3b25d881c6a2'),
#  314: ('ecoinvent 3.9.1 cutoff', 'c17632aee277e137c03daf24c9d8a18a'),
#  315: ('ecoinvent 3.9.1 cutoff', '32df9c5f828b773a9b9e2e7cbc1cc469'),
#  316: ('ecoinvent 3.9.1 cutoff', 'ffb64f016425c23b0922c00e5807ecda'),
#  317: ('ecoinvent 3.9.1 cutoff', '1ebf858bb02e4831d6ddd9db53f54cca'),
#  318: ('ecoinvent 3.9.1 cutoff', 'ff6ebb501a3f6b1eca3fb6ebfac8b793'),
#  319: ('ecoinvent 3.9.1 cutoff', '6d8634428d45ca379953e82b97a3a56e'),
#  320: ('ecoinvent 3.9.1 cutoff', '20c4e961209aaad64b28e5bb48d679a2'),
#  321: ('ecoinvent 3.9.1 cutoff', 'bd45312a77ef5be8b8340cddd8d814c7'),
#  322: ('ecoinvent 3.9.1 cutoff', '4e666879ce6ae88fa1cc2a7e7e7a7533'),
#  323: ('ecoinvent 3.9.1 cutoff', '8c0a99afd9c222f67dd8cf661be0e658'),
#  324: ('ecoinvent 3.9.1 cutoff', 'f40f8355c2887c397395e613197b065f'),
#  325: ('ecoinvent 3.9.1 cutoff', '0ad2735ace3b0d2166e3dd5525088768'),
#  326: ('ecoinvent 3.9.1 cutoff', '28b198bffb1cb8303935303756e4001a'),
#  327: ('ecoinvent 3.9.1 cutoff', '0d5f51645e0a2b69019ea8f0344509cc'),
#  328: ('ecoinvent 3.9.1 cutoff', '3b7a9dbae734127c3a3145a945d3cc3a'),
#  329: ('ecoinvent 3.9.1 cutoff', 'e1cc308f0ec364435bc90c19311046a6'),
#  330: ('ecoinvent 3.9.1 cutoff', '914ee40dfe479760a5883a7962ce50cc'),
#  331: ('ecoinvent 3.9.1 cutoff', 'dd7b9f99e891fc46d4f52beb94245f75'),
#  332: ('ecoinvent 3.9.1 cutoff', '1c5338d9d8660450791fccf2322c1721'),
#  333: ('ecoinvent 3.9.1 cutoff', 'a39fa8035aaf9c8e029a46a344b629e7'),
#  334: ('ecoinvent 3.9.1 cutoff', 'bbcc24a62a7a425e708fa8967f0df2ee'),
#  335: ('ecoinvent 3.9.1 cutoff', 'd0c724bbf3c0cda9ae394557fbcb1a96'),
#  336: ('ecoinvent 3.9.1 cutoff', 'd8296d5323d49042f6730355a861139f'),
#  337: ('ecoinvent 3.9.1 cutoff', 'acf95acf991d2932c76e32509a2bf9b2'),
#  338: ('ecoinvent 3.9.1 cutoff', '99d97aca1efbc7eaaf44a99c3982f5ff'),
#  339: ('ecoinvent 3.9.1 cutoff', '732368a43476509bb333d81d104f67b0'),
#  340: ('ecoinvent 3.9.1 cutoff', '85c4bd2041087082456be0f19fce090b'),
#  341: ('ecoinvent 3.9.1 cutoff', '4f0693ef68120a39f711295a64db098f'),
#  342: ('ecoinvent 3.9.1 cutoff', 'eda5a9889a07fc6759f5e391cd76b24a'),
#  343: ('ecoinvent 3.9.1 cutoff', '9a647fad72b406d28275c585a82a93e6'),
#  344: ('ecoinvent 3.9.1 cutoff', '7549307336f18ef773558a1be5e1329f'),
#  345: ('ecoinvent 3.9.1 cutoff', '4649f0461a43a817181a0eb250f9ce04'),
#  346: ('ecoinvent 3.9.1 cutoff', '699406091375b0a709b82947bd8c1982'),
#  347: ('ecoinvent 3.9.1 cutoff', '08a684cd60d03f17de397396af5289ce'),
#  348: ('ecoinvent 3.9.1 cutoff', 'c8234c88a5e7d4f294f492f01487a351'),
#  349: ('ecoinvent 3.9.1 cutoff', '430c10dda95db2917c3295905bc109fc'),
#  350: ('ecoinvent 3.9.1 cutoff', '49d7a23a1bd2240b7a9eb75e68092047'),
#  351: ('ecoinvent 3.9.1 cutoff', '8c8c82e16d5392e88efdbea56d97b394'),
#  352: ('ecoinvent 3.9.1 cutoff', '4eebcaf9c1f715990605ddfa4f886b72'),
#  353: ('ecoinvent 3.9.1 cutoff', '3f168a0f12526e90ec5061e540326e5c'),
#  354: ('ecoinvent 3.9.1 cutoff', '059ccc54a0e014448afa9a0b0f9af98a'),
#  355: ('ecoinvent 3.9.1 cutoff', '1e6b7f4552249e2add36981101446e25'),
#  356: ('ecoinvent 3.9.1 cutoff', '73645511b70124cd6cecbdea4d66b3fa'),
#  357: ('ecoinvent 3.9.1 cutoff', '23810b0bbe04fca71b0f53fc97d56360'),
#  358: ('ecoinvent 3.9.1 cutoff', '9fb70a8fad616207387b2e316cf5b593'),
#  359: ('ecoinvent 3.9.1 cutoff', '47c24a47dbcd0128a3b3fe1c891db3eb'),
#  360: ('ecoinvent 3.9.1 cutoff', '141d30fee87b8fb379d6f5d179fb8f20'),
#  361: ('ecoinvent 3.9.1 cutoff', '7d8831cba33f207607e7ee4a2b9193d9'),
#  362: ('ecoinvent 3.9.1 cutoff', 'b0369a7a31757d7c2535c7d1d0cc5e33'),
#  363: ('ecoinvent 3.9.1 cutoff', 'c4c81dd3eac790e0f467285a98ca82d4'),
#  364: ('ecoinvent 3.9.1 cutoff', '26c8f644836c9b914b46911ca3b82f6d'),
#  365: ('ecoinvent 3.9.1 cutoff', '75428352cbba91962648fe146bb1c5ac'),
#  366: ('ecoinvent 3.9.1 cutoff', '5af58ee120bccd04fb4053c89ff1c9ea'),
#  367: ('ecoinvent 3.9.1 cutoff', 'd722526f6809661548989302b3482a13'),
#  368: ('ecoinvent 3.9.1 cutoff', '41885dc5b3ce5fe6d74fb7dd8c971e39'),
#  369: ('ecoinvent 3.9.1 cutoff', '79603102b9965446e5b997507af648a9'),
#  370: ('ecoinvent 3.9.1 cutoff', '0c2eab9445adc9efe1eafb7a2a06e1e4'),
#  371: ('ecoinvent 3.9.1 cutoff', '099a8b432861489fa3220d641e035c8c'),
#  372: ('ecoinvent 3.9.1 cutoff', 'efa1d6535ba36d66935f9d419c9db084'),
#  373: ('ecoinvent 3.9.1 cutoff', '76de973096c034312a24dae8f35ad7f7'),
#  374: ('ecoinvent 3.9.1 cutoff', '58c95b186dcd36b51e82c6928378726a'),
#  375: ('ecoinvent 3.9.1 cutoff', '02c1e856918387a63eee82addf807656'),
#  376: ('ecoinvent 3.9.1 cutoff', '2f1d5113530088fa162e8fa0fffb9887'),
#  377: ('ecoinvent 3.9.1 cutoff', 'c54fb832f5a288b04c4fc82f06170f57'),
#  378: ('ecoinvent 3.9.1 cutoff', '085ecbcca04e0bd9078f69ab1365a37f'),
#  379: ('ecoinvent 3.9.1 cutoff', 'e81b517c7792db6696aca932d400a5dd'),
#  380: ('ecoinvent 3.9.1 cutoff', '559939ba79c75435be91c1c425237106'),
#  381: ('ecoinvent 3.9.1 cutoff', 'cfbc05a41ac930e63398c926fe988239'),
#  382: ('ecoinvent 3.9.1 cutoff', '9ef8f7515e54a8f0248bb72b1e30d686'),
#  383: ('ecoinvent 3.9.1 cutoff', 'e0651437589a5561e5856b2aefabcc2e'),
#  384: ('ecoinvent 3.9.1 cutoff', '5d70da4f02121296de86d807529738d1'),
#  385: ('ecoinvent 3.9.1 cutoff', '5367e00a48c6b150866aa31205f61c58'),
#  386: ('ecoinvent 3.9.1 cutoff', '6900041fd2172853d1c023af3d5037ab'),
#  387: ('ecoinvent 3.9.1 cutoff', 'bb83be2001da7a01c9a91e7aa8849303'),
#  388: ('ecoinvent 3.9.1 cutoff', '8096f22c8b5e8d404e7c6a595d6c7314'),
#  389: ('ecoinvent 3.9.1 cutoff', '0a14afef87cd81d8e6185c1bebe95ec8'),
#  390: ('ecoinvent 3.9.1 cutoff', '744ccd13d9807c322687c4a67a341826'),
#  391: ('ecoinvent 3.9.1 cutoff', '82a63d54c0d98c7f7b18428bc781e189'),
#  392: ('ecoinvent 3.9.1 cutoff', '0013eecac5d35ec768cc8e933c69deb8'),
#  393: ('ecoinvent 3.9.1 cutoff', 'ffed19327fa56d006cf5760ccd9e91cd'),
#  394: ('ecoinvent 3.9.1 cutoff', '3a3f3bc4137ae0e3753f1ea59a97168e'),
#  395: ('ecoinvent 3.9.1 cutoff', 'cd3c8d718d5fe2b4a23b3e44983d9e83'),
#  396: ('ecoinvent 3.9.1 cutoff', '493740d4f2eaaa4d9e9302b356e42372'),
#  397: ('ecoinvent 3.9.1 cutoff', '106873f5e1120e4a8f279b989c7bba94'),
#  398: ('ecoinvent 3.9.1 cutoff', 'd36a947a505d74d9dec6eea2d4eb58a7'),
#  399: ('ecoinvent 3.9.1 cutoff', '00018a2608c38f1e5cdf5f6dbec86312'),
#  400: ('ecoinvent 3.9.1 cutoff', '360636def07f1eafd172bb4a5b7aea42'),
#  401: ('ecoinvent 3.9.1 cutoff', 'de76fc5a46ebab99ef2b343608299ac0'),
#  402: ('ecoinvent 3.9.1 cutoff', 'da173c1bdd8c240bdcc77584a9456c8a'),
#  403: ('ecoinvent 3.9.1 cutoff', 'fb9892cc8ae21391015a261efbfd2284'),
#  404: ('ecoinvent 3.9.1 cutoff', '8e99902a7d5a9940fca553f8f9efb813'),
#  405: ('ecoinvent 3.9.1 cutoff', 'f575621104a6653f8b7bc1d12f0f5a71'),
#  406: ('ecoinvent 3.9.1 cutoff', 'e26545f20151e555df08c992c284990a'),
#  407: ('ecoinvent 3.9.1 cutoff', 'f8a7c40945e5532c9c6d45c43e6a5e2e'),
#  408: ('ecoinvent 3.9.1 cutoff', '7e02be7831649502d41249e151d482ca'),
#  409: ('ecoinvent 3.9.1 cutoff', 'f2be200384d3aa64b0c18a53bf5ce3e2'),
#  410: ('ecoinvent 3.9.1 cutoff', '9d1ed41851f7883ee09daea95d4ee864'),
#  411: ('ecoinvent 3.9.1 cutoff', '6175b2df9656437aa94846ae62ad8fcd'),
#  412: ('ecoinvent 3.9.1 cutoff', '07ec8222254949e633412e479a0cebbe'),
#  413: ('ecoinvent 3.9.1 cutoff', 'c5b0e996d2c2c54b9b5e382ad051a3d1'),
#  414: ('ecoinvent 3.9.1 cutoff', '6fd953429014a7b19123f7d132810cf4'),
#  415: ('ecoinvent 3.9.1 cutoff', 'bc745fcb1391eb2b82d16ce4166280f2'),
#  416: ('ecoinvent 3.9.1 cutoff', '0153a1ab7fb39f5bd163721e3bd4a109'),
#  417: ('ecoinvent 3.9.1 cutoff', '1e29d602b77cd8d2d10976cf10622153'),
#  418: ('ecoinvent 3.9.1 cutoff', '310ce99699562ce3584b81df52bf3462'),
#  419: ('ecoinvent 3.9.1 cutoff', '6e670a32788d73e054f8245736c663b1'),
#  420: ('ecoinvent 3.9.1 cutoff', '53f6eabe6b31759e709ac5030271b7f4'),
#  421: ('ecoinvent 3.9.1 cutoff', 'd0d202a5b7708a4b839e9abe3f40da68'),
#  422: ('ecoinvent 3.9.1 cutoff', '1bc36a71fc93670eda192d923ee2bfe3'),
#  423: ('ecoinvent 3.9.1 cutoff', 'e8146e0c6b7efeb3b683449089e1d86a'),
#  424: ('ecoinvent 3.9.1 cutoff', '2e2215f785cc4ed3be85bf025f3ec81b'),
#  425: ('ecoinvent 3.9.1 cutoff', '6fae7898d34cd7a7d2b88d79644c6fdb'),
#  426: ('ecoinvent 3.9.1 cutoff', '747f46bca5870721d535c836cf8c6597'),
#  427: ('ecoinvent 3.9.1 cutoff', '19e5867c5e98a3b3b582d0ece930b8b2'),
#  428: ('ecoinvent 3.9.1 cutoff', '67be994191f5938d9a3ee1c9bd8c3e47'),
#  429: ('ecoinvent 3.9.1 cutoff', '355fa185d5cfb0fbff960b206dabdcd0'),
#  430: ('ecoinvent 3.9.1 cutoff', '2f5b684789b719d9af35f609b06563d4'),
#  431: ('ecoinvent 3.9.1 cutoff', '865c7a20cd8b4684bf48c146f105c5ea'),
#  432: ('ecoinvent 3.9.1 cutoff', '0d4ce52b9f184721b35a07766b68a014'),
#  433: ('ecoinvent 3.9.1 cutoff', 'c578b2b6b24a8fe94e2fabaae27942b9'),
#  434: ('ecoinvent 3.9.1 cutoff', 'ab9fcd99f5f6cd9b8a94b2cefa5d88e4'),
#  435: ('ecoinvent 3.9.1 cutoff', '7b38aee71facb3b5f3724170bbde773d'),
#  436: ('ecoinvent 3.9.1 cutoff', '872198c284fdcdbab2d81e9ed37e5dcd'),
#  437: ('ecoinvent 3.9.1 cutoff', '72b06d70c6d741eb4a4874413694f845'),
#  438: ('ecoinvent 3.9.1 cutoff', '0c16be957f2fbb933192c9fdf810e3f1'),
#  439: ('ecoinvent 3.9.1 cutoff', '61cfb543c0647733c5412dbd33fc5aaa'),
#  440: ('ecoinvent 3.9.1 cutoff', '75da16c809a91760a19f0338ac3388ae'),
#  441: ('ecoinvent 3.9.1 cutoff', '3a6586952eff793738eef72743703e90'),
#  442: ('ecoinvent 3.9.1 cutoff', '47472ca6017b6e8b751d638cec288a0d'),
#  443: ('ecoinvent 3.9.1 cutoff', '5b9110c5a13c9a421d6b87cf8ac7bec9'),
#  444: ('ecoinvent 3.9.1 cutoff', '3603265625a6c6c9702ede0aa7413665'),
#  445: ('ecoinvent 3.9.1 cutoff', '0a76e11c8b34db514631f52b35cc1897'),
#  446: ('ecoinvent 3.9.1 cutoff', '8aa735d42dc54b7baef97d13ea10e1ee'),
#  447: ('ecoinvent 3.9.1 cutoff', 'c34d80499a99d949cb1a38cae5838ee3'),
#  448: ('ecoinvent 3.9.1 cutoff', '8388d8054ea1d79b748fe68ccf9fb4e8'),
#  449: ('ecoinvent 3.9.1 cutoff', '56ac81c10d2adde86edc7f368eb79eaa'),
#  450: ('ecoinvent 3.9.1 cutoff', 'bc2d101dd2a466543296008ce8c342da'),
#  451: ('ecoinvent 3.9.1 cutoff', '1463cc2a4ee4765d5b8a42965cddaa15'),
#  452: ('ecoinvent 3.9.1 cutoff', '6a2493e09fc8c5fc8a5b35680a45e292'),
#  453: ('ecoinvent 3.9.1 cutoff', '33f187d2b8bdb52c593510b899b17759'),
#  454: ('ecoinvent 3.9.1 cutoff', '6f5456984855ca384444d304caf927fb'),
#  455: ('ecoinvent 3.9.1 cutoff', '303ceb4a91057559fed5cb1c3bf29149'),
#  456: ('ecoinvent 3.9.1 cutoff', '0a5950353e4cb6f6ad44bb7a455ba465'),
#  457: ('ecoinvent 3.9.1 cutoff', 'b32d59c3168bbbb0167fe0bd290bc8df'),
#  458: ('ecoinvent 3.9.1 cutoff', '838512bcecf14f99e1aa18b9f297ca3b'),
#  459: ('ecoinvent 3.9.1 cutoff', 'fff5b57441f64ef02ea869803a212120'),
#  460: ('ecoinvent 3.9.1 cutoff', 'e6c57edbd8456bbec31bf522604cc3d6'),
#  461: ('ecoinvent 3.9.1 cutoff', 'cb6beec3a04776ff98bbf28e1dc467a9'),
#  462: ('ecoinvent 3.9.1 cutoff', '15f475a53c59ef4224074301545d86ab'),
#  463: ('ecoinvent 3.9.1 cutoff', 'b38e0559c59b1be2c2fc66ebe65d56e6'),
#  464: ('ecoinvent 3.9.1 cutoff', 'dfd8dafa15514464a61eb5b968e6ba86'),
#  465: ('ecoinvent 3.9.1 cutoff', 'f70a903a7f5aadac01850fd27b17544a'),
#  466: ('ecoinvent 3.9.1 cutoff', '0cd40ef57970224bbf6d57d073596b75'),
#  467: ('ecoinvent 3.9.1 cutoff', '8d9cf1a79ce97f23da17746d4f3fbe7c'),
#  468: ('ecoinvent 3.9.1 cutoff', 'aa56c62c46a0dae412bc13b83fd4d524'),
#  469: ('ecoinvent 3.9.1 cutoff', 'fd61d919330074150bb28d9f97360994'),
#  470: ('ecoinvent 3.9.1 cutoff', '9a5d8b504b687999106456a802f9075e'),
#  471: ('ecoinvent 3.9.1 cutoff', 'c570966d606a8902ac73ff101305beef'),
#  472: ('ecoinvent 3.9.1 cutoff', 'dc67083d9d6fdddf50f6a82ec53fb805'),
#  473: ('ecoinvent 3.9.1 cutoff', 'f66d4cb858737451800d73c56b0b96aa'),
#  474: ('ecoinvent 3.9.1 cutoff', 'd255ac2e9418e2854e1f8d4f4c2b4180'),
#  475: ('ecoinvent 3.9.1 cutoff', '78ea189e63477241c3e13c9b501bb24d'),
#  476: ('ecoinvent 3.9.1 cutoff', '911bd1f9214e55a3edf6844c7c81df19'),
#  477: ('ecoinvent 3.9.1 cutoff', 'eab8ab3cefe550330ff413a73e2867db'),
#  478: ('ecoinvent 3.9.1 cutoff', 'a2e398ef5a0b5b883aba6f0513e3c5bb'),
#  479: ('ecoinvent 3.9.1 cutoff', '9177b177d7a52078622d255d0d6c7b49'),
#  480: ('ecoinvent 3.9.1 cutoff', 'f2a73f75d4e28be479d66de37f2d79cd'),
#  481: ('ecoinvent 3.9.1 cutoff', 'a18ffd81dbcaa17ad104189f6019eeae'),
#  482: ('ecoinvent 3.9.1 cutoff', '1fa519a80419ec64cf19a371c2078202'),
#  483: ('ecoinvent 3.9.1 cutoff', 'c29509574498ed98c26af747f65665df'),
#  484: ('ecoinvent 3.9.1 cutoff', '31188a004efe458b84b1c39d6644f042'),
#  485: ('ecoinvent 3.9.1 cutoff', '870a2c52aec6235e38893b83473c5c14'),
#  486: ('ecoinvent 3.9.1 cutoff', '42c314295fcead0dafef17c4346c45d8'),
#  487: ('ecoinvent 3.9.1 cutoff', '827f242c77bccd7c899e7376bfd1f8b7'),
#  488: ('ecoinvent 3.9.1 cutoff', 'bab51cbc5c22ac6f6b1c37acf74856a7'),
#  489: ('ecoinvent 3.9.1 cutoff', '9cc71803f2d887617f8a731028fece0f'),
#  490: ('ecoinvent 3.9.1 cutoff', '1caf7675422a5b52fe6e9bfb82ac11e3'),
#  491: ('ecoinvent 3.9.1 cutoff', '72931a7046660c97257548aa1bfd6565'),
#  492: ('ecoinvent 3.9.1 cutoff', '1fb0f5436cb75b53df069caed28a09cd'),
#  493: ('ecoinvent 3.9.1 cutoff', 'c3ee5d4c3ec111c911591c61f522f88e'),
#  494: ('ecoinvent 3.9.1 cutoff', '473055804622e48cc4f306c362c36925'),
#  495: ('ecoinvent 3.9.1 cutoff', '1f03d3641c97fa1d246e3a0a93adb4e6'),
#  496: ('ecoinvent 3.9.1 cutoff', '7828a943e134cb66b04a9e8c71bab201'),
#  497: ('ecoinvent 3.9.1 cutoff', 'c3cb481399ac70af7d59816f0457df64'),
#  498: ('ecoinvent 3.9.1 cutoff', '9c491ca9e45cd95b2edd74f4b3386f9c'),
#  499: ('ecoinvent 3.9.1 cutoff', '2256961bda47b6359456db4c7dca8553'),
#  500: ('ecoinvent 3.9.1 cutoff', 'e97fa8b32c22a155d672e4d6a7058c6a'),
#  501: ('ecoinvent 3.9.1 cutoff', '53ba8f9e43d897b596246e4b4820adcf'),
#  502: ('ecoinvent 3.9.1 cutoff', 'e67c5898587e40420bf9b075dc610e25'),
#  503: ('ecoinvent 3.9.1 cutoff', '68cd54a33dc9b8a0cc8fa627816ce53a'),
#  504: ('ecoinvent 3.9.1 cutoff', '5efd4061851b2bd322f17830fee57dff'),
#  505: ('ecoinvent 3.9.1 cutoff', '280c26a529ecb0c0b6ad2ed1f6984cc3'),
#  506: ('ecoinvent 3.9.1 cutoff', '555da7deacd3ca82bcdb406bd7795f81'),
#  507: ('ecoinvent 3.9.1 cutoff', 'a5dff97d0e9fb37553e2aad762e7fa2e'),
#  508: ('ecoinvent 3.9.1 cutoff', '2eb618b2c0347ae4551b8e563589b569'),
#  509: ('ecoinvent 3.9.1 cutoff', '57e0e55f7829c06e8671b4282612b2aa'),
#  510: ('ecoinvent 3.9.1 cutoff', 'c156a7876538483bea13171cfef6f1d9'),
#  511: ('ecoinvent 3.9.1 cutoff', '24a7ed95a6fd3f4678e7a02e26c05c91'),
#  512: ('ecoinvent 3.9.1 cutoff', 'a2836c2d7dac8ababf9ba207164e0e4a'),
#  513: ('ecoinvent 3.9.1 cutoff', '6c46eb2d0d3f48ad0d916f7969ad940c'),
#  514: ('ecoinvent 3.9.1 cutoff', '30d6ec17ba464490cf266b0f36c9e594'),
#  515: ('ecoinvent 3.9.1 cutoff', 'e4be524775d99609fc4ecc031cb39e16'),
#  516: ('ecoinvent 3.9.1 cutoff', '924596707cdaae0682742d3f4d8d205d'),
#  517: ('ecoinvent 3.9.1 cutoff', 'a4e506f2c34146b021f25f0460ebebf4'),
#  518: ('ecoinvent 3.9.1 cutoff', '7656777bec4271f2d78c3c4e581a2dc3'),
#  519: ('ecoinvent 3.9.1 cutoff', '49e550d28bda969c98f1080c036da524'),
#  520: ('ecoinvent 3.9.1 cutoff', '743576f3c8254142997bd3c159b7fd54'),
#  521: ('ecoinvent 3.9.1 cutoff', '913c5d119499fc8c91f5402469ea592e'),
#  522: ('ecoinvent 3.9.1 cutoff', 'a004ca7193090d7952f08e4264531b12'),
#  523: ('ecoinvent 3.9.1 cutoff', '5ac188d87a9117b371dfec1226d83838'),
#  524: ('ecoinvent 3.9.1 cutoff', 'a8fb091c6660c414d157d9438e4e00c1'),
#  525: ('ecoinvent 3.9.1 cutoff', '8fea69d0824110bc9d745996b1155041'),
#  526: ('ecoinvent 3.9.1 cutoff', '10584bcddb60ec95f2753916ed3ce83e'),
#  527: ('ecoinvent 3.9.1 cutoff', '44eb57ada5499566c962f58879647275'),
#  528: ('ecoinvent 3.9.1 cutoff', 'bb953ac821a28fe944cad0d4670af299'),
#  529: ('ecoinvent 3.9.1 cutoff', '55889c730b60394168e079603427e5c1'),
#  530: ('ecoinvent 3.9.1 cutoff', '8e0588a762abc8adefe9f05150b37c6b'),
#  531: ('ecoinvent 3.9.1 cutoff', 'ac5a5541841dd4c02cd5275f84c0ed98'),
#  532: ('ecoinvent 3.9.1 cutoff', '9ad5b05cbab4abd22c8e623ce779a0e0'),
#  533: ('ecoinvent 3.9.1 cutoff', 'a03d33eca4e2670632bc88178ed80146'),
#  534: ('ecoinvent 3.9.1 cutoff', 'f61ebd8209f18f7826779e51299cdef2'),
#  535: ('ecoinvent 3.9.1 cutoff', '475eed409ce96bfbb2b092215d5a12c8'),
#  536: ('ecoinvent 3.9.1 cutoff', '58de3387c1413bb191f1411afae02efb'),
#  537: ('ecoinvent 3.9.1 cutoff', '37a5b08b3e13bf76c8a1f23bd3a81230'),
#  538: ('ecoinvent 3.9.1 cutoff', '98d0b5bcb97f3f98730e03c132eb0d67'),
#  539: ('ecoinvent 3.9.1 cutoff', 'ba3860e14f90855c019df7c7cf043db6'),
#  540: ('ecoinvent 3.9.1 cutoff', '6c217855b836ba886ebcb20c105ad088'),
#  541: ('ecoinvent 3.9.1 cutoff', '867a871552e767ed52e8aaf4a138465f'),
#  542: ('ecoinvent 3.9.1 cutoff', '346568a8600f79d06541e100ddab5fe1'),
#  543: ('ecoinvent 3.9.1 cutoff', '902cecec60e7845317ee1b942d377f3f'),
#  544: ('ecoinvent 3.9.1 cutoff', '43c9af565c8378e9c3499181c43cd77b'),
#  545: ('ecoinvent 3.9.1 cutoff', '3da85b95610e6968c4a0a874549fbef8'),
#  546: ('ecoinvent 3.9.1 cutoff', '419243ae593d779ce102a6cde5f99de0'),
#  547: ('ecoinvent 3.9.1 cutoff', 'e0c5fc1a4904141bc139699b19f23bf1'),
#  548: ('ecoinvent 3.9.1 cutoff', '87783ade347640aba3b1d2c588d4ce77'),
#  549: ('ecoinvent 3.9.1 cutoff', 'a4d6322a775771b4eeed3e6bed5686fe'),
#  550: ('ecoinvent 3.9.1 cutoff', 'a5f5352ae8d8e7f4d38d56ea98852371'),
#  551: ('ecoinvent 3.9.1 cutoff', 'f3099fd9853592d671d2590f8a37f3fc'),
#  552: ('ecoinvent 3.9.1 cutoff', '475dbe44b357641147047cd7a66f6c03'),
#  553: ('ecoinvent 3.9.1 cutoff', '679467b3588782aff94f749f3bd4a084'),
#  554: ('ecoinvent 3.9.1 cutoff', 'e0dee162f5617a7540fbd4b319b843ef'),
#  555: ('ecoinvent 3.9.1 cutoff', '410625dd1e4de1f71562af36aede6b55'),
#  556: ('ecoinvent 3.9.1 cutoff', '3dd23b78d0f180d24081d7be6fb44499'),
#  557: ('ecoinvent 3.9.1 cutoff', '2b50bbbb43e3849538945675b7d006f9'),
#  558: ('ecoinvent 3.9.1 cutoff', 'be33116d9801dd9e6a161a7f97be15c4'),
#  559: ('ecoinvent 3.9.1 cutoff', 'c9a0ae0dbad4a15b39cc1de4541ad23a'),
#  560: ('ecoinvent 3.9.1 cutoff', '7198f5ff54c1b3161104853b0916ed74'),
#  561: ('ecoinvent 3.9.1 cutoff', '3fef6f14b2705f886a04763532941215'),
#  562: ('ecoinvent 3.9.1 cutoff', '9e822103697b49ed85c7c056c95d9a43'),
#  563: ('ecoinvent 3.9.1 cutoff', '26b7b36c99c358c65adb728020192066'),
#  564: ('ecoinvent 3.9.1 cutoff', 'c117325648bd95c66aa5d15eed8fe33c'),
#  565: ('ecoinvent 3.9.1 cutoff', '50ad49f522df462405f927a3a2e12000'),
#  566: ('ecoinvent 3.9.1 cutoff', '81284e6ffa4fe0221fa1fbec0f0d23a9'),
#  567: ('ecoinvent 3.9.1 cutoff', 'b4cf9bef49c25e06bf9ccfba45c7d955'),
#  568: ('ecoinvent 3.9.1 cutoff', '9328809152594d47c3f5a98422744b64'),
#  569: ('ecoinvent 3.9.1 cutoff', '5c488bb51ae5192064bac821d2360e28'),
#  570: ('ecoinvent 3.9.1 cutoff', '173b6065c70b230c1f422c69e222ca7b'),
#  571: ('ecoinvent 3.9.1 cutoff', '43ab4e514c101536a77210171cd24d19'),
#  572: ('ecoinvent 3.9.1 cutoff', '1a3d7b9381157cdda1d1a1026dbbe83e'),
#  573: ('ecoinvent 3.9.1 cutoff', 'b517fcdbd866b9d6e0dea5201810cbca'),
#  574: ('ecoinvent 3.9.1 cutoff', 'ea03c88f279f972cf40f0783212534eb'),
#  575: ('ecoinvent 3.9.1 cutoff', '0515b27bc2b759a3a98bf3f1422725a8'),
#  576: ('ecoinvent 3.9.1 cutoff', '7d4d5d299ec3c7d5c0153c0f25a4e399'),
#  577: ('ecoinvent 3.9.1 cutoff', 'dd6864cb8b450c5d4c743c91b760a8e1'),
#  578: ('ecoinvent 3.9.1 cutoff', '28a8b2ae814e8706d99ead9ba8f1b12f'),
#  579: ('ecoinvent 3.9.1 cutoff', '4e80275f003a47f2a6ed5799f5bf0ba2'),
#  580: ('ecoinvent 3.9.1 cutoff', 'fe3ce61b18cbf79a501cc4c80a9e3bc5'),
#  581: ('ecoinvent 3.9.1 cutoff', 'ce35451dc8dbb1c8b072260a111bdaa7'),
#  582: ('ecoinvent 3.9.1 cutoff', '0128f1307254111f13c164789b5d8a8f'),
#  583: ('ecoinvent 3.9.1 cutoff', '5263f69b7939ac473e695ab9e5c61c8f'),
#  584: ('ecoinvent 3.9.1 cutoff', '958b97179ce5f619cb2227a2cb4db020'),
#  585: ('ecoinvent 3.9.1 cutoff', 'ce4fd53de338d437079a03f92b6486ec'),
#  586: ('ecoinvent 3.9.1 cutoff', 'f3ea83eb92a29982043f5092c3896233'),
#  587: ('ecoinvent 3.9.1 cutoff', 'a0dfb4fe5e906bf383a08f2efc667b51'),
#  588: ('ecoinvent 3.9.1 cutoff', '633715e7d3eae06361eef95af8fa9445'),
#  589: ('ecoinvent 3.9.1 cutoff', '4698fc41f0c66e84fd453a7206568bd0'),
#  590: ('ecoinvent 3.9.1 cutoff', 'e5a36c4fa92df93d0a0864042de4ba89'),
#  591: ('ecoinvent 3.9.1 cutoff', '11214fd665f836f1cc9a57f282ba7df4'),
#  592: ('ecoinvent 3.9.1 cutoff', 'eebd3fad4b5782760466a510d2e654b5'),
#  593: ('ecoinvent 3.9.1 cutoff', 'cd22160e4adfaed7dc359b6268210311'),
#  594: ('ecoinvent 3.9.1 cutoff', 'f4f9607a95e7a6168cd1f0544b156d91'),
#  595: ('ecoinvent 3.9.1 cutoff', '9684a0a2fd1209422ff4c917633eacba'),
#  596: ('ecoinvent 3.9.1 cutoff', 'fbab3177434d78b701a6182d3407868a'),
#  597: ('ecoinvent 3.9.1 cutoff', 'bf16f06c1340c2ffc65b4f99b7210f85'),
#  598: ('ecoinvent 3.9.1 cutoff', '31e581ff13eac8f9e6c2c206eace810b'),
#  599: ('ecoinvent 3.9.1 cutoff', '67447ddfb9076a17cb2c5845fcabb9fd'),
#  600: ('ecoinvent 3.9.1 cutoff', '1a5654b42884d8d190670e5b6d6a2b74'),
#  601: ('ecoinvent 3.9.1 cutoff', 'a8c8faaf1b2f17ee9777f6ad0caa60cb'),
#  602: ('ecoinvent 3.9.1 cutoff', 'adc6bbccf3d5b2955b050510e647852a'),
#  603: ('ecoinvent 3.9.1 cutoff', '8b123363da970e3d854cdc986a83c75a'),
#  604: ('ecoinvent 3.9.1 cutoff', '90669c776b1818c3f113f0f1464390ed'),
#  605: ('ecoinvent 3.9.1 cutoff', '14cef19bdae1d765494c60b83267703e'),
#  606: ('ecoinvent 3.9.1 cutoff', '479b10df06e621a85d96fc67aca4e161'),
#  607: ('ecoinvent 3.9.1 cutoff', 'cfe458937a2d61f41220ba3fd59e8f7a'),
#  608: ('ecoinvent 3.9.1 cutoff', 'cc4351bd84820a90ea1da2509bb40d8a'),
#  609: ('ecoinvent 3.9.1 cutoff', '0bd3b02787dd4dae7081387aaade8222'),
#  610: ('ecoinvent 3.9.1 cutoff', 'be3fcedb3af7dccd6321a0a9825f05fd'),
#  611: ('ecoinvent 3.9.1 cutoff', 'db85f784a886f8048dbd27ae7ae1d076'),
#  612: ('ecoinvent 3.9.1 cutoff', '71e371ed63c6010084214ff385aa84bb'),
#  613: ('ecoinvent 3.9.1 cutoff', '878d9c2141693adcb5340045b77d3e05'),
#  614: ('ecoinvent 3.9.1 cutoff', '6c4ed20b68db442724ab40ac031e48cb'),
#  615: ('ecoinvent 3.9.1 cutoff', '06020ac5974bd7a09ea0b4ecdd667179'),
#  616: ('ecoinvent 3.9.1 cutoff', '952c17489a705401d756376719d6b8ed'),
#  617: ('ecoinvent 3.9.1 cutoff', 'efd4c0ffb98fbe1b6b8f48ae48197727'),
#  618: ('ecoinvent 3.9.1 cutoff', '74f2cacce53f906d8b8e18498ec408e6'),
#  619: ('ecoinvent 3.9.1 cutoff', 'cb1df0a8ab0977367fea18d4ad1b8ea9'),
#  620: ('ecoinvent 3.9.1 cutoff', '0224df1ef0381d72d37029497b2e1ca7'),
#  621: ('ecoinvent 3.9.1 cutoff', '051cf998e54d2bb976c547b7cd8e8604'),
#  622: ('ecoinvent 3.9.1 cutoff', '9740ae0d393463221360bee2975eef2c'),
#  623: ('ecoinvent 3.9.1 cutoff', '1bc863a377c63072694d33d69f9fd94f'),
#  624: ('ecoinvent 3.9.1 cutoff', '95cd863061414d4fdbf55c2811d45e17'),
#  625: ('ecoinvent 3.9.1 cutoff', '44a81751c3fe47ab996227401eabd040'),
#  626: ('ecoinvent 3.9.1 cutoff', '56d1e925b1744ccb1c801047f2728b6d'),
#  627: ('ecoinvent 3.9.1 cutoff', 'ac3ad0ae0cea00a36e5eb22070163ce1'),
#  628: ('ecoinvent 3.9.1 cutoff', '77a4e7769692eab7d0d0e55f1c425034'),
#  629: ('ecoinvent 3.9.1 cutoff', '34dd0410ae388e0643d20c97045e63d6'),
#  630: ('ecoinvent 3.9.1 cutoff', 'a3e904506ae579dd6e186eb7294dd2c4'),
#  631: ('ecoinvent 3.9.1 cutoff', 'cbd789f0b6d687a49b3a86a4c2954c83'),
#  632: ('ecoinvent 3.9.1 cutoff', 'abab94332c86322e9a9aee5a5f946057'),
#  633: ('ecoinvent 3.9.1 cutoff', 'ede0ad49c4b28a0998e58a8db4f62a66'),
#  634: ('ecoinvent 3.9.1 cutoff', 'ca911493e543cafee939a65118dafc4c'),
#  635: ('ecoinvent 3.9.1 cutoff', '0df5349be94959344c9c3b8262036b17'),
#  636: ('ecoinvent 3.9.1 cutoff', '0cfadf0ecdbae67e7f4a0f1a5b1d173e'),
#  637: ('ecoinvent 3.9.1 cutoff', '55e8298fad7e612acfb4bc99478d95c2'),
#  638: ('ecoinvent 3.9.1 cutoff', '5eaaa29a44cabd875e848b24e7f0cc40'),
#  639: ('ecoinvent 3.9.1 cutoff', 'ffe6a2e9373cea9aa682ac6ef56ee3c0'),
#  640: ('ecoinvent 3.9.1 cutoff', '77c2e8abdd3a011be36f474a205129e1'),
#  641: ('ecoinvent 3.9.1 cutoff', 'eaa04a47f3430fe07d301f6cd0b3128d'),
#  642: ('ecoinvent 3.9.1 cutoff', '8fbd7c9e0ceda7f69cb2dbaffca87175'),
#  643: ('ecoinvent 3.9.1 cutoff', 'a92a31d4d055865e1b3049e926effb9c'),
#  644: ('ecoinvent 3.9.1 cutoff', '42dd4659d51b658c85a628b12e1efbe3'),
#  645: ('ecoinvent 3.9.1 cutoff', 'a8d353a6d0138951953406cdd1c62469'),
#  646: ('ecoinvent 3.9.1 cutoff', '15b8ecb1ac0eb0984d6ee5781811c0b0'),
#  647: ('ecoinvent 3.9.1 cutoff', 'f70b7f71d607f8186f9e8e3833fc2a95'),
#  648: ('ecoinvent 3.9.1 cutoff', '126650b1365bf02b3a1081d958ef9733'),
#  649: ('ecoinvent 3.9.1 cutoff', '935f63eb0945e49cd3e50d69497447ab'),
#  650: ('ecoinvent 3.9.1 cutoff', '79e5fdfb7d39ce052524203a4a513cce'),
#  651: ('ecoinvent 3.9.1 cutoff', '23234034409f549ce64cab10e015c3bf'),
#  652: ('ecoinvent 3.9.1 cutoff', 'dc91d3ec6e7e22b7bc81a5b3a94db6ec'),
#  653: ('ecoinvent 3.9.1 cutoff', '401e178fb277d985eac1be6d0eb7b81a'),
#  654: ('ecoinvent 3.9.1 cutoff', 'b8d1b7c749539212d21d200503642de8'),
#  655: ('ecoinvent 3.9.1 cutoff', '6334589ce00d44d325a82e4a9a0ec8aa'),
#  656: ('ecoinvent 3.9.1 cutoff', '96d78033cfbf4f9302725904b0878198'),
#  657: ('ecoinvent 3.9.1 cutoff', 'd3664899c24ea7d80235f62afc3a91d6'),
#  658: ('ecoinvent 3.9.1 cutoff', '2ccf582fae11f961a8fed21d6d4a6ff2'),
#  659: ('ecoinvent 3.9.1 cutoff', 'b64aac4bf4e1e5f744f404facb1d0763'),
#  660: ('ecoinvent 3.9.1 cutoff', '492bc562567c44952ccfd3f031c1e433'),
#  661: ('ecoinvent 3.9.1 cutoff', '97a551a848949d12e1cb06a953d66025'),
#  662: ('ecoinvent 3.9.1 cutoff', 'dfc74b8073499cd3435aeb6d5cc60801'),
#  663: ('ecoinvent 3.9.1 cutoff', 'df5f90d8cfc3a6589f89f0c806ac3af6'),
#  664: ('ecoinvent 3.9.1 cutoff', 'bb921a940bb03a00081a51043579b7de'),
#  665: ('ecoinvent 3.9.1 cutoff', '4e0a12c2d96c333c5f4e8094db3f8c17'),
#  666: ('ecoinvent 3.9.1 cutoff', '18277df8a10170108ac21b60acb13c16'),
#  667: ('ecoinvent 3.9.1 cutoff', '81a9ffea9d65721b7e60c2edf98dc6db'),
#  668: ('ecoinvent 3.9.1 cutoff', '4b5c91c6fff2bd2072e6a29f84085e4b'),
#  669: ('ecoinvent 3.9.1 cutoff', 'cf2080991aa160259cd24bc8bd819f50'),
#  670: ('ecoinvent 3.9.1 cutoff', 'c3b054c970a5c96d14da244a200829ee'),
#  671: ('ecoinvent 3.9.1 cutoff', 'c5119ecef56bd19a9e9c4d6121659cc9'),
#  672: ('ecoinvent 3.9.1 cutoff', 'ff7400512ba12f010951c9d33ec1d34f'),
#  673: ('ecoinvent 3.9.1 cutoff', '4eb19b85e98c980588e40d31347f512e'),
#  674: ('ecoinvent 3.9.1 cutoff', '3a5b4a948eea974a6a18b1e615ca4002'),
#  675: ('ecoinvent 3.9.1 cutoff', '586aec0414247e42cfffff8f48e04ab9'),
#  676: ('ecoinvent 3.9.1 cutoff', '89690ad03452b115d95aee8657246880'),
#  677: ('ecoinvent 3.9.1 cutoff', 'b7e80540edceeec98aa24816d696e2b5'),
#  678: ('ecoinvent 3.9.1 cutoff', 'b2e4547eee413d90ff335015f047cc48'),
#  679: ('ecoinvent 3.9.1 cutoff', '1373b63314d03c42313a372bca1bd648'),
#  680: ('ecoinvent 3.9.1 cutoff', 'a073f3ac8414e343af72dc562401ed98'),
#  681: ('ecoinvent 3.9.1 cutoff', '1bb0afe88c73e144ef02fa79095a7761'),
#  682: ('ecoinvent 3.9.1 cutoff', '774a8b458a0b5fb8ea869f5a2c9d8e58'),
#  683: ('ecoinvent 3.9.1 cutoff', 'b1a2f6c1a4c751547a11f65165071c62'),
#  684: ('ecoinvent 3.9.1 cutoff', '942cfb405cfda264f6423fcbe5b26b77'),
#  685: ('ecoinvent 3.9.1 cutoff', '02c274ac6f63462abbadba8f93015e9b'),
#  686: ('ecoinvent 3.9.1 cutoff', 'dcd443b459a65526855154b643f43e8f'),
# ...
#  772: ('ecoinvent 3.9.1 cutoff', '4240acf9b1ac3b50a94a141fb9e1ec1b'),
#  773: ('ecoinvent 3.9.1 cutoff', '022970e79aa7a703fcc12ab084e7ca00'),
#  774: ('ecoinvent 3.9.1 cutoff', '3fc90040083e0b3e89272c523511d17a'),
#  775: ('ecoinvent 3.9.1 cutoff', '970d8f8909acf2ac8b4923d8c9112949'),
#  776: ('ecoinvent 3.9.1 cutoff', 'e9204e86216df579a37963cd6183422a'),
#  777: ('ecoinvent 3.9.1 cutoff', 'a7415d01dd3906477e8b987c47c71e2c'),
#  778: ('ecoinvent 3.9.1 cutoff', 'a25c7c13721c4efdcf8712c1ebaba0ab'),
#  779: ('ecoinvent 3.9.1 cutoff', 'a9506bf8dc77d95ff2a0b35bbfdd144e'),
#  780: ('ecoinvent 3.9.1 cutoff', 'a71311350cde020b1cdbeeaf46189bb5'),
#  781: ('ecoinvent 3.9.1 cutoff', '52cb90121d0057b995246adf8e65af85'),
#  782: ('ecoinvent 3.9.1 cutoff', '19c0f0a59f270b946f8c74353b4915c7'),
#  783: ('ecoinvent 3.9.1 cutoff', '6930ede21609d7bab82fa1a9ce18fee7'),
#  784: ('ecoinvent 3.9.1 cutoff', 'a9423ef7ef538f3d58f9f93b5e1c46ae'),
#  785: ('ecoinvent 3.9.1 cutoff', 'aade32fb136966b2cb8344637d6f8b91'),
#  786: ('ecoinvent 3.9.1 cutoff', '70092ed4981c01849e5f88535a2ce228'),
#  787: ('ecoinvent 3.9.1 cutoff', '8746aba9854bfb5d12c1b55af893f744'),
#  788: ('ecoinvent 3.9.1 cutoff', '3c9fd326e30ac411e8300432e7812839'),
#  789: ('ecoinvent 3.9.1 cutoff', 'd855ee92bbf715d2d497c475469e2b95'),
#  790: ('ecoinvent 3.9.1 cutoff', '0b23bf5c153f34c00f631604d135eea9'),
#  791: ('ecoinvent 3.9.1 cutoff', '0453e7806400149ec8fe799ca7c95059'),
#  792: ('ecoinvent 3.9.1 cutoff', 'fd547c07109e2993b15e651895c011c6'),
#  793: ('ecoinvent 3.9.1 cutoff', '72087fa796618602cdf57fb15281b7cc'),
#  794: ('ecoinvent 3.9.1 cutoff', '2b0ebf51700ba8f7806d954dfe9c6e88'),
#  795: ('ecoinvent 3.9.1 cutoff', 'e81689e3157e165b5d5c9e0d31d72712'),
#  796: ('ecoinvent 3.9.1 cutoff', '21cd1306ec308a156bfb7aae2e7e0fff'),
#  797: ('ecoinvent 3.9.1 cutoff', 'c771a791c451bdd925a79a7e53049044'),
#  798: ('ecoinvent 3.9.1 cutoff', '770e335015df7c3bb7c2327d9e78bf21'),
#  799: ('ecoinvent 3.9.1 cutoff', 'df0fb123969159779ed72520d59a746e'),
#  800: ('ecoinvent 3.9.1 cutoff', 'e9e86902994b5231cea624ceec96b2d6'),
#  801: ('ecoinvent 3.9.1 cutoff', 'b4e86a1a12374dc15d5dc3c5da023a8e'),
#  802: ('ecoinvent 3.9.1 cutoff', '725e88d72f7afd5777fa4f94ca0d71cb'),
#  803: ('ecoinvent 3.9.1 cutoff', '06472e4df0613445bb026542ae6e334f'),
#  804: ('ecoinvent 3.9.1 cutoff', '6482d208f1bc601f8f94a4da2df7aef1'),
#  805: ('ecoinvent 3.9.1 cutoff', 'dba289213c21c57f69545fb7d53ae62b'),
#  806: ('ecoinvent 3.9.1 cutoff', '55ad07f8f06a331d8a234a2e564f43be'),
#  807: ('ecoinvent 3.9.1 cutoff', 'c2da04479af6f089181a94c6e4cda05d'),
#  808: ('ecoinvent 3.9.1 cutoff', '74ef75bcb4332e7da92b0c1f1d6f8a2e'),
#  809: ('ecoinvent 3.9.1 cutoff', '286880eb46e21377c7a0a4ea11b60590'),
#  810: ('ecoinvent 3.9.1 cutoff', '30c9df47b304646e9fb9770f96f058c4'),
#  811: ('ecoinvent 3.9.1 cutoff', '73e1b4ce1572de4b35551919d32f86b1'),
#  812: ('ecoinvent 3.9.1 cutoff', '1cdf1035076bd0f8da77cd69ba2ff602'),
#  813: ('ecoinvent 3.9.1 cutoff', '2cd4563848298f6b484f98073b8cd277'),
#  814: ('ecoinvent 3.9.1 cutoff', '95be048ea36fd3152fe1038de19e3dfc'),
#  815: ('ecoinvent 3.9.1 cutoff', 'ed610c7ba52c5540af304514004789f0'),
#  816: ('ecoinvent 3.9.1 cutoff', 'e178b3944435bcabc0a57867078e5285'),
#  817: ('ecoinvent 3.9.1 cutoff', 'c9f5e18f5dc885c8a6af95207ab86b09'),
#  818: ('ecoinvent 3.9.1 cutoff', 'fcfbc7a1053e57faab0e6515c9b9740d'),
#  819: ('ecoinvent 3.9.1 cutoff', 'a083b1377b2de0fc2834f8c0003f043f'),
#  820: ('ecoinvent 3.9.1 cutoff', '640d6867119f23ac15a8977d7dc2aa31'),
#  821: ('ecoinvent 3.9.1 cutoff', '8aeef01cbd7b431a112c1dcac104facd'),
#  822: ('ecoinvent 3.9.1 cutoff', '7f7abb966decf3487a6da1a91d11c55c'),
#  823: ('ecoinvent 3.9.1 cutoff', 'ff135d17573f3907b7e227584b146cae'),
#  824: ('ecoinvent 3.9.1 cutoff', 'b0add456b086bb6572dc5ab6b09e90bd'),
#  825: ('ecoinvent 3.9.1 cutoff', '31a0a5b3bc51146cd42843b098fa7efa'),
#  826: ('ecoinvent 3.9.1 cutoff', '32bafc46ffdbaa06f6ca84e815fdf1be'),
#  827: ('ecoinvent 3.9.1 cutoff', '1d22f6f161ae2bc91253e39ba705139c'),
#  828: ('ecoinvent 3.9.1 cutoff', 'ebfa07cc2809192c992a3ef10433bec4'),
#  829: ('ecoinvent 3.9.1 cutoff', 'ac52682bf304cb839c5c0cdcca0ec106'),
#  830: ('ecoinvent 3.9.1 cutoff', 'de57494a3a38210ddb843fb7a473d00f'),
#  831: ('ecoinvent 3.9.1 cutoff', 'eb33948c1111c74c8599b98f34c43ac6'),
#  832: ('ecoinvent 3.9.1 cutoff', '5969d12c72e038c0c6d7cba5687ab4ce'),
#  833: ('ecoinvent 3.9.1 cutoff', '7153aabc8f0b32675e49ebfac9305891'),
#  834: ('ecoinvent 3.9.1 cutoff', '0da27900c297a7047d58e1276f28e8c9'),
#  835: ('ecoinvent 3.9.1 cutoff', '9b1ed23d79cef9afabba07ec1dd4dbcb'),
#  836: ('ecoinvent 3.9.1 cutoff', '0889f5b4a45ed54c2a8f76eeab45a541'),
#  837: ('ecoinvent 3.9.1 cutoff', '332b08ae55f82bc8af3367ada48e4b8d'),
#  838: ('ecoinvent 3.9.1 cutoff', 'cc0027eb9554116012ed741c77693b95'),
#  839: ('ecoinvent 3.9.1 cutoff', '3a4bb4b0b56fa5cc9d1b6cd6cc0791f8'),
#  840: ('ecoinvent 3.9.1 cutoff', 'b89ca68cfb31e46fe7335666ebe6568a'),
#  841: ('ecoinvent 3.9.1 cutoff', '0c98592089f562e632c1d782a26a3d33'),
#  842: ('ecoinvent 3.9.1 cutoff', 'df3b7846473e9ff389b966887b405960'),
#  843: ('ecoinvent 3.9.1 cutoff', '22d9da9ebb6b31522f5a10bee1000555'),
#  844: ('ecoinvent 3.9.1 cutoff', 'dbc2dae24e9d2ed3809c00af4c26c93f'),
#  845: ('ecoinvent 3.9.1 cutoff', '00f412d1aedba7bf45ac8e166f38c6f5'),
#  846: ('ecoinvent 3.9.1 cutoff', 'c16dcffc37a27b5c02dee528e97c03e8'),
#  847: ('ecoinvent 3.9.1 cutoff', '1a12f919afd6d3e3d662ea7481cbe47e'),
#  848: ('ecoinvent 3.9.1 cutoff', '34be8d3f3678f372f7e97fa3b2254aa0'),
#  849: ('ecoinvent 3.9.1 cutoff', '4415d92b393bcf09bb357c3d9919b594'),
#  850: ('ecoinvent 3.9.1 cutoff', 'f6a649b400b6c49bdf9e465997262e4e'),
#  851: ('ecoinvent 3.9.1 cutoff', 'badd44eeee579c96eafa116bcc3d442d'),
#  852: ('ecoinvent 3.9.1 cutoff', '2e4be222f87f3bc10a72adfde5dadf12'),
#  853: ('ecoinvent 3.9.1 cutoff', 'fdfe684de3b8f5990a710aa0dc503daf'),
#  854: ('ecoinvent 3.9.1 cutoff', 'e01f270d8d7c3b9db3939fc0cc27b05b'),
#  855: ('ecoinvent 3.9.1 cutoff', '156bb62d6d54f22dbdcb7135d6d98d9c'),
#  856: ('ecoinvent 3.9.1 cutoff', '0c11de06c0bb75c5e3b0d96f0982e5cf'),
#  857: ('ecoinvent 3.9.1 cutoff', 'e465b77983c7d363283812adaa7bb249'),
#  858: ('ecoinvent 3.9.1 cutoff', '9dce5800695416824e4c653ca72bf3bf'),
#  859: ('ecoinvent 3.9.1 cutoff', '04adfb2f30539b8f7d0e4d0ad3f7d5b6'),
#  860: ('ecoinvent 3.9.1 cutoff', 'db75249799d25a057d5fd09899c9e722'),
#  861: ('ecoinvent 3.9.1 cutoff', 'f2d4d5a6e36a509956508d418c537945'),
#  862: ('ecoinvent 3.9.1 cutoff', '0d619914505277425fad74ef455684b2'),
#  863: ('ecoinvent 3.9.1 cutoff', 'a5d63f34b86d85d55a4af951a0010bde'),
#  864: ('ecoinvent 3.9.1 cutoff', '7a8d07103fc62e17254af4c6e49ca007'),
#  865: ('ecoinvent 3.9.1 cutoff', 'f79691893130beefe04d8f00482ff568'),
#  866: ('ecoinvent 3.9.1 cutoff', 'e5aaa18b109ac8a69a1ee2e33e630648'),
#  867: ('ecoinvent 3.9.1 cutoff', '3f797041a2b9e296322084b716dca9fa'),
#  868: ('ecoinvent 3.9.1 cutoff', '51a3e4e52cff1f98c1e9bb4195f029e2'),
#  869: ('ecoinvent 3.9.1 cutoff', '41f29a942fddb1dc75a05b2cdd03effe'),
#  870: ('ecoinvent 3.9.1 cutoff', 'b35f7214b7d746f7a0f3317b6775d0c0'),
#  871: ('ecoinvent 3.9.1 cutoff', '01db3171b28379d4168e3cb68de4b8e9'),
#  872: ('ecoinvent 3.9.1 cutoff', 'ae90714e13c711de2afb9f4e0ca815df'),
#  873: ('ecoinvent 3.9.1 cutoff', 'ac2f8e03003b0c2125bbe8296924190a'),
#  874: ('ecoinvent 3.9.1 cutoff', '02af7804c2ae6374a2cca968a3d09884'),
#  875: ('ecoinvent 3.9.1 cutoff', '98d38f6114359f968b2634e57c9f8a74'),
#  876: ('ecoinvent 3.9.1 cutoff', '4983da0d78421ab80dea56f92f999f13'),
#  877: ('ecoinvent 3.9.1 cutoff', 'ee3dd49679efb8d5af65b2ae13508d80'),
#  878: ('ecoinvent 3.9.1 cutoff', 'c0fd068c34f97a24ea4deb40632c616e'),
#  879: ('ecoinvent 3.9.1 cutoff', '5dc11bfa4bf1247f83847e5dae499c87'),
#  880: ('ecoinvent 3.9.1 cutoff', 'd4ebeee2483aead92b485bf333aaf1d9'),
#  881: ('ecoinvent 3.9.1 cutoff', '0e04995be1052c07824d26a52855138c'),
#  882: ('ecoinvent 3.9.1 cutoff', '9528b41a7d625f47d571bbff3be269e9'),
#  883: ('ecoinvent 3.9.1 cutoff', '9524c1c6403e6ba9c103062d3289c38a'),
#  884: ('ecoinvent 3.9.1 cutoff', 'dd199cee6575fc366c9ef7347c62657e'),
#  885: ('ecoinvent 3.9.1 cutoff', '71c6a54cc81bc9dedb1dc5db59321e3c'),
#  886: ('ecoinvent 3.9.1 cutoff', '6761db2e5f3efc9fbb8beb65323fe337'),
#  887: ('ecoinvent 3.9.1 cutoff', 'b8cd32578507b1695875d85cdcea5d3c'),
#  888: ('ecoinvent 3.9.1 cutoff', '9816838836977733d75f120de28f41e0'),
#  889: ('ecoinvent 3.9.1 cutoff', 'b589ab190e4b2020f28cb481116a9e9b'),
#  890: ('ecoinvent 3.9.1 cutoff', '2ff1ba5838e739018d0398b1f149c8a9'),
#  891: ('ecoinvent 3.9.1 cutoff', 'd0ebe4d3aec3eec7b8052b8cfc7ab083'),
#  892: ('ecoinvent 3.9.1 cutoff', 'adbc7d5cc2833d31ed0a221b4baca54c'),
#  893: ('ecoinvent 3.9.1 cutoff', '66b2b24dc19fcdb67d14b63891e3684e'),
#  894: ('ecoinvent 3.9.1 cutoff', '74731344fc6317e18d7083f1153c4d08'),
#  895: ('ecoinvent 3.9.1 cutoff', '4ba5853c8a7737d16a8401029a6486fb'),
#  896: ('ecoinvent 3.9.1 cutoff', '318e5792fc2c672c47a9d9391ab60d03'),
#  897: ('ecoinvent 3.9.1 cutoff', '1b8cbe73a21ba46c2e03297a996d2e7a'),
#  898: ('ecoinvent 3.9.1 cutoff', 'fd3ccc1990eb4e583a1785a2a8721ff4'),
#  899: ('ecoinvent 3.9.1 cutoff', '15075b46cb5ae4be19c483771187b44a'),
#  900: ('ecoinvent 3.9.1 cutoff', '076f157d3912ee401ae16c508fd857a7'),
#  901: ('ecoinvent 3.9.1 cutoff', 'e147db75c03f6efd791965ccb23d0b82'),
#  902: ('ecoinvent 3.9.1 cutoff', '15bba3a28d6de8850be98710b31273c0'),
#  903: ('ecoinvent 3.9.1 cutoff', 'b227b3f1c6bf37bf51e29654dd56ceee'),
#  904: ('ecoinvent 3.9.1 cutoff', '312ec3471055cdf44c829b272e834ac3'),
#  905: ('ecoinvent 3.9.1 cutoff', '80310b5021efcb8abcf6d15a9f5ce58e'),
#  906: ('ecoinvent 3.9.1 cutoff', 'eb0aca5052709420b75502b213aa0782'),
#  907: ('ecoinvent 3.9.1 cutoff', '732173184aebbc20eb17bc917db04080'),
#  908: ('ecoinvent 3.9.1 cutoff', '5f1acf3cc6ec24a42de3577404dcf039'),
#  909: ('ecoinvent 3.9.1 cutoff', 'ce3472b50ff7694ffd712f8757d1941d'),
#  910: ('ecoinvent 3.9.1 cutoff', 'c876d293cc1f5727cc0e2a700491dc57'),
#  911: ('ecoinvent 3.9.1 cutoff', '7fc11b59dcfdc4618763b6ccd71141ad'),
#  912: ('ecoinvent 3.9.1 cutoff', 'e1d69fa2818715197eab972c386850a5'),
#  913: ('ecoinvent 3.9.1 cutoff', 'd63010667a9f06c70b58375103d84097'),
#  914: ('ecoinvent 3.9.1 cutoff', '0499fa4e688990715acdaa77ef6fc3d4'),
#  915: ('ecoinvent 3.9.1 cutoff', '43299c17d7c0921388443e77525611ae'),
#  916: ('ecoinvent 3.9.1 cutoff', '236cf556395f97a454e9a4db9fb24957'),
#  917: ('ecoinvent 3.9.1 cutoff', '6aef5bff19eb1ed760fd60562aab8f29'),
#  918: ('ecoinvent 3.9.1 cutoff', 'cce4f7785bf55f7eb7ff7507e8d5c9d0'),
#  919: ('ecoinvent 3.9.1 cutoff', '12e6b948cc3e5703595d3c7e4caa0ec7'),
#  920: ('ecoinvent 3.9.1 cutoff', 'ebfa06d269890c1d1e9f2814b91ba146'),
#  921: ('ecoinvent 3.9.1 cutoff', '849a75a0ebb405870c063957ce212536'),
#  922: ('ecoinvent 3.9.1 cutoff', '2ae0c455043d5588b1b36c3ae5b056a0'),
#  923: ('ecoinvent 3.9.1 cutoff', 'd21fc29e41fd86b71567b7d93cdeff22'),
#  924: ('ecoinvent 3.9.1 cutoff', 'a065436368cfc96b077dc3da3f311f42'),
#  925: ('ecoinvent 3.9.1 cutoff', 'd50e1d8c625becd15d212f857b796828'),
#  926: ('ecoinvent 3.9.1 cutoff', '0f805466b2058f8bdafaee328b6984ce'),
#  927: ('ecoinvent 3.9.1 cutoff', '7f5d8f54b362eff0507a61f49e21eb65'),
#  928: ('ecoinvent 3.9.1 cutoff', '6cd89faa138a9fa1bd0b0f3e71fb602e'),
#  929: ('ecoinvent 3.9.1 cutoff', '3c32969b9b437e38177bc1d684384b7e'),
#  930: ('ecoinvent 3.9.1 cutoff', 'd7d8a3ba8c2f8e187909780f3a25517a'),
#  931: ('ecoinvent 3.9.1 cutoff', '3c5d95051f58f78cc140b11daeaabc59'),
#  932: ('ecoinvent 3.9.1 cutoff', 'c7bbbc05a6f6e9443d41734fa8787d27'),
#  933: ('ecoinvent 3.9.1 cutoff', '45c01ae50ef01486e3d972600700c885'),
#  934: ('ecoinvent 3.9.1 cutoff', 'd7e5c81108b7112febd148185e2490d0'),
#  935: ('ecoinvent 3.9.1 cutoff', '1ebc79deef136be992b37ded2b775399'),
#  936: ('ecoinvent 3.9.1 cutoff', 'bc93b0934f8cb69f077096d59db51511'),
#  937: ('ecoinvent 3.9.1 cutoff', '7fce902798cbbec1471cfe1b114fe906'),
#  938: ('ecoinvent 3.9.1 cutoff', '4c983749f7a504d6596167ffd2c35f75'),
#  939: ('ecoinvent 3.9.1 cutoff', '953165bb6a4c36e4e5bad6c59ad418b1'),
#  940: ('ecoinvent 3.9.1 cutoff', '0623a034627252756f6f223affe3f62b'),
#  941: ('ecoinvent 3.9.1 cutoff', '2feaec82aabebe06588d6d60959e5bb9'),
#  942: ('ecoinvent 3.9.1 cutoff', '4cf59d8f42046329f3c3db828e0393d2'),
#  943: ('ecoinvent 3.9.1 cutoff', 'bf9df4068344cdb51abb3e3154bda16c'),
#  944: ('ecoinvent 3.9.1 cutoff', '79f116aba4f57181cae6a4f97aa9e746'),
#  945: ('ecoinvent 3.9.1 cutoff', '3bf4ca48b84f3161c9aa29abb39d70cb'),
#  946: ('ecoinvent 3.9.1 cutoff', '165ac73fb2bdcd52aa2d2db3d2baaff7'),
#  947: ('ecoinvent 3.9.1 cutoff', 'ef52f7ff6322d7c110d2ebdd99eb7dd6'),
#  948: ('ecoinvent 3.9.1 cutoff', '63b3f3ed34463f671530dd0826b1bbb7'),
#  949: ('ecoinvent 3.9.1 cutoff', 'e92ea41a693c3a5284166f273b1d62f2'),
#  950: ('ecoinvent 3.9.1 cutoff', '642db87a420548a65505fab4e6c2ac12'),
#  951: ('ecoinvent 3.9.1 cutoff', '5c7213132a80b7fffd7727d6292fd2dd'),
#  952: ('ecoinvent 3.9.1 cutoff', '20ea43c84cebc2f7a31282c3dc0d2c9e'),
#  953: ('ecoinvent 3.9.1 cutoff', 'e73087e282f26de5d3a9fec2edc19e61'),
#  954: ('ecoinvent 3.9.1 cutoff', '5a235904c937a2195e1d6f93f35a4fba'),
#  955: ('ecoinvent 3.9.1 cutoff', 'e38e7a502235b0f56fc369746c816087'),
#  956: ('ecoinvent 3.9.1 cutoff', '944f4d6357140424a2ed2bc5b8a2c60f'),
#  957: ('ecoinvent 3.9.1 cutoff', '7c94299585fd4bd7fcb3671c36cd1618'),
#  958: ('ecoinvent 3.9.1 cutoff', '721ae79285226621f79832bab54b5aa3'),
#  959: ('ecoinvent 3.9.1 cutoff', '1f1f015f0eb5df5375839a532dfd2be2'),
#  960: ('ecoinvent 3.9.1 cutoff', '86f9b7a0b2e8b9958ce98da1bdb6534d'),
#  961: ('ecoinvent 3.9.1 cutoff', '9e30ea99559439a35ecddf5c5f2702b2'),
#  962: ('ecoinvent 3.9.1 cutoff', 'f16a8f1243e9009bf5da56630850a408'),
#  963: ('ecoinvent 3.9.1 cutoff', '8a8f5bc7c85fd4671ea527fab19621d8'),
#  964: ('ecoinvent 3.9.1 cutoff', 'feed384f74dd9c7bb7ec1bde7ee8ea17'),
#  965: ('ecoinvent 3.9.1 cutoff', '64a69b19fb8f9195a4ecb9a345bbe890'),
#  966: ('ecoinvent 3.9.1 cutoff', 'a8e38c246d88c9f2aff00eed34addb92'),
#  967: ('ecoinvent 3.9.1 cutoff', 'c02e8dd8466b0fa7d15e14a1eea8ca1b'),
#  968: ('ecoinvent 3.9.1 cutoff', '4b436201bb90eec23bd63002694988bf'),
#  969: ('ecoinvent 3.9.1 cutoff', 'e0ac4d31b158f812d8f730be432f7298'),
#  970: ('ecoinvent 3.9.1 cutoff', '7e997067d3ffeee07c338a11b8ca995b'),
#  971: ('ecoinvent 3.9.1 cutoff', '34b75ad92d172a88fd9efd7ed3c2ac6e'),
#  972: ('ecoinvent 3.9.1 cutoff', '09d373b36620a6c816284ade70acfa7d'),
#  973: ('ecoinvent 3.9.1 cutoff', 'a0e1f30f070427855f1242dd7197a11f'),
#  974: ('ecoinvent 3.9.1 cutoff', '5242fe46aff85436624348dde36999c7'),
#  975: ('ecoinvent 3.9.1 cutoff', '5d39ac23af7a21282fdf5bdac27480b2'),
#  976: ('ecoinvent 3.9.1 cutoff', '4e82a1f2c6e56513bb1bf2ae41d288ea'),
#  977: ('ecoinvent 3.9.1 cutoff', '689776646d7863d0932b2622bff8021f'),
#  978: ('ecoinvent 3.9.1 cutoff', '243d4a82943e188af9b29de344d83727'),
#  979: ('ecoinvent 3.9.1 cutoff', '3b3205f5785dd3887a8571a00c204ee0'),
#  980: ('ecoinvent 3.9.1 cutoff', 'cca2039abd7def9ed78fb33ce61c5d98'),
#  981: ('ecoinvent 3.9.1 cutoff', 'fd9419bc14e077ca33133be02728da0a'),
#  982: ('ecoinvent 3.9.1 cutoff', '5c48bd226e6ff64e3c147cff0d031b9a'),
#  983: ('ecoinvent 3.9.1 cutoff', 'cbd465406f945a34a876d6dd59a0feb1'),
#  984: ('ecoinvent 3.9.1 cutoff', '6223a7c6df557e70d51ba02015f12747'),
#  985: ('ecoinvent 3.9.1 cutoff', '2a3f6abf50827c5e5bbcfd239e2a7b64'),
#  986: ('ecoinvent 3.9.1 cutoff', '0d24f83959f5aaa0868fd6c2f7a81f16'),
#  987: ('ecoinvent 3.9.1 cutoff', '8bdcea421dbf8e54737ecff76e13e7fb'),
#  988: ('ecoinvent 3.9.1 cutoff', 'c193d0f882a1a5d38ed38dbad8484e37'),
#  989: ('ecoinvent 3.9.1 cutoff', '7911eadc945b3209644f7ddb2d80255f'),
#  990: ('ecoinvent 3.9.1 cutoff', '9cc61af3911ec13a7241f68694028083'),
#  991: ('ecoinvent 3.9.1 cutoff', 'c45081be533e001567594f1e2d42a216'),
#  992: ('ecoinvent 3.9.1 cutoff', '299b810b14af97d9d88dcc4e29169ce9'),
#  993: ('ecoinvent 3.9.1 cutoff', '1f69f64549a9bd8f86273831bb116360'),
#  994: ('ecoinvent 3.9.1 cutoff', '6203b16fef3134c1d0f01f552cf0bc04'),
#  995: ('ecoinvent 3.9.1 cutoff', '19365a29b7532004ce3674c4d98ff640'),
#  996: ('ecoinvent 3.9.1 cutoff', 'fa44db4ba7382e34423482718aabfea3'),
#  997: ('ecoinvent 3.9.1 cutoff', 'c331767827b5d9d56eb7ad98dc9b7063'),
#  998: ('ecoinvent 3.9.1 cutoff', 'fe14a325f410d6fd9b54e9a747e809f7'),
#  999: ('ecoinvent 3.9.1 cutoff', '80ba18ac209fcf0d3c68da2fa7cd9363'),
#  ...}

# %%
for x, f in enumerate(lca.biosphere_matrix.sum(axis=1)):
    print(x, f[0])
# Out:
# 0 [[0.01006901]]
# 1 [[0.00027231]]
# 2 [[0.00020911]]
# 3 [[0.00272545]]
# 4 [[0.00162764]]
# 5 [[0.00024168]]
# 6 [[0.00341045]]
# 7 [[0.0033492]]
# 8 [[0.00550001]]
# 9 [[0.49204292]]
# 10 [[0.0028502]]
# 11 [[0.02148005]]
# 12 [[4.10219654e-05]]
# 13 [[1.16570998e-11]]
# 14 [[0.00094576]]
# 15 [[0.05246912]]
# 16 [[7.78473343e-06]]
# 17 [[0.04962279]]
# 18 [[0.00139536]]
# 19 [[0.30004903]]
# 20 [[0.00380236]]
# 21 [[1.84414826e-05]]
# 22 [[0.00176296]]
# 23 [[0.00161923]]
# 24 [[0.00101908]]
# 25 [[0.0044262]]
# 26 [[6.21483786e-05]]
# 27 [[0.02382166]]
# 28 [[2.92230628e-05]]
# 29 [[4.50408273e-07]]
# 30 [[8.34426505]]
# 31 [[0.0024303]]
# 32 [[0.50531978]]
# 33 [[0.00103158]]
# 34 [[0.00836183]]
# 35 [[0.00018314]]
# 36 [[2.47882603e-05]]
# 37 [[0.278078]]
# 38 [[0.00016941]]
# 39 [[4.24165367e-07]]
# 40 [[0.00060194]]
# 41 [[0.00675674]]
# 42 [[9.22922218e-07]]
# 43 [[0.00313704]]
# 44 [[0.10897468]]
# 45 [[2.21063557]]
# 46 [[1.89599776e-07]]
# 47 [[3.74573967e-06]]
# 48 [[0.00347742]]
# 49 [[0.00635573]]
# 50 [[5.29866722e-06]]
# 51 [[0.24074345]]
# 52 [[0.00797644]]
# 53 [[2.15569873e-08]]
# 54 [[5.32818052e-08]]
# 55 [[3.20414368e-05]]
# 56 [[1.27171394e-06]]
# 57 [[1.0626324e-05]]
# 58 [[1.61444138e-05]]
# 59 [[1.70752517e-06]]
# 60 [[4.52662351]]
# 61 [[0.0008272]]
# 62 [[4.48102989e-07]]
# 63 [[0.00224444]]
# 64 [[0.00319081]]
# 65 [[0.0048531]]
# 66 [[0.00030498]]
# 67 [[4.69330824e-07]]
# 68 [[4.64052131e-05]]
# 69 [[0.00087559]]
# 70 [[0.01925968]]
# 71 [[0.00381544]]
# 72 [[0.00018328]]
# 73 [[8.2769691e-05]]
# 74 [[2179.51226953]]
# 75 [[0.40749829]]
# 76 [[0.02615864]]
# 77 [[1.92658939e-05]]
# 78 [[0.00114796]]
# 79 [[0.00073632]]
# 80 [[0.00043358]]
# 81 [[0.67591196]]
# 82 [[1828.64103787]]
# 83 [[90515.56886687]]
# 84 [[7116.00702708]]
# 85 [[0.00390769]]
# 86 [[2.99294135]]
# 87 [[16.04770961]]
# 88 [[23330.26660563]]
# 89 [[0.01016342]]
# 90 [[5.96041947e-05]]
# 91 [[0.00986155]]
# 92 [[0.00098122]]
# 93 [[1.01275478]]
# 94 [[0.00063858]]
# 95 [[0.01961057]]
# 96 [[0.0243211]]
# 97 [[0.00271137]]
# 98 [[0.00075367]]
# 99 [[0.00527172]]
# 100 [[4.72202638e-07]]
# 101 [[8.91973397e-05]]
# 102 [[0.00067257]]
# 103 [[5.66326848e-06]]
# 104 [[0.00185981]]
# 105 [[1.11176318]]
# 106 [[5.4595445e-07]]
# 107 [[4.21999773]]
# 108 [[5592.47818314]]
# 109 [[0.01062269]]
# 110 [[2.01539408e-05]]
# 111 [[0.00012661]]
# 112 [[1.39610231e-05]]
# 113 [[2.31282581e-06]]
# 114 [[1.95655074e-07]]
# 115 [[55.39027692]]
# 116 [[270.43152938]]
# 117 [[0.00019896]]
# 118 [[9.11250284]]
# 119 [[0.16411082]]
# 120 [[0.00152548]]
# 121 [[0.00944763]]
# 122 [[0.00061722]]
# 123 [[0.00371586]]
# 124 [[0.00018823]]
# 125 [[4.12644749e-05]]
# 126 [[0.00071399]]
# 127 [[0.00327483]]
# 128 [[0.00051893]]
# 129 [[0.00039256]]
# 130 [[1.27736446e-05]]
# 131 [[0.02040003]]
# 132 [[7.69987077e-05]]
# 133 [[3.61502318e-05]]
# 134 [[0.00025664]]
# 135 [[0.00014495]]
# 136 [[3.86866707e-05]]
# 137 [[0.00019929]]
# 138 [[0.00507118]]
# 139 [[0.92679967]]
# 140 [[0.00302125]]
# 141 [[0.00012626]]
# 142 [[0.00012564]]
# 143 [[1.59170786e-06]]
# 144 [[0.00016497]]
# 145 [[6.78368838e-05]]
# 146 [[0.00130793]]
# 147 [[4.94014973e-05]]
# 148 [[0.00077398]]
# 149 [[0.00529346]]
# 150 [[5.73968236e-08]]
# 151 [[0.00228256]]
# 152 [[9.10806206e-05]]
# 153 [[0.08517357]]
# 154 [[4.50408285e-06]]
# 155 [[0.00085128]]
# 156 [[3.42341344]]
# 157 [[2.77840977]]
# 158 [[0.00042858]]
# 159 [[8.07170046e-06]]
# 160 [[0.00042142]]
# 161 [[6.06063003e-07]]
# 162 [[0.00130655]]
# 163 [[0.00203565]]
# 164 [[1.73468754]]
# 165 [[0.32170512]]
# 166 [[0.01112356]]
# 167 [[0.11973318]]
# 168 [[14.06696778]]
# 169 [[38.03936461]]
# 170 [[0.00565924]]
# 171 [[0.00060161]]
# 172 [[0.00036246]]
# 173 [[0.0040596]]
# 174 [[8.76266915e-06]]
# 175 [[0.28127413]]
# 176 [[0.00320052]]
# 177 [[0.00265403]]
# 178 [[0.00346962]]
# 179 [[0.0001662]]
# 180 [[0.01463134]]
# 181 [[0.00134525]]
# 182 [[0.0015388]]
# 183 [[1.92125115e-06]]
# 184 [[7.43903385e-07]]
# 185 [[5.92708773e-06]]
# 186 [[4.69959666e-05]]
# 187 [[0.00013008]]
# 188 [[0.00048882]]
# 189 [[1.51625098e-06]]
# 190 [[0.00026151]]
# 191 [[4.03202718e-07]]
# 192 [[0.0001622]]
# 193 [[0.00028915]]
# 194 [[2.95122917e-08]]
# 195 [[4.3599879e-05]]
# 196 [[2.03490672e-05]]
# 197 [[3.06244116e-06]]
# 198 [[0.00025045]]
# 199 [[0.00351373]]
# 200 [[6.27783954e-08]]
# 201 [[1.02365217e-06]]
# 202 [[2.90864468e-05]]
# 203 [[0.00022587]]
# 204 [[5.89012828e-06]]
# 205 [[1.72414911e-06]]
# 206 [[0.00025266]]
# 207 [[2.77880326e-07]]
# 208 [[0.33679195]]
# 209 [[0.00049802]]
# 210 [[0.0008949]]
# 211 [[0.00166699]]
# 212 [[0.05415805]]
# 213 [[8.02988992]]
# 214 [[181.76627361]]
# 215 [[91.99169762]]
# 216 [[1.98957401e-05]]
# 217 [[8361.84727694]]
# 218 [[0.03816]]
# 219 [[0.04700383]]
# 220 [[0.00049668]]
# 221 [[0.07062396]]
# 222 [[0.22541989]]
# 223 [[0.09910445]]
# 224 [[0.19790025]]
# 225 [[0.00937304]]
# 226 [[0.0333226]]
# 227 [[8.95802743e-09]]
# 228 [[0.64241064]]
# 229 [[0.61760509]]
# 230 [[0.00101532]]
# 231 [[0.02872628]]
# 232 [[8.50971796e-05]]
# 233 [[3.70509667e-08]]
# 234 [[4.41663985e-05]]
# 235 [[6.82434804e-08]]
# 236 [[3.91736446e-08]]
# 237 [[0.00020137]]
# 238 [[0.09187488]]
# 239 [[0.01026841]]
# 240 [[0.0018021]]
# 241 [[0.00135551]]
# 242 [[2.47802962e-05]]
# 243 [[2.21943225e-05]]
# 244 [[12.62406403]]
# 245 [[0.00039099]]
# 246 [[4.76456444e-09]]
# 247 [[6.15570057e-05]]
# 248 [[0.02697947]]
# 249 [[0.05423663]]
# 250 [[0.00153394]]
# 251 [[0.02618342]]
# 252 [[0.00040903]]
# 253 [[9.58438045e-06]]
# 254 [[2.23125177e-07]]
# 255 [[0.01765733]]
# 256 [[0.0014343]]
# 257 [[0.00025475]]
# 258 [[3.69386094e-05]]
# 259 [[0.00018531]]
# 260 [[2.43628893e-05]]
# 261 [[2.13605968e-06]]
# 262 [[4.06258036e-05]]
# 263 [[0.16106135]]
# 264 [[2.1063095e-07]]
# 265 [[8.84810264e-05]]
# 266 [[4.69059909e-05]]
# 267 [[0.03108808]]
# 268 [[0.00118322]]
# 269 [[0.00032213]]
# 270 [[4.21233582]]
# 271 [[0.00156979]]
# 272 [[0.00058976]]
# 273 [[1.76616949e-05]]
# 274 [[0.00065681]]
# 275 [[1.94000124e-06]]
# 276 [[0.0094677]]
# 277 [[0.00236084]]
# 278 [[0.01703593]]
# 279 [[2.20013597e-05]]
# 280 [[3.37721228]]
# 281 [[0.37109279]]
# 282 [[0.00212489]]
# 283 [[0.0014858]]
# 284 [[0.03461969]]
# 285 [[0.00700418]]
# 286 [[0.00062373]]
# 287 [[0.07625312]]
# 288 [[3.23648385e-06]]
# 289 [[0.00063393]]
# 290 [[0.00083678]]
# 291 [[0.00153482]]
# 292 [[0.00028496]]
# 293 [[0.00520674]]
# 294 [[0.27394974]]
# 295 [[0.00528002]]
# 296 [[0.00042923]]
# 297 [[1.2377718e-07]]
# 298 [[0.00019823]]
# 299 [[3.42737453e-05]]
# 300 [[0.00031901]]
# 301 [[0.02783777]]
# 302 [[8.49499993e-05]]
# 303 [[3.85967922e-05]]
# 304 [[0.02694517]]
# 305 [[0.01005895]]
# 306 [[0.00063249]]
# 307 [[0.00295319]]
# 308 [[2.65123669e-05]]
# 309 [[0.00510601]]
# 310 [[0.00149468]]
# 311 [[0.00565154]]
# 312 [[8.76949994e-06]]
# 313 [[0.04488438]]
# 314 [[12.16271245]]
# 315 [[5.74503856e-05]]
# 316 [[173.77531853]]
# 317 [[0.2018]]
# 318 [[35.300168]]
# 319 [[5.54215173]]
# 320 [[131.04191695]]
# 321 [[47044.44121958]]
# 322 [[23639.3487929]]
# 323 [[25.22763371]]
# 324 [[62949433.37691385]]
# 325 [[43036016.0314452]]
# 326 [[105166.23098573]]
# 327 [[57800.843376]]
# 328 [[5625000.02924026]]
# 329 [[1280.37194224]]
# 330 [[7.22323925e+09]]
# 331 [[0.01594896]]
# 332 [[7.00000002e+09]]
# 333 [[5.17236878e+10]]
# 334 [[4780.82644607]]
# 335 [[15.03424232]]
# 336 [[56.16157747]]
# 337 [[4.90239508]]
# 338 [[248.36946403]]
# 339 [[4.5207435]]
# 340 [[3.47523407]]
# 341 [[3.72038966]]
# 342 [[85.08119491]]
# 343 [[260.17555008]]
# 344 [[80650.00223686]]
# 345 [[0.65454543]]
# 346 [[0.04853765]]
# 347 [[19360049.9326917]]
# 348 [[2140959.51837635]]
# 349 [[3.20568214e+09]]
# 350 [[0.0346256]]
# 351 [[0.00127832]]
# 352 [[6883071.75]]
# 353 [[18119.51883389]]
# 354 [[0.01194]]
# 355 [[2250000.05058689]]
# 356 [[0.00048855]]
# 357 [[0.00474947]]
# 358 [[0.00011872]]
# 359 [[1.30075295e-05]]
# 360 [[4.77432908e-06]]
# 361 [[0.00128015]]
# 362 [[1.5808171e-05]]
# 363 [[0.01425923]]
# 364 [[0.00663358]]
# 365 [[0.00462]]
# 366 [[0.00095587]]
# 367 [[5.12093336e-05]]
# 368 [[1.70255456]]
# 369 [[301.71780514]]
# 370 [[0.00235697]]
# 371 [[0.05388182]]
# 372 [[2.00004714]]
# 373 [[2.71698395e-06]]
# 374 [[4.63274801e-05]]
# 375 [[0.04481726]]
# 376 [[0.00082128]]
# 377 [[5.12059009e-07]]
# 378 [[1.58420645e-05]]
# 379 [[1.4651803e-05]]
# 380 [[1.34130362]]
# 381 [[0.02050676]]
# 382 [[1.58633002e-05]]
# 383 [[0.0204712]]
# 384 [[0.61220401]]
# 385 [[5.90245834e-08]]
# 386 [[0.00013464]]
# 387 [[9.33347835e-06]]
# 388 [[0.00041558]]
# 389 [[6.47019293e-10]]
# 390 [[0.09925534]]
# 391 [[1.47012288]]
# 392 [[0.01511561]]
# 393 [[9.26293403e-07]]
# 394 [[1.49375698e-05]]
# 395 [[2.63534368e-05]]
# 396 [[0.00015925]]
# 397 [[4.87311141e-08]]
# 398 [[8.591406e-05]]
# 399 [[7.60653997e-08]]
# 400 [[0.02769536]]
# 401 [[0.00713778]]
# 402 [[0.00082623]]
# 403 [[0.5777495]]
# 404 [[1.11812809e-05]]
# 405 [[0.02489519]]
# 406 [[8.8574718e-05]]
# 407 [[0.00912763]]
# 408 [[2.70165332e-07]]
# 409 [[0.00041987]]
# 410 [[0.00890547]]
# 411 [[5.25500058e-07]]
# 412 [[4.34000015]]
# 413 [[4.86827901e-07]]
# 414 [[0.00223262]]
# 415 [[2.45006379e-06]]
# 416 [[2.22000003]]
# 417 [[1.37995197e-05]]
# 418 [[3.20065883e-05]]
# 419 [[2.36258096e-06]]
# 420 [[9.51330238e-06]]
# 421 [[1.80156008e-05]]
# 422 [[32720.04360153]]
# 423 [[0.01401649]]
# 424 [[0.05555597]]
# 425 [[0.07518225]]
# 426 [[0.04274298]]
# 427 [[1.23284886e-06]]
# 428 [[21.70294005]]
# 429 [[1.07084164e-06]]
# 430 [[0.00016889]]
# 431 [[0.0002052]]
# 432 [[99.38239133]]
# 433 [[0.21294939]]
# 434 [[3.6308113e-06]]
# 435 [[0.00463549]]
# 436 [[1.28773823e-06]]
# 437 [[0.00042316]]
# 438 [[0.10727816]]
# 439 [[0.00673355]]
# 440 [[48.35617941]]
# 441 [[0.01034703]]
# 442 [[0.00082001]]
# 443 [[0.00236657]]
# 444 [[0.41293822]]
# 445 [[2.75084325]]
# 446 [[1.30171116]]
# 447 [[0.19007585]]
# 448 [[9.01802242e-06]]
# 449 [[7.79644412e-05]]
# 450 [[1.97039999]]
# 451 [[0.00162829]]
# 452 [[0.00949236]]
# 453 [[0.2756381]]
# 454 [[9.30796867e-05]]
# 455 [[5.37133992e-05]]
# 456 [[9.52263277e-06]]
# 457 [[2.37495591e-06]]
# 458 [[0.07029338]]
# 459 [[10.8188901]]
# 460 [[3.50724996e-05]]
# 461 [[550.46830265]]
# 462 [[0.00106026]]
# 463 [[0.00381013]]
# 464 [[2.26250214]]
# 465 [[5.10215713e-07]]
# 466 [[0.00023839]]
# 467 [[0.00102633]]
# 468 [[0.00014771]]
# 469 [[7.78108019e-06]]
# 470 [[0.00175152]]
# 471 [[3.4928328e-05]]
# 472 [[6.29579767e-06]]
# 473 [[0.00107618]]
# 474 [[0.00084134]]
# 475 [[0.210317]]
# 476 [[1.37328074e-06]]
# 477 [[0.003566]]
# 478 [[5.81631382e-07]]
# 479 [[0.00017683]]
# 480 [[7.69019336e-05]]
# 481 [[1.64943749e-06]]
# 482 [[0.00535322]]
# 483 [[0.00393815]]
# 484 [[0.02470145]]
# 485 [[5.13617499e-06]]
# 486 [[0.01204145]]
# 487 [[0.00138413]]
# 488 [[3.42423864]]
# 489 [[0.08223638]]
# 490 [[0.00832994]]
# 491 [[6.89817188e-05]]
# 492 [[15498.37422043]]
# 493 [[0.49901801]]
# 494 [[54.23169123]]
# 495 [[4.34145434]]
# 496 [[95.96359954]]
# 497 [[80057.8558332]]
# 498 [[40163.16768273]]
# 499 [[362.16757487]]
# 500 [[0.00063829]]
# 501 [[0.00435485]]
# 502 [[0.00237013]]
# 503 [[0.00282594]]
# 504 [[0.00015282]]
# 505 [[4176.43147034]]
# 506 [[618.188982]]
# 507 [[75392.6226663]]
# 508 [[21.51836389]]
# 509 [[154186.29522951]]
# 510 [[4061414.55345892]]
# 511 [[995.74514689]]
# 512 [[1948.00003464]]
# 513 [[9911502.39601556]]
# 514 [[1.63956588e+09]]
# 515 [[10561885.22586017]]
# 516 [[0.50068724]]
# 517 [[32.57503829]]
# 518 [[191.68571724]]
# 519 [[11.87388754]]
# 520 [[1.77135001]]
# 521 [[0.17378881]]
# 522 [[1.30799998]]
# 523 [[0.00213452]]
# 524 [[1655.00001266]]
# 525 [[5322.67561073]]
# 526 [[0.01585111]]
# 527 [[4.70113206]]
# 528 [[0.08]]
# 529 [[1.83039612e+09]]
# 530 [[72012.70333683]]
# 531 [[31554.44000244]]
# 532 [[58853.84921265]]
# 533 [[1.65210602]]
# 534 [[6109.95901181]]
# 535 [[0.49901801]]
# 536 [[61.34282072]]
# 537 [[0.40031999]]
# 538 [[9.33025669]]
# 539 [[156.57121438]]
# 540 [[80066.38551492]]
# 541 [[40185.90227372]]
# 542 [[363.3955897]]
# 543 [[0.22343255]]
# 544 [[0.13692299]]
# 545 [[0.00435485]]
# 546 [[430360.00237015]]
# 547 [[0.00282594]]
# 548 [[0.00015282]]
# 549 [[1379.41776273]]
# 550 [[754.86656636]]
# 551 [[0.09425277]]
# 552 [[8.29206226]]
# 553 [[75001.16429668]]
# 554 [[998.43672301]]
# 555 [[92205812.00884597]]
# 556 [[99237706.19467886]]
# 557 [[0.00015949]]
# 558 [[70000000.16152672]]
# 559 [[1.63991837e+09]]
# 560 [[2860574.47375535]]
# 561 [[0.50068724]]
# 562 [[22.05512921]]
# 563 [[253.8047158]]
# 564 [[11.87388754]]
# 565 [[1.77135001]]
# 566 [[0.26804159]]
# 567 [[1.54112606]]
# 568 [[0.72475233]]
# 569 [[260.17555008]]
# 570 [[5062.50006065]]
# 571 [[1655.00001266]]
# 572 [[0.00970374]]
# 573 [[96800.31996953]]
# 574 [[42809.81772237]]
# 575 [[32517569.71715996]]
# 576 [[1.55741858e+09]]
# 577 [[3.11785923e-05]]
# 578 [[91774.28921509]]
# 579 [[363.41637994]]
# 580 [[30000.0012618]]
# 581 [[0.2984671]]
# 582 [[0.00033003]]
# 583 [[4.72202638e-07]]
# 584 [[2.57276856e-07]]
# 585 [[9.81251078e-06]]
# 586 [[0.00011592]]
# 587 [[6.8881304e-05]]
# 588 [[0.0001871]]
# 589 [[0.00239323]]
# 590 [[2.08505389e-05]]
# 591 [[5.34880977e-05]]
# 592 [[0.08592645]]
# 593 [[2.21864047e-06]]
# 594 [[0.01167453]]
# 595 [[0.00626206]]
# 596 [[0.0026539]]
# 597 [[2.]]
# 598 [[8.78438441e-06]]
# 599 [[2.0000052]]
# 600 [[2.00000082]]
# 601 [[79.30601646]]
# 602 [[0.00857052]]
# 603 [[1926.34833602]]
# 604 [[109.07902955]]
# 605 [[2852.54229693]]
# 606 [[289.47218817]]
# 607 [[18.73612299]]
# 608 [[9490.19498494]]
# 609 [[277246.69061339]]
# 610 [[5369.73434859]]
# 611 [[22.64654845]]
# 612 [[18.65892467]]
# 613 [[0.02639659]]
# 614 [[1.48103549]]
# 615 [[0.10224758]]
# 616 [[0.05906095]]
# 617 [[0.02872886]]
# 618 [[0.006208]]
# 619 [[0.09143445]]
# 620 [[1.01742648e-05]]
# 621 [[0.09329544]]
# 622 [[2.22351741e-07]]
# 623 [[1.57411749e-08]]
# 624 [[0.00188884]]
# 625 [[0.43363088]]
# 626 [[0.0824393]]
# 627 [[1.39422407]]
# 628 [[0.04748031]]
# 629 [[0.41231832]]
# 630 [[0.78244305]]
# 631 [[0.11944873]]
# 632 [[0.00011713]]
# 633 [[0.04242208]]
# 634 [[0.05019418]]
# 635 [[0.03098359]]
# 636 [[0.00178252]]
# 637 [[0.00228319]]
# 638 [[0.19436453]]
# 639 [[3.66623203]]
# 640 [[0.3760794]]
# 641 [[9.1088597]]
# 642 [[0.02583353]]
# 643 [[9.62739532]]
# 644 [[0.61534218]]
# 645 [[0.00033797]]
# 646 [[0.29490249]]
# 647 [[1.12928831e-07]]
# 648 [[2.26579124e-06]]
# 649 [[0.21554069]]
# 650 [[0.00024485]]
# 651 [[0.02150052]]
# 652 [[0.1075899]]
# 653 [[5.76693441e-05]]
# 654 [[0.00098152]]
# 655 [[0.0001153]]
# 656 [[0.34854625]]
# 657 [[0.25456662]]
# 658 [[0.01642454]]
# 659 [[0.00297068]]
# 660 [[3.24831692e-13]]
# 661 [[1.72387302e-07]]
# 662 [[3.22838574e-12]]
# 663 [[0.00032577]]
# 664 [[0.0001538]]
# 665 [[0.03398385]]
# 666 [[0.00046322]]
# 667 [[0.00094445]]
# 668 [[0.00416184]]
# 669 [[0.00615212]]
# 670 [[0.00032772]]
# 671 [[0.00313365]]
# 672 [[0.0002322]]
# 673 [[0.02403496]]
# 674 [[0.00569616]]
# 675 [[0.02045563]]
# 676 [[0.00016602]]
# 677 [[0.00468291]]
# 678 [[0.00055297]]
# 679 [[1.64948233e-08]]
# 680 [[0.12434842]]
# 681 [[0.00491345]]
# 682 [[1.20938377]]
# 683 [[0.4803622]]
# 684 [[175.80727922]]
# 685 [[18778.77989771]]
# 686 [[2.42002032e+09]]
# 687 [[0.39903161]]
# 688 [[7.29953653]]
# 689 [[18763.05126035]]
# 690 [[9.49569861]]
# 691 [[0.00220129]]
# 692 [[0.85374898]]
# 693 [[24.08572553]]
# 694 [[1428033.14092146]]
# 695 [[0.00596747]]
# 696 [[34.2898706]]
# 697 [[1693203.3517475]]
# 698 [[1.39758232e-05]]
# 699 [[0.06290823]]
# 700 [[0.04541278]]
# 701 [[0.06732773]]
# 702 [[2.22127238e-06]]
# 703 [[2.97050871e-05]]
# 704 [[0.03]]
# 705 [[0.13156346]]
# 706 [[8.0833634e-07]]
# 707 [[8.25241217e-08]]
# 708 [[0.17838129]]
# 709 [[0.00037775]]
# 710 [[0.00236066]]
# 711 [[0.00930007]]
# 712 [[8.95568273e-07]]
# 713 [[0.18923034]]
# 714 [[0.00297322]]
# 715 [[0.03097203]]
# 716 [[2.21395854e-06]]
# 717 [[1.54799127e-05]]
# 718 [[0.28386923]]
# 719 [[0.03146886]]
# 720 [[2.75841983e-06]]
# 721 [[2.57118814]]
# 722 [[1.23430503e-07]]
# 723 [[1.03534236e-05]]
# 724 [[2.25651085]]
# 725 [[2.47719403e-07]]
# 726 [[0.0693]]
# 727 [[0.0497125]]
# 728 [[0.04984305]]
# 729 [[1.25406585e-06]]
# 730 [[4.7970154e-12]]
# 731 [[5.51233273e-09]]
# 732 [[0.83564247]]
# 733 [[0.00274023]]
# 734 [[0.05162617]]
# 735 [[1.00757167]]
# 736 [[4.53551882e-07]]
# 737 [[7.01209163e-07]]
# 738 [[1.17278796e-06]]
# 739 [[0.02780014]]
# 740 [[0.02800071]]
# 741 [[9.04571296e-07]]
# 742 [[0.02172649]]
# 743 [[0.00200007]]
# 744 [[0.00011684]]
# 745 [[1.52267721e-05]]
# 746 [[0.23111022]]
# 747 [[0.0148813]]
# 748 [[1.29783171]]
# 749 [[0.00074193]]
# 750 [[9.73259587e-07]]
# 751 [[8.94159321e-06]]
# 752 [[0.047627]]
# 753 [[0.01115601]]
# 754 [[0.02655323]]
# 755 [[0.03359517]]
# 756 [[0.03809702]]
# 757 [[0.22306277]]
# 758 [[1.0050971]]
# 759 [[1.52923869]]
# 760 [[0.72996443]]
# 761 [[3.18529932]]
# 762 [[2442.64224253]]
# 763 [[1179.2683248]]
# 764 [[0.00332105]]
# 765 [[0.07530794]]
# 766 [[2.52474604e-05]]
# 767 [[0.06451933]]
# 768 [[0.00043333]]
# 769 [[1.3114868e-05]]
# 770 [[0.00621846]]
# 771 [[0.57154031]]
# 772 [[0.00082236]]
# 773 [[0.24230082]]
# 774 [[5.48615948e-05]]
# 775 [[0.00096809]]
# 776 [[4.59214204e-06]]
# 777 [[0.0003423]]
# 778 [[0.95159716]]
# 779 [[0.10345929]]
# 780 [[0.06436713]]
# 781 [[3.701221e-05]]
# 782 [[0.46635141]]
# 783 [[0.28370902]]
# 784 [[0.04587928]]
# 785 [[3129809.63879218]]
# 786 [[0.00048976]]
# 787 [[7.59721621e-10]]
# 788 [[4.63288823e-06]]
# 789 [[34.60098113]]
# 790 [[0.07701493]]
# 791 [[0.00017623]]
# 792 [[0.00031804]]
# 793 [[3.99094834]]
# 794 [[0.58751634]]
# 795 [[0.01061766]]
# 796 [[0.71593981]]
# 797 [[1.42062825]]
# 798 [[0.19125102]]
# 799 [[0.24912465]]
# 800 [[0.10427312]]
# 801 [[4.92717491e-06]]
# 802 [[2.82389985]]
# 803 [[0.03314343]]
# 804 [[3.29896462e-05]]
# 805 [[2.38229815]]
# 806 [[4.19712241]]
# 807 [[0.00601789]]
# 808 [[0.00338818]]
# 809 [[0.3664937]]
# 810 [[0.02858735]]
# 811 [[0.66135184]]
# 812 [[0.08247973]]
# 813 [[0.18548184]]
# 814 [[4.58630125e-07]]
# 815 [[0.20537372]]
# 816 [[0.00025322]]
# 817 [[1.15393755e-10]]
# 818 [[0.00226642]]
# 819 [[56.46492933]]
# 820 [[0.29322592]]
# 821 [[6.08162866e-05]]
# 822 [[2.98483558e-07]]
# 823 [[1.16314273e-06]]
# 824 [[0.00805407]]
# 825 [[5.78946234e-08]]
# 826 [[6.57084318e-06]]
# 827 [[0.0406452]]
# 828 [[1.001]]
# 829 [[3200006.05990277]]
# 830 [[5.77328422e-07]]
# 831 [[0.04746566]]
# 832 [[1.20122711e-05]]
# 833 [[0.04129796]]
# 834 [[7.22961944e-06]]
# 835 [[0.00160383]]
# 836 [[1.09922025e-05]]
# 837 [[1.47142015]]
# 838 [[1.35727603]]
# 839 [[3.24915863e-05]]
# 840 [[0.00097266]]
# 841 [[0.00181688]]
# 842 [[2.52826274e-07]]
# 843 [[1.95530274e-05]]
# 844 [[0.00637236]]
# 845 [[0.02795347]]
# 846 [[1.1366064e-05]]
# 847 [[5.24999996e-05]]
# 848 [[7.05271115e-06]]
# 849 [[0.00945026]]
# 850 [[0.19129772]]
# 851 [[0.00676503]]
# 852 [[1.15393756e-07]]
# 853 [[0.03303506]]
# 854 [[0.5599962]]
# 855 [[0.01761192]]
# 856 [[0.1033333]]
# 857 [[0.00528569]]
# 858 [[49085871.67517207]]
# 859 [[0.00048248]]
# 860 [[443885.77695664]]
# 861 [[3.32009474e+08]]
# 862 [[3.36663211e-05]]
# 863 [[0.00350363]]
# 864 [[0.02259413]]
# 865 [[0.00395914]]
# 866 [[0.00181029]]
# 867 [[2.41003652e+08]]
# 868 [[8.32213578]]
# 869 [[49.11933001]]
# 870 [[0.09851007]]
# 871 [[0.01149986]]
# 872 [[0.00427393]]
# 873 [[0.01214948]]
# 874 [[0.00186382]]
# 875 [[4.43896664e-05]]
# 876 [[0.90632811]]
# 877 [[7.18145554e-09]]
# 878 [[0.00036573]]
# 879 [[0.00616666]]
# 880 [[0.02344135]]
# 881 [[0.01878702]]
# 882 [[4.11427444e-08]]
# 883 [[8.89930839e-08]]
# 884 [[4.72013416e-06]]
# 885 [[1.08203075e-05]]
# 886 [[6.34604932]]
# 887 [[0.01101676]]
# 888 [[0.00146895]]
# 889 [[0.62673189]]
# 890 [[1.82945058]]
# 891 [[0.06427929]]
# 892 [[0.00166512]]
# 893 [[0.00028146]]
# 894 [[0.00240804]]
# 895 [[0.11383832]]
# 896 [[0.00041519]]
# 897 [[6.42066936e-10]]
# 898 [[0.00157566]]
# 899 [[0.36504799]]
# 900 [[0.00789092]]
# 901 [[8.47232227e-05]]
# 902 [[4.25413513e-06]]
# 903 [[0.00023612]]
# 904 [[0.81330372]]
# 905 [[1.72199723e-05]]
# 906 [[4.08860687e-06]]
# 907 [[28.34465568]]
# 908 [[0.00155303]]
# 909 [[0.01736389]]
# 910 [[0.00495797]]
# 911 [[1.5593701]]
# 912 [[0.00605286]]
# 913 [[2561140.14095597]]
# 914 [[1.40060966e+08]]
# 915 [[0.60347603]]
# 916 [[1.19615694e-08]]
# 917 [[2.42334291e-05]]
# 918 [[0.01310369]]
# 919 [[1.06424611e-07]]
# 920 [[0.35625851]]
# 921 [[0.00183168]]
# 922 [[1.64948233e-08]]
# 923 [[0.0014037]]
# 924 [[0.01538734]]
# 925 [[0.81717402]]
# 926 [[0.1947728]]
# 927 [[2.68493426e-05]]
# 928 [[4.23685229e-07]]
# 929 [[0.00054831]]
# 930 [[2.10420306e-07]]
# 931 [[3.03073786e-07]]
# 932 [[0.00225772]]
# 933 [[0.23068134]]
# 934 [[0.12371229]]
# 935 [[0.00211558]]
# 936 [[0.00018026]]
# 937 [[0.01344309]]
# 938 [[0.00147947]]
# 939 [[0.00079781]]
# 940 [[0.00093005]]
# 941 [[0.08189482]]
# 942 [[3.37586547]]
# 943 [[0.77652554]]
# 944 [[30124.12745135]]
# 945 [[0.00138563]]
# 946 [[85.00080281]]
# 947 [[0.002]]
# 948 [[0.23408173]]
# 949 [[0.08763563]]
# 950 [[0.62284964]]
# 951 [[0.0995406]]
# 952 [[3.81963419e-08]]
# 953 [[8.76677825e-07]]
# 954 [[2.4398115e-05]]
# 955 [[0.00013904]]
# 956 [[2.03342277e-07]]
# 957 [[0.00962612]]
# 958 [[0.00062907]]
# 959 [[2.01236605]]
# 960 [[1.37641889]]
# 961 [[0.00043968]]
# 962 [[0.82402543]]
# 963 [[0.03755531]]
# 964 [[0.00087458]]
# 965 [[0.0198383]]
# 966 [[7.47110501e-05]]
# 967 [[0.24044627]]
# 968 [[0.01028927]]
# 969 [[0.23757001]]
# 970 [[0.08572622]]
# 971 [[0.00198796]]
# 972 [[3.76268986e-06]]
# 973 [[0.00148042]]
# 974 [[5.14834575e-07]]
# 975 [[2.94197101e-07]]
# 976 [[50.21228181]]
# 977 [[6.56700039]]
# 978 [[0.3191803]]
# 979 [[6.66898771]]
# 980 [[0.00129591]]
# 981 [[0.00021309]]
# 982 [[0.02309939]]
# 983 [[0.00279051]]
# 984 [[0.9962988]]
# 985 [[71.93051119]]
# 986 [[0.03939673]]
# 987 [[24.33334923]]
# 988 [[9.1543129]]
# 989 [[0.28546053]]
# 990 [[2.13691374]]
# 991 [[0.04269048]]
# 992 [[0.05924783]]
# 993 [[0.71162947]]
# 994 [[0.02434857]]
# 995 [[1.64948236e-05]]
# 996 [[3.29548452]]
# 997 [[2.29005169e-06]]
# 998 [[1.40328684e-05]]
# 999 [[5.6459698e-06]]
# 1000 [[0.10428373]]
# 1001 [[0.10189659]]
# 1002 [[0.01701176]]
# 1003 [[9.27622844e-05]]
# 1004 [[0.00526573]]
# 1005 [[7.32712079e-06]]
# 1006 [[0.04291374]]
# 1007 [[0.01737056]]
# 1008 [[0.00048996]]
# 1009 [[2.97280787e-08]]
# 1010 [[1.61551924e-05]]
# 1011 [[9.49042011e-07]]
# 1012 [[0.00011108]]
# 1013 [[0.00033291]]
# 1014 [[1.89124962]]
# 1015 [[0.0076035]]
# 1016 [[0.01719889]]
# 1017 [[4.99930808e-07]]
# 1018 [[0.0012304]]
# 1019 [[1.58312125e-05]]
# 1020 [[0.90367321]]
# 1021 [[0.39975886]]
# 1022 [[0.00588883]]
# 1023 [[10.99390066]]
# 1024 [[0.00162554]]
# 1025 [[1.32200027]]
# 1026 [[0.3531491]]
# 1027 [[0.13269225]]
# 1028 [[6.03901164e-06]]
# 1029 [[0.00104846]]
# 1030 [[9.0281818e-05]]
# 1031 [[0.01777113]]
# 1032 [[0.00220568]]
# 1033 [[0.00055532]]
# 1034 [[4.64080896e-05]]
# 1035 [[0.94688846]]
# 1036 [[-3.55373416e-05]]
# 1037 [[0.15941989]]
# 1038 [[6.68905766]]
# 1039 [[0.05302457]]
# 1040 [[7.22003474]]
# 1041 [[0.00282025]]
# 1042 [[26.70175642]]
# 1043 [[171.86239062]]
# 1044 [[2.59916801e-08]]
# 1045 [[0.11025857]]
# 1046 [[0.18754442]]
# 1047 [[0.05665101]]
# 1048 [[0.15691487]]
# 1049 [[9.80252583e-07]]
# 1050 [[0.0070173]]
# 1051 [[0.00059637]]
# 1052 [[0.10001971]]
# 1053 [[0.04347607]]
# 1054 [[0.00075217]]
# 1055 [[0.06285079]]
# 1056 [[0.05409521]]
# 1057 [[0.00021042]]
# 1058 [[3.29667525e-05]]
# 1059 [[3.33822057e-05]]
# 1060 [[3.43356663e-08]]
# 1061 [[0.00035776]]
# 1062 [[1.54633883e-05]]
# 1063 [[1.04322718e-05]]
# 1064 [[0.19554768]]
# 1065 [[2.97563988e-06]]
# 1066 [[0.0021183]]
# 1067 [[0.00010642]]
# 1068 [[0.22900303]]
# 1069 [[5.07273057e-05]]
# 1070 [[0.35948342]]
# 1071 [[0.00262549]]
# 1072 [[0.03033784]]
# 1073 [[7912.99889293]]
# 1074 [[14.00397424]]
# 1075 [[0.03082313]]
# 1076 [[0.00474697]]
# 1077 [[0.00012681]]
# 1078 [[0.20263508]]
# 1079 [[0.01901561]]
# 1080 [[0.00212368]]
# 1081 [[7.94339022e-07]]
# 1082 [[2.67102906e-06]]
# 1083 [[5.20396345e-07]]
# 1084 [[3.2563282e-05]]
# 1085 [[6.89460057e-05]]
# 1086 [[0.27037615]]
# 1087 [[0.47932215]]
# 1088 [[0.03103355]]
# 1089 [[0.00643095]]
# 1090 [[2.1776513e-06]]
# 1091 [[7.19438197e-07]]
# 1092 [[0.00587448]]
# 1093 [[0.27790761]]
# 1094 [[0.23725634]]
# 1095 [[0.00014434]]
# 1096 [[0.00236236]]
# 1097 [[0.00014563]]
# 1098 [[326.1256349]]
# 1099 [[0.00726255]]
# 1100 [[0.00314095]]
# 1101 [[3.76185191e-08]]
# 1102 [[1.30281409e-05]]
# 1103 [[1.64320178e-07]]
# 1104 [[0.04210835]]
# 1105 [[0.0020283]]
# 1106 [[1.87880338e-06]]
# 1107 [[0.00427608]]
# 1108 [[0.02415236]]
# 1109 [[0.00215933]]
# 1110 [[0.00408166]]
# 1111 [[0.00012605]]
# 1112 [[0.01018479]]
# 1113 [[2.38107356e-05]]
# 1114 [[4.42333183]]
# 1115 [[-0.00015477]]
# 1116 [[0.27042578]]
# 1117 [[0.02494746]]
# 1118 [[0.01394653]]
# 1119 [[0.00065354]]
# 1120 [[0.00049387]]
# 1121 [[0.00403742]]
# 1122 [[0.01566108]]
# 1123 [[0.0080382]]
# 1124 [[0.04034797]]
# 1125 [[0.00155514]]
# 1126 [[0.0068404]]
# 1127 [[0.00076]]
# 1128 [[0.14736032]]
# 1129 [[1.33032099e-08]]
# 1130 [[9.04186575e-08]]
# 1131 [[0.00150145]]
# 1132 [[4.47842341e-08]]
# 1133 [[4.23044493e-06]]
# 1134 [[0.26805532]]
# 1135 [[0.5632433]]
# 1136 [[0.00077366]]
# 1137 [[0.27649633]]
# 1138 [[0.00134882]]
# 1139 [[0.00025216]]
# 1140 [[0.0005134]]
# 1141 [[0.02481724]]
# 1142 [[6.67160963e-07]]
# 1143 [[0.00088635]]
# 1144 [[56.20159687]]
# 1145 [[0.00653869]]
# 1146 [[47.38129005]]
# 1147 [[336638.00196603]]
# 1148 [[1.57473695]]
# 1149 [[0.03650716]]
# 1150 [[0.35666974]]
# 1151 [[0.1050957]]
# 1152 [[21.30144749]]
# 1153 [[3.42541956]]
# 1154 [[9.49172045e-06]]
# 1155 [[0.02088692]]
# 1156 [[0.00433952]]
# 1157 [[0.00138184]]
# 1158 [[0.11077024]]
# 1159 [[0.24899722]]
# 1160 [[4.41597121e-06]]
# 1161 [[8.75331311e-05]]
# 1162 [[0.50591715]]
# 1163 [[0.00430812]]
# 1164 [[5.25827771e-07]]
# 1165 [[1.66428968]]
# 1166 [[0.00032074]]
# 1167 [[162.1093812]]
# 1168 [[0.003625]]
# 1169 [[0.00108823]]
# 1170 [[1.72698692]]
# 1171 [[0.00506335]]
# 1172 [[0.03377481]]
# 1173 [[0.25753009]]
# 1174 [[0.00014998]]
# 1175 [[0.0152535]]
# 1176 [[0.0001425]]
# 1177 [[0.5500238]]
# 1178 [[5.45059884e-06]]
# 1179 [[0.46421371]]
# 1180 [[5.1394256e-05]]
# 1181 [[0.00010143]]
# 1182 [[2.99072151e-07]]
# 1183 [[0.02]]
# 1184 [[2.85776692e-06]]
# 1185 [[0.01987571]]
# 1186 [[3.8363892e-05]]
# 1187 [[2.72900187e-06]]
# 1188 [[24.46935343]]
# 1189 [[63000015.33827977]]
# 1190 [[1079.58634412]]
# 1191 [[1.36200005e+08]]
# 1192 [[0.0702728]]
# 1193 [[0.01832969]]
# 1194 [[0.00061172]]
# 1195 [[0.17598532]]
# 1196 [[0.00057718]]
# 1197 [[0.25614354]]
# 1198 [[6.16883359e-05]]
# 1199 [[0.01522799]]
# 1200 [[9.94530163]]
# 1201 [[0.0005914]]
# 1202 [[0.06655507]]
# 1203 [[0.00134039]]
# 1204 [[0.35924144]]
# 1205 [[0.57304861]]
# 1206 [[0.01740288]]
# 1207 [[0.00095493]]
# 1208 [[0.0105967]]
# 1209 [[0.00268589]]
# 1210 [[0.02205]]
# 1211 [[0.27613768]]
# 1212 [[0.37761525]]
# 1213 [[2.02871016e-05]]
# 1214 [[0.01306098]]
# 1215 [[0.05599962]]
# 1216 [[0.0107263]]
# 1217 [[1.86340361]]
# 1218 [[0.44850787]]
# 1219 [[1.70819448]]
# 1220 [[0.01390743]]
# 1221 [[0.00336]]
# 1222 [[7.0342105e-05]]
# 1223 [[4.66714274e-05]]
# 1224 [[1.91483815e-06]]
# 1225 [[3.77919349e-06]]
# 1226 [[0.09193892]]
# 1227 [[0.28241507]]
# 1228 [[3.22743377]]
# 1229 [[9.60101849]]
# 1230 [[4.60236034]]
# 1231 [[319.08568657]]
# 1232 [[18.80830204]]
# 1233 [[0.02090324]]
# 1234 [[0.00176396]]
# 1235 [[5.93023363]]
# 1236 [[3.01900521]]
# 1237 [[0.63515026]]
# 1238 [[0.00213495]]
# 1239 [[0.00538466]]
# 1240 [[0.00990457]]
# 1241 [[7.54752907e-08]]
# 1242 [[0.00091697]]
# 1243 [[0.0002565]]
# 1244 [[0.36589809]]
# 1245 [[4.48907842]]
# 1246 [[1.18144089e-05]]
# 1247 [[0.0019241]]
# 1248 [[0.10365777]]
# 1249 [[0.00097318]]
# 1250 [[0.01150442]]
# 1251 [[9.03120516e-05]]
# 1252 [[0.13236595]]
# 1253 [[0.00027018]]
# 1254 [[0.1419151]]
# 1255 [[3.7175822e-06]]
# 1256 [[0.00086371]]
# 1257 [[0.11444949]]
# 1258 [[0.07151775]]
# 1259 [[92.1573258]]
# 1260 [[63000014.98671798]]
# 1261 [[940.2908218]]
# 1262 [[1.36200007e+08]]
# 1263 [[8.0785153]]
# 1264 [[41.51476748]]
# 1265 [[9.63000762]]
# 1266 [[0.00886529]]
# 1267 [[0.02990092]]
# 1268 [[7.37250002e-06]]
# 1269 [[32.41019062]]
# 1270 [[15.66019712]]
# 1271 [[1.18901909e-05]]
# 1272 [[0.0148]]
# 1273 [[0.01984043]]
# 1274 [[0.01372889]]
# 1275 [[0.01217102]]
# 1276 [[0.027165]]
# 1277 [[0.00320549]]
# 1278 [[0.04924011]]
# 1279 [[0.0053694]]
# 1280 [[0.02427092]]
# 1281 [[0.0054781]]
# 1282 [[177.52591173]]
# 1283 [[0.14379403]]
# 1284 [[70.3242637]]
# 1285 [[17320005.80163754]]
# 1286 [[164.0884345]]
# 1287 [[40400002.32353804]]
# 1288 [[7.49019993e-09]]
# 1289 [[0.00011766]]
# 1290 [[6.29564791e-07]]
# 1291 [[0.37534495]]
# 1292 [[0.00662699]]
# 1293 [[0.06357989]]
# 1294 [[0.00015357]]
# 1295 [[1.01677322e-06]]
# 1296 [[0.02144545]]
# 1297 [[0.00636974]]
# 1298 [[0.00835906]]
# 1299 [[0.0112396]]
# 1300 [[5.22346176e-06]]
# 1301 [[0.05912248]]
# 1302 [[3.3023077e-10]]
# 1303 [[0.00512532]]
# 1304 [[7.60073827]]
# 1305 [[0.33802041]]
# 1306 [[1.94453595]]
# 1307 [[8.44657187]]
# 1308 [[0.00632472]]
# 1309 [[0.0038841]]
# 1310 [[0.04849609]]
# 1311 [[0.00208553]]
# 1312 [[0.00119528]]
# 1313 [[0.3163372]]
# 1314 [[0.00034698]]
# 1315 [[3.38773196e-08]]
# 1316 [[0.0200135]]
# 1317 [[3059.96274824]]
# 1318 [[5396.59458258]]
# 1319 [[31.03994184]]
# 1320 [[0.0101052]]
# 1321 [[0.00219244]]
# 1322 [[0.00024893]]
# 1323 [[0.0004913]]
# 1324 [[2.2978058e-05]]
# 1325 [[0.00374548]]
# 1326 [[4.01931964e-07]]
# 1327 [[0.23215169]]
# 1328 [[0.00836503]]
# 1329 [[3.00208713]]
# 1330 [[0.41223103]]
# 1331 [[122015.35815272]]
# 1332 [[0.04199506]]
# 1333 [[0.00128654]]
# 1334 [[0.0167793]]
# 1335 [[0.08305552]]
# 1336 [[0.04709665]]
# 1337 [[13380379.99952012]]
# 1338 [[2813.74000839]]
# 1339 [[0.14802072]]
# 1340 [[0.00363696]]
# 1341 [[0.00081491]]
# 1342 [[0.00083745]]
# 1343 [[0.00570634]]
# 1344 [[1.17642326e-05]]
# 1345 [[5.99391895e-05]]
# 1346 [[0.00223079]]
# 1347 [[1.39600111]]
# 1348 [[0.09869141]]
# 1349 [[0.00011868]]
# 1350 [[45.32325113]]
# 1351 [[412.153588]]
# 1352 [[13.08059915]]
# 1353 [[0.7443253]]
# 1354 [[0.45673832]]
# 1355 [[0.00432501]]
# 1356 [[0.00093837]]
# 1357 [[0.00018893]]
# 1358 [[0.00063437]]
# 1359 [[3.14824454]]
# 1360 [[0.12039214]]
# 1361 [[3.31687824]]
# 1362 [[0.00102422]]
# 1363 [[0.0085786]]
# 1364 [[1.95412772]]
# 1365 [[3.69596001]]
# 1366 [[0.00091822]]
# 1367 [[0.00050743]]
# 1368 [[0.15714307]]
# 1369 [[0.01040787]]
# 1370 [[0.04632499]]
# 1371 [[7.61007544]]
# 1372 [[0.09290948]]
# 1373 [[7.49425632]]
# 1374 [[5.39590947]]
# 1375 [[0.00285333]]
# 1376 [[1.16737445]]
# 1377 [[0.00055921]]
# 1378 [[1.50321361]]
# 1379 [[0.02852457]]
# 1380 [[0.00362046]]
# 1381 [[4.70046095e-06]]
# 1382 [[0.00364231]]
# 1383 [[0.00439101]]
# 1384 [[0.06487136]]
# 1385 [[3.64670484e-06]]
# 1386 [[0.12353356]]
# 1387 [[4.62454754e-08]]
# 1388 [[8.03999995e-08]]
# 1389 [[0.33555182]]
# 1390 [[0.00486255]]
# 1391 [[0.00200828]]
# 1392 [[0.02998322]]
# 1393 [[0.0006839]]
# 1394 [[0.00210801]]
# 1395 [[0.00910002]]
# 1396 [[0.02697956]]
# 1397 [[0.07824424]]
# 1398 [[2.39354774e-08]]
# 1399 [[0.15512226]]
# 1400 [[1.36606589e-06]]
# 1401 [[5.54306551e-05]]
# 1402 [[0.004239]]
# 1403 [[0.00594377]]
# 1404 [[9.61231945e-08]]
# 1405 [[1.59511457]]
# 1406 [[3.57179137]]
# 1407 [[4.13624054]]
# 1408 [[0.00371956]]
# 1409 [[0.00037818]]
# 1410 [[1177.92994759]]
# 1411 [[20.81167209]]
# 1412 [[4.21241724]]
# 1413 [[124.01002983]]
# 1414 [[2.67315603]]
# 1415 [[0.01941172]]
# 1416 [[0.08720248]]
# 1417 [[0.06541799]]
# 1418 [[0.00346139]]
# 1419 [[0.02264848]]
# 1420 [[6.18539167e-05]]
# 1421 [[0.00211086]]
# 1422 [[0.28335034]]
# 1423 [[5.05229413]]
# 1424 [[0.42524389]]
# 1425 [[0.58284892]]
# 1426 [[2.08975605]]
# 1427 [[0.00013891]]
# 1428 [[0.00052592]]
# 1429 [[6.70859372]]
# 1430 [[0.04085857]]
# 1431 [[20000000.02793835]]
# 1432 [[7.00168919e-08]]
# 1433 [[1.30341066e-05]]
# 1434 [[4.17626209e-05]]
# 1435 [[0.00022251]]
# 1436 [[3.59155368e-05]]
# 1437 [[0.020538]]
# 1438 [[0.037757]]
# 1439 [[2.30806909e-05]]
# 1440 [[0.00015359]]
# 1441 [[0.09853559]]
# 1442 [[0.02326123]]
# 1443 [[4.3591238]]
# 1444 [[0.15856931]]
# 1445 [[6.57008716]]
# 1446 [[0.32888714]]
# 1447 [[0.00192701]]
# 1448 [[0.00167205]]
# 1449 [[3.29944662]]
# 1450 [[0.05387014]]
# 1451 [[0.01305349]]
# 1452 [[14.34470563]]
# 1453 [[0.10849405]]
# 1454 [[18.61667731]]
# 1455 [[0.20975411]]
# 1456 [[10.46380128]]
# 1457 [[0.05608225]]
# 1458 [[0.00103686]]
# 1459 [[1.13616436]]
# 1460 [[0.13604107]]
# 1461 [[0.01222924]]
# 1462 [[0.03062712]]
# 1463 [[0.14559545]]
# 1464 [[0.02187503]]
# 1465 [[0.00100766]]
# 1466 [[0.02043756]]
# 1467 [[15.00872631]]
# 1468 [[0.01677244]]
# 1469 [[33600.95425888]]
# 1470 [[899.6061374]]
# 1471 [[0.48311366]]
# 1472 [[0.95349052]]
# 1473 [[0.00962231]]
# 1474 [[22.21543963]]
# 1475 [[13231.90660693]]
# 1476 [[0.01455869]]
# 1477 [[1.91598709]]
# 1478 [[3.78146091]]
# 1479 [[0.00591143]]
# 1480 [[1.91483815e-05]]
# 1481 [[3.77919345e-05]]
# 1482 [[2.84235683e-05]]
# 1483 [[0.00083513]]
# 1484 [[0.11824823]]
# 1485 [[0.00012987]]
# 1486 [[0.00247363]]
# 1487 [[0.02180915]]
# 1488 [[0.00561546]]
# 1489 [[8.60010798e-05]]
# 1490 [[0.0316443]]
# 1491 [[52.74100309]]
# 1492 [[514.92253329]]
# 1493 [[1.00581067]]
# 1494 [[0.00057432]]
# 1495 [[0.28551502]]
# 1496 [[1.14890289e-06]]
# 1497 [[0.00072594]]
# 1498 [[0.01487241]]
# 1499 [[0.04137701]]
# 1500 [[0.00197002]]
# 1501 [[11.48054793]]
# 1502 [[1.65045858]]
# 1503 [[105.70205895]]
# 1504 [[10.89096226]]
# 1505 [[0.00100509]]
# 1506 [[1.15794235]]
# 1507 [[4.27285494]]
# 1508 [[188108.24500919]]
# 1509 [[0.00184371]]
# 1510 [[1.01793254]]
# 1511 [[0.01346149]]
# 1512 [[0.27407584]]
# 1513 [[0.00017304]]
# 1514 [[0.00114426]]
# 1515 [[716.0203348]]
# 1516 [[2.03698036]]
# 1517 [[20.49549512]]
# 1518 [[200.88020659]]
# 1519 [[7.84341483]]
# 1520 [[462.15370227]]
# 1521 [[16.63887956]]
# 1522 [[0.00726021]]
# 1523 [[0.27797534]]
# 1524 [[0.03851396]]
# 1525 [[0.00771898]]
# 1526 [[0.01544706]]
# 1527 [[0.00734526]]
# 1528 [[1.2351219e-05]]
# 1529 [[0.67491662]]
# 1530 [[2.26157138]]
# 1531 [[576.43210575]]
# 1532 [[18.64915945]]
# 1533 [[5.04397484]]
# 1534 [[8.33092032e-07]]
# 1535 [[2.58629658e-06]]
# 1536 [[0.00246323]]
# 1537 [[0.00143129]]
# 1538 [[0.000186]]
# 1539 [[8.15297537e-06]]
# 1540 [[4.47935788e-07]]
# 1541 [[0.00121379]]
# 1542 [[0.00056616]]
# 1543 [[9.05183435e-06]]
# 1544 [[7.54181937e-09]]
# 1545 [[5.64620632e-09]]
# 1546 [[0.00010517]]
# 1547 [[0.38466476]]
# 1548 [[0.75583866]]
# 1549 [[2420.74241602]]
# 1550 [[1.23985772e-05]]
# 1551 [[0.02538806]]
# 1552 [[0.06235656]]
# 1553 [[15.12333771]]
# 1554 [[1.30701643]]
# 1555 [[0.00078]]
# 1556 [[0.00327297]]
# 1557 [[0.00037812]]
# 1558 [[3.45584234]]
# 1559 [[85.64283153]]
# 1560 [[0.00369999]]
# 1561 [[0.00440399]]
# 1562 [[70.3242637]]
# 1563 [[17320005.90695364]]
# 1564 [[244.11002449]]
# 1565 [[40400002.37304426]]
# 1566 [[0.00022393]]
# 1567 [[0.06976112]]
# 1568 [[5.24339203e-06]]
# 1569 [[0.01089919]]
# 1570 [[4.45167459e-06]]
# 1571 [[2.41999999e-07]]
# 1572 [[1.47434393e-06]]
# 1573 [[5.00412925e-05]]
# 1574 [[0.00013471]]
# 1575 [[0.5901904]]
# 1576 [[0.7359684]]
# 1577 [[1078.14077853]]
# 1578 [[18.01010025]]
# 1579 [[29.71126864]]
# 1580 [[0.00440117]]
# 1581 [[4.82351901]]
# 1582 [[45.37527054]]
# 1583 [[0.03045629]]
# 1584 [[0.00039078]]
# 1585 [[0.00625981]]
# 1586 [[0.27762966]]
# 1587 [[1.24464479e-08]]
# 1588 [[0.02289333]]
# 1589 [[4.9505679e-06]]
# 1590 [[0.00018701]]
# 1591 [[0.00036962]]
# 1592 [[2.66992778e-06]]
# 1593 [[5.64062182]]
# 1594 [[13162.41757534]]
# 1595 [[105.78115704]]
# 1596 [[0.02675062]]
# 1597 [[0.04154348]]
# 1598 [[0.22847247]]
# 1599 [[0.0058221]]
# 1600 [[0.0173295]]
# 1601 [[1910.86585475]]
# 1602 [[0.00288722]]
# 1603 [[4.46123488e-06]]
# 1604 [[0.00118823]]
# 1605 [[4.73116015e-09]]
# 1606 [[0.05455677]]
# 1607 [[1.52169598e-06]]
# 1608 [[0.00032272]]
# 1609 [[1.86785606e-05]]
# 1610 [[0.00242657]]
# 1611 [[6.85999483e-06]]
# 1612 [[3.79019285e-05]]
# 1613 [[3.18066758e-06]]
# 1614 [[1.04962571e-05]]
# 1615 [[5.57183493e-07]]
# 1616 [[2.85536205e-05]]
# 1617 [[4.51605297e-05]]
# 1618 [[1.41188785e-07]]
# 1619 [[0.00015147]]
# 1620 [[6.84899213e-08]]
# 1621 [[3.12708721e-06]]
# 1622 [[5.08625761e-06]]
# 1623 [[5.78228205e-08]]
# 1624 [[1.10401165e-07]]
# 1625 [[2.33675426e-06]]
# 1626 [[1.57556877e-07]]
# 1627 [[1.63415391e-05]]
# 1628 [[4.44428611e-05]]
# 1629 [[0.00011667]]
# 1630 [[3.37494624e-09]]
# 1631 [[2.31491709e-08]]
# 1632 [[1.42747643e-09]]
# 1633 [[0.00010297]]
# 1634 [[7.90790778e-09]]
# 1635 [[8.90224203e-08]]
# 1636 [[1.5816165e-07]]
# 1637 [[9.91884581e-10]]
# 1638 [[3.81588292e-09]]
# 1639 [[1.11180597e-07]]
# 1640 [[5.04125151e-06]]
# 1641 [[4.63874169e-07]]
# 1642 [[1.35287359e-08]]
# 1643 [[0.00023006]]
# 1644 [[5.73881203e-05]]
# 1645 [[3.38828955e-05]]
# 1646 [[7.8733903e-08]]
# 1647 [[0.000522]]
# 1648 [[0.00016154]]
# 1649 [[1.0747272e-07]]
# 1650 [[0.00267478]]
# 1651 [[5.76171983e-06]]
# 1652 [[8.21077318e-08]]
# 1653 [[8.38235501e-06]]
# 1654 [[3.33152066e-08]]
# 1655 [[0.25200305]]
# 1656 [[0.08544217]]
# 1657 [[0.14060089]]
# 1658 [[0.00173712]]
# 1659 [[0.59600722]]
# 1660 [[0.40763964]]
# 1661 [[0.45800222]]
# 1662 [[0.00215455]]
# 1663 [[0.59600722]]
# 1664 [[0.00027292]]
# 1665 [[1.30341066e-05]]
# 1666 [[0.00891326]]
# 1667 [[0.25200305]]
# 1668 [[0.00489276]]
# 1669 [[0.02433155]]
# 1670 [[0.00031794]]
# 1671 [[0.00035581]]
# 1672 [[3.2637711e-05]]
# 1673 [[0.0006384]]
# 1674 [[1.51000004e-05]]
# 1675 [[9.01000021e-05]]
# 1676 [[3.47999986e-07]]
# 1677 [[5.4379291e-05]]
# 1678 [[0.00027]]
# 1679 [[1.03124997e-05]]
# 1680 [[5.77499989e-06]]
# 1681 [[0.00089039]]
# 1682 [[2.365e-05]]
# 1683 [[1.0445e-05]]
# 1684 [[1.72499995e-05]]
# 1685 [[3.08201491e-05]]
# 1686 [[5.29999988e-06]]
# 1687 [[9.54999996e-05]]
# 1688 [[2.25839945e-05]]
# 1689 [[2.04500009e-06]]
# 1690 [[0.00203375]]
# 1691 [[161.90834678]]
# 1692 [[57739037.43275461]]
# 1693 [[40.96376957]]
# 1694 [[0.41154684]]
# 1695 [[1.26135243e-05]]
# 1696 [[69.55535917]]
# 1697 [[62976841.91703406]]
# 1698 [[1.37484]]
# 1699 [[1479.06619361]]
# 1700 [[8.45346241e-06]]
# 1701 [[0.63502264]]
# 1702 [[34.24586387]]
# 1703 [[1.00333088]]
# 1704 [[16.65735093]]
# 1705 [[0.00081536]]
# 1706 [[4.51250741]]
# 1707 [[1.57805567]]
# 1708 [[42539.00115141]]
# 1709 [[69.01481888]]
# 1710 [[85264.35442662]]
# 1711 [[0.33435308]]
# 1712 [[729.39414375]]
# 1713 [[0.00485708]]
# 1714 [[0.03262656]]
# 1715 [[0.15784643]]
# 1716 [[2.00409083]]
# 1717 [[0.00014587]]
# 1718 [[1.00432454e-05]]
# 1719 [[5.02616293e-08]]
# 1720 [[8.73298192e-08]]
# 1721 [[6.24076094e-08]]
# 1722 [[2.25247411e-08]]
# 1723 [[4.4622491e-08]]
# 1724 [[2.85122542e-09]]
# 1725 [[1.17261455e-05]]
# 1726 [[1.02217279e-08]]
# 1727 [[3.09666149e-05]]
# 1728 [[3.69027126e-07]]
# 1729 [[0.00171691]]
# 1730 [[0.01457232]]
# 1731 [[20.53668085]]
# 1732 [[0.02638978]]
# 1733 [[122043.57995152]]
# 1734 [[0.03021092]]
# 1735 [[0.00374059]]
# 1736 [[0.00113118]]
# 1737 [[5.4598234e-05]]
# 1738 [[0.0015534]]
# 1739 [[0.00051104]]
# 1740 [[0.0018216]]
# 1741 [[2.70761773e-06]]
# 1742 [[0.000144]]
# 1743 [[5.99999985e-05]]
# 1744 [[0.0255]]
# 1745 [[2.01073667e-08]]
# 1746 [[6.72255266e-08]]
# 1747 [[1.4078171e-08]]
# 1748 [[0.00633065]]
# 1749 [[0.0023333]]
# 1750 [[2.20970006e-07]]
# 1751 [[0.00046787]]
# 1752 [[0.00476909]]
# 1753 [[0.00031955]]
# 1754 [[1.20583908e-06]]
# 1755 [[1.46509444e-07]]
# 1756 [[1.4289192e-07]]
# 1757 [[40401.85809207]]
# 1758 [[0.03693784]]
# 1759 [[2.09734078e-13]]
# 1760 [[2.30837762e-05]]
# 1761 [[257.78545711]]
# 1762 [[1433.19931152]]
# 1763 [[1403.83486215]]
# 1764 [[1274.11248616]]
# 1765 [[2.30926465e-07]]
# 1766 [[0.00034298]]
# 1767 [[4.87940055e-07]]
# 1768 [[5.91487996e-05]]
# 1769 [[1.820844e-06]]
# 1770 [[7.46767986e-09]]
# 1771 [[1.20254415e-08]]
# 1772 [[1.58216308e-05]]
# 1773 [[2.07517585e-11]]
# 1774 [[1.66650161e-09]]
# 1775 [[1.31800196e-09]]
# 1776 [[3.61002969e-07]]
# 1777 [[9.01862796e-08]]
# 1778 [[3.97880333e-10]]
# 1779 [[0.0001922]]
# 1780 [[6.17789398e-05]]
# 1781 [[4.25092019e-07]]
# 1782 [[7.34374916e-11]]
# 1783 [[3.38224232e-05]]
# 1784 [[1.19527934e-10]]
# 1785 [[1.28800687e-05]]
# 1786 [[2.31066562e-08]]
# 1787 [[1.88619687e-15]]
# 1788 [[1.13174232e-13]]
# 1789 [[2.30392501e-06]]
# 1790 [[4.41688214e-06]]
# 1791 [[4.46552302e-06]]
# 1792 [[1.69480004e-06]]
# 1793 [[2.91139996e-06]]
# 1794 [[1.05679004e-08]]
# 1795 [[1.01925e-06]]
# 1796 [[1.06090002e-08]]
# 1797 [[2.29500001e-06]]
# 1798 [[3.42399997e-11]]
# 1799 [[8.90042917e-06]]
# 1800 [[1.70539196e-07]]
# 1801 [[2.31999995e-15]]
# 1802 [[3.83858151e-06]]
# 1803 [[2.50400005e-12]]
# 1804 [[5.78800012e-08]]
# 1805 [[3.81999987e-09]]
# 1806 [[2.31499993e-11]]
# 1807 [[6.92627672e-08]]
# 1808 [[4.73000009e-07]]
# 1809 [[9.11000029e-05]]
# 1810 [[2.83800001e-06]]
# 1811 [[1.16099999e-08]]
# 1812 [[6.29200027e-07]]
# 1813 [[3.83999997e-05]]
# 1814 [[1.06100004e-06]]
# 1815 [[4.40999993e-09]]
# 1816 [[3.62399988e-05]]
# 1817 [[4.41919981e-06]]
# 1818 [[1.01500001e-06]]
# 1819 [[4.02599999e-09]]
# 1820 [[6.53823738e-10]]
# 1821 [[0.00027512]]
# 1822 [[3.32293443e-06]]
# 1823 [[3.7741087e-05]]
# 1824 [[0.00148605]]
# 1825 [[0.0012037]]
# 1826 [[7.60646935e-05]]
# 1827 [[0.00037985]]
# 1828 [[2.97157071e-05]]
# 1829 [[7.93799148e-05]]
# 1830 [[0.00987702]]
# 1831 [[9.25970831e-07]]
# 1832 [[0.00041986]]
# 1833 [[9.67341631]]
# 1834 [[3.60988776e-06]]
# 1835 [[8.60714913e-13]]
# 1836 [[1.49343415e-08]]
# 1837 [[706307.75009576]]
# 1838 [[37002.37640026]]
# 1839 [[0.0082716]]
# 1840 [[0.00684252]]
# 1841 [[0.00337012]]
# 1842 [[0.00538364]]
# 1843 [[0.00047811]]
# 1844 [[5.29583758e-06]]
# 1845 [[0.001777]]
# 1846 [[0.00321299]]
# 1847 [[0.00476799]]
# 1848 [[0.10744122]]
# 1849 [[0.01044057]]
# 1850 [[0.00255902]]
# 1851 [[0.00050251]]
# 1852 [[0.53965858]]
# 1853 [[0.00282906]]
# 1854 [[0.03888791]]
# 1855 [[0.00502513]]
# 1856 [[0.0017477]]
# 1857 [[0.00085552]]
# 1858 [[0.01161485]]
# 1859 [[0.00041077]]
# 1860 [[0.00053179]]
# 1861 [[0.00357391]]
# 1862 [[0.00194255]]
# 1863 [[0.11030262]]
# 1864 [[0.00194326]]
# 1865 [[0.02619182]]
# 1866 [[1.31368738]]
# 1867 [[0.00218519]]
# 1868 [[0.00123665]]
# 1869 [[0.00503577]]
# 1870 [[0.00019073]]
# 1871 [[0.00158093]]
# 1872 [[0.00502513]]
# 1873 [[0.00215911]]
# 1874 [[0.00041196]]
# 1875 [[0.00112903]]
# 1876 [[4.37251251e-05]]
# 1877 [[3.47286389e-06]]
# 1878 [[0.00063137]]
# 1879 [[0.00010236]]
# 1880 [[6.40268136e-06]]
# 1881 [[7.99256095e-06]]
# 1882 [[5.05555545e-05]]
# 1883 [[0.00012827]]
# 1884 [[1.34220742e-05]]
# 1885 [[1.50305598e-05]]
# 1886 [[2.43750001e-05]]
# 1887 [[10.54535543]]
# 1888 [[0.00031]]
# 1889 [[1.79999995e-06]]
# 1890 [[3.40000014e-07]]
# 1891 [[0.000114]]
# 1892 [[3.40000006e-05]]
# 1893 [[7.9999998e-05]]
# 1894 [[2.93826356e-05]]
# 1895 [[1.05136963e-05]]
# 1896 [[0.85813292]]
# 1897 [[0.28866296]]
# 1898 [[1.44053188]]
# 1899 [[2.07880275e-07]]
# 1900 [[8.89930839e-08]]
# 1901 [[1.50372792e-07]]
# 1902 [[8.30693152e-05]]
# 1903 [[25975.00160942]]
# 1904 [[5944.43118718]]
# 1905 [[87.26277491]]
# 1906 [[1.05673309]]
# 1907 [[0.28537359]]
# 1908 [[5.86582107e-10]]
# 1909 [[9.62529303e-10]]
# 1910 [[19.5342315]]
# 1911 [[5.54280943]]
# 1912 [[2.71946439]]
# 1913 [[2876.18643415]]
# 1914 [[9.59871956]]
# 1915 [[1.29086556]]
# 1916 [[103.76200161]]
# 1917 [[5.94483377]]
# 1918 [[3.16216629]]
# 1919 [[0.0017044]]
# 1920 [[0.02107138]]
# 1921 [[0.10577432]]
# 1922 [[0.76778132]]
# 1923 [[0.95174321]]
# 1924 [[0.03822963]]
# 1925 [[0.47613636]]
# 1926 [[1.13941815]]
# 1927 [[1.02212831]]
# 1928 [[0.00123604]]
# 1929 [[0.00447795]]
# 1930 [[0.14970258]]
# 1931 [[1.14883749]]
# 1932 [[0.01385996]]
# 1933 [[0.03749453]]
# 1934 [[2.44805118]]
# 1935 [[0.56531189]]
# 1936 [[2.22000003]]
# 1937 [[0.06670309]]
# 1938 [[5.22992447]]
# 1939 [[0.68721542]]
# 1940 [[0.35525116]]
# 1941 [[1.43021344]]
# 1942 [[0.11776254]]
# 1943 [[5.03574115e-05]]
# 1944 [[0.02046627]]
# 1945 [[0.00119277]]
# 1946 [[0.04000795]]
# 1947 [[96.80850746]]
# 1948 [[2.69531581]]
# 1949 [[1.0439122]]
# 1950 [[0.00330066]]
# 1951 [[0.00074162]]
# 1952 [[1.3745333]]
# 1953 [[0.00453214]]
# 1954 [[1.77693722]]
# 1955 [[5.53327077]]
# 1956 [[1.0009889]]
# 1957 [[101.52063839]]
# 1958 [[2.83201479]]
# 1959 [[696.53027443]]
# 1960 [[8.75787799]]
# 1961 [[10.20186227]]
# 1962 [[2.40442458]]
# 1963 [[0.28373886]]
# 1964 [[0.82750251]]
# 1965 [[0.02266469]]
# 1966 [[2643.39392054]]
# 1967 [[12.50669402]]
# 1968 [[10294.66276031]]
# 1969 [[2482.77296046]]
# 1970 [[1.60594849]]
# 1971 [[13.20101184]]
# 1972 [[16.13358867]]
# 1973 [[0.00425481]]
# 1974 [[60.00058784]]
# 1975 [[220.50918624]]
# 1976 [[3.85900002e-07]]
# 1977 [[7.07684587e-07]]
# 1978 [[8.12110771e-05]]
# 1979 [[5.28701197e-06]]
# 1980 [[7.32770856e-07]]
# 1981 [[9.84000015e-09]]
# 1982 [[1.3934056e-07]]
# 1983 [[1.15899997e-08]]
# 1984 [[3.47400004e-06]]
# 1985 [[6.86904942e-06]]
# 1986 [[2.00799999e-09]]
# 1987 [[2.87910003e-07]]
# 1988 [[5.91063603e-06]]
# 1989 [[5.6668549e-07]]
# 1990 [[3.85199999e-06]]
# 1991 [[1.9413466e-06]]
# 1992 [[7.50385926e-06]]
# 1993 [[4.09800001e-08]]
# 1994 [[0.00011621]]
# 1995 [[4.28499995e-07]]
# 1996 [[6.74188624e-05]]
# 1997 [[0.00013651]]
# 1998 [[6.86514704e-06]]
# 1999 [[3.92005412e-06]]
# 2000 [[3.68619735e-06]]
# 2001 [[1.82819446e-08]]
# 2002 [[4.31400003e-07]]
# 2003 [[5.59707843e-06]]
# 2004 [[1.81500001e-08]]
# 2005 [[7.99599993e-07]]
# 2006 [[3.87899996e-06]]
# 2007 [[7.57000015e-06]]
# 2008 [[8.4029999e-07]]
# 2009 [[8.55640486e-05]]
# 2010 [[4.59591028e-06]]
# 2011 [[4.55499996e-09]]
# 2012 [[3.90040004e-08]]
# 2013 [[9.03797228e-05]]
# 2014 [[2.69011282e-06]]
# 2015 [[8.28240085e-06]]
# 2016 [[1.51475554e-08]]
# 2017 [[1.36427154e-05]]
# 2018 [[1.43299999e-08]]
# 2019 [[5.64129306e-06]]
# 2020 [[6.62533961e-07]]
# 2021 [[2.67000004e-07]]
# 2022 [[2.27000001e-07]]
# 2023 [[1.21900001e-08]]
# 2024 [[9480.90014624]]
# 2025 [[0.0536]]
# 2026 [[1.25062716]]
# 2027 [[1.10689697]]
# 2028 [[2.29739892e-07]]
# 2029 [[0.00037896]]
# 2030 [[1.06697048e-05]]
# 2031 [[0.00062064]]
# 2032 [[3.67382631e-06]]
# 2033 [[0.00063618]]
# 2034 [[7.33703454e-07]]
# 2035 [[2.72109845e-07]]
# 2036 [[2.171261e-06]]
# 2037 [[8.64293197e-05]]
# 2038 [[8.28121553e-05]]
# 2039 [[0.00791882]]
# 2040 [[157.06826207]]
# 2041 [[12.96228295]]
# 2042 [[0.00417249]]
# 2043 [[9.69557256e-07]]
# 2044 [[8.08221182e-05]]
# 2045 [[1.05763549e-05]]
# 2046 [[1789594.45323983]]
# 2047 [[0.07804311]]
# 2048 [[0.00122343]]
# 2049 [[8.13000015e-12]]
# 2050 [[2.07085542e-05]]
# 2051 [[4.8875308e-05]]
# 2052 [[0.00027663]]
# 2053 [[2.04899999e-06]]
# 2054 [[0.25815299]]
# 2055 [[6.0919753e-07]]
# 2056 [[3.1830426e-08]]
# 2057 [[0.00525143]]
# 2058 [[7.77766179e-07]]
# 2059 [[2.02826989e-06]]
# 2060 [[2.22579523e-07]]
# 2061 [[0.47867629]]
# 2062 [[0.0010044]]
# 2063 [[0.00015498]]
# 2064 [[4.33803551e-06]]
# 2065 [[4.33803551e-06]]
# 2066 [[0.17999999]]
# 2067 [[0.00200007]]
# 2068 [[0.00034319]]
# 2069 [[0.58728951]]
# 2070 [[0.00172702]]
# 2071 [[0.05259793]]
# 2072 [[0.10176899]]
# 2073 [[0.06650989]]
# 2074 [[0.00011484]]
# 2075 [[0.00038932]]
# 2076 [[1.20788137e-05]]
# 2077 [[0.20248299]]
# 2078 [[0.01940883]]
# 2079 [[0.12925643]]
# 2080 [[0.0005459]]
# 2081 [[0.00016259]]
# 2082 [[0.07109939]]
# 2083 [[0.00067019]]
# 2084 [[1.61062362]]
# 2085 [[0.0389486]]
# 2086 [[0.24393151]]
# 2087 [[0.13280662]]
# 2088 [[30.03389099]]
# 2089 [[3.94904919]]
# 2090 [[107.18398508]]
# 2091 [[0.55595366]]
# 2092 [[3.11214724e-07]]
# 2093 [[1.05164764e-06]]
# 2094 [[1.68986836e-07]]
# 2095 [[1.93016109e-06]]
# 2096 [[4.01276851e-05]]
# 2097 [[2.49534425]]
# 2098 [[0.09672782]]
# 2099 [[0.20136696]]
# 2100 [[0.01136359]]
# 2101 [[9.62964964e-06]]
# 2102 [[1.28395328e-06]]
# 2103 [[1.1234591e-06]]
# 2104 [[3.73917819e-05]]
# 2105 [[9.44364017e-06]]
# 2106 [[2.5603192e-06]]
# 2107 [[3.17738811e-05]]
# 2108 [[2.08448617e-06]]
# 2109 [[4.48615381e-06]]
# 2110 [[3.01929146e-06]]
# 2111 [[2.90354308e-07]]
# 2112 [[8.43005155e-08]]
# 2113 [[4.64468541e-09]]
# 2114 [[2.69233458e-08]]
# 2115 [[2.32283446e-06]]
# 2116 [[4.64468541e-09]]
# 2117 [[2.44115487e-06]]
# 2118 [[2.09434528e-05]]
# 2119 [[2.69190252e-06]]
# 2120 [[0.0007848]]
# 2121 [[0.00197173]]
# 2122 [[0.01005025]]
# 2123 [[0.000316]]
# 2124 [[0.00363715]]
# 2125 [[0.00060812]]
# 2126 [[3.09244665e-08]]
# 2127 [[5.64884264e-08]]
# 2128 [[4.8506314e-11]]
# 2129 [[4.33861009e-09]]
# 2130 [[7.62407361e-08]]
# 2131 [[2.20819395e-06]]
# 2132 [[4.90430576e-08]]
# 2133 [[1.0377071e-06]]
# 2134 [[8.33144393e-08]]
# 2135 [[9.69105183e-08]]
# 2136 [[1.28614685e-07]]
# 2137 [[8.66212652e-07]]
# 2138 [[5.27906606e-07]]
# 2139 [[2.01907626e-05]]
# 2140 [[9.00382102e-07]]
# 2141 [[2.86586391e-10]]
# 2142 [[3.57731437e-08]]
# 2143 [[9.95467141e-09]]
# 2144 [[1.84065806e-07]]
# 2145 [[4.3691949e-05]]
# 2146 [[2.4101226e-06]]
# 2147 [[1.52917981e-07]]
# 2148 [[3.44471626e-08]]
# 2149 [[1.52225858e-08]]
# 2150 [[8.37632873e-07]]
# 2151 [[1.30729835e-05]]
# 2152 [[8.04720744e-09]]
# 2153 [[5.63034637e-07]]
# 2154 [[1.67706712e-06]]
# 2155 [[3.22218966e-05]]
# 2156 [[4.95136336e-10]]
# 2157 [[2.36449243e-06]]
# 2158 [[1.71897377e-07]]
# 2159 [[2.00447041e-06]]
# 2160 [[4.57584528e-08]]
# 2161 [[2.00748567e-09]]
# 2162 [[5.26586086e-11]]
# 2163 [[1.46200158e-07]]
# 2164 [[1.45320795e-05]]
# 2165 [[4.17847582e-08]]
# 2166 [[7.61540506e-09]]
# 2167 [[1.02560109e-07]]
# 2168 [[3.94555585e-06]]
# 2169 [[6.99812654e-06]]
# 2170 [[0.00012795]]
# 2171 [[1.93308077e-09]]
# 2172 [[3.16062751e-09]]
# 2173 [[1.20925097e-07]]
# 2174 [[4.1414404e-08]]
# 2175 [[8.11635342e-07]]
# 2176 [[7.13673126e-12]]
# 2177 [[2.28103483e-09]]
# 2178 [[1.79084498e-08]]
# 2179 [[1.86040665e-07]]
# 2180 [[1.47405763e-09]]
# 2181 [[1.11577968e-06]]
# 2182 [[5.56300384e-11]]
# 2183 [[3.53498762e-10]]
# 2184 [[1.15661501e-07]]
# 2185 [[2.71070587e-09]]
# 2186 [[5.02694322e-08]]
# 2187 [[1.7700505e-06]]
# 2188 [[2.48440802e-07]]
# 2189 [[1.37759138e-05]]
# 2190 [[5.7432173e-08]]
# 2191 [[3.42692327e-09]]
# 2192 [[1.69269233e-07]]
# 2193 [[2.52346166e-08]]
# 2194 [[1.76538476e-07]]
# 2195 [[1.73537587e-10]]
# 2196 [[4.89988476e-09]]
# 2197 [[1.4291331e-08]]
# 2198 [[5.00196579e-08]]
# 2199 [[9.18728405e-08]]
# 2200 [[4.56246695e-10]]
# 2201 [[5.26748396e-12]]
# 2202 [[1.88340251e-12]]
# 2203 [[3.1725764e-09]]
# 2204 [[6.31493779e-09]]
# 2205 [[1.76254239e-08]]
# 2206 [[1.53089395e-06]]
# 2207 [[2.72285278e-07]]
# 2208 [[9.14848449e-08]]
# 2209 [[1.90854182e-05]]
# 2210 [[6.19068536e-09]]
# 2211 [[2.36447088e-09]]
# 2212 [[7.48513074e-08]]
# 2213 [[2.14008733e-06]]
# 2214 [[5.12536484e-09]]
# 2215 [[1.09096118]]
# 2216 [[0.00990984]]
# 2217 [[0.0033]]
# 2218 [[10.4537525]]
# 2219 [[2.03140793e-06]]
# 2220 [[2.16524238e-06]]
# 2221 [[4.02047356e-09]]
# 2222 [[1.13134767e-09]]
# 2223 [[2.89008889e-07]]
# 2224 [[9.73292992e-08]]
# 2225 [[1.66013294e-07]]
# 2226 [[1.74605583e-06]]
# 2227 [[6.51760982e-06]]
# 2228 [[2.77246788e-05]]
# 2229 [[1.89435675e-06]]
# 2230 [[3.32851378e-06]]
# 2231 [[1.89617953e-07]]
# 2232 [[6.55115868e-07]]
# 2233 [[1.23333019e-08]]
# 2234 [[4.10934484e-08]]
# 2235 [[4.05837963e-09]]
# 2236 [[6.41853893e-06]]
# 2237 [[9.20590474e-06]]
# 2238 [[7.72648772e-09]]
# 2239 [[1.4333355e-07]]
# 2240 [[2.12401869e-05]]
# 2241 [[2.22790699e-07]]
# 2242 [[2.45629711e-06]]
# 2243 [[4.65730825e-06]]
# 2244 [[1.31728856e-06]]
# 2245 [[0.00014543]]
# 2246 [[0.00062353]]
# 2247 [[5.01020079e-09]]
# 2248 [[3.60320396e-09]]
# 2249 [[6.08343977e-07]]
# 2250 [[4.49952602e-07]]
# 2251 [[2.90577433e-06]]
# 2252 [[1.47363498e-07]]
# 2253 [[3.97491756e-08]]
# 2254 [[2.08834497e-05]]
# 2255 [[1.34978922e-07]]
# 2256 [[3.90300402e-06]]
# 2257 [[7.35302116e-05]]
# 2258 [[1.06074096e-06]]
# 2259 [[8.53522934e-07]]
# 2260 [[3.31520301e-07]]
# 2261 [[9.35303131e-06]]
# 2262 [[2.09855362e-06]]
# 2263 [[5.70129031e-10]]
# 2264 [[3.96590823e-08]]
# 2265 [[3.32423284e-08]]
# 2266 [[1.79757167e-08]]
# 2267 [[6.58920607e-09]]
# 2268 [[6.49934009e-08]]
# 2269 [[8.34125938e-07]]
# 2270 [[2.93298058e-06]]
# 2271 [[0.00019244]]
# 2272 [[5.45672474e-09]]
# 2273 [[1.32413047e-07]]
# 2274 [[4.85027166e-07]]
# 2275 [[1.34196146e-10]]
# 2276 [[4.41076256e-10]]
# 2277 [[9.55673389e-10]]
# 2278 [[3.35770204e-09]]
# 2279 [[1.40368645e-07]]
# 2280 [[1.29819537e-08]]
# 2281 [[2.23281666e-08]]
# 2282 [[7.66728515e-09]]
# 2283 [[3.33266639e-07]]
# 2284 [[1.63525123e-06]]
# 2285 [[2.15344101e-06]]
# 2286 [[2.26222511e-05]]
# 2287 [[1.56083576e-09]]
# 2288 [[7.45732607e-08]]
# 2289 [[2.94824521e-06]]
# 2290 [[66.79552339]]
# 2291 [[5.05746947e-08]]
# 2292 [[2.13913318e-10]]
# 2293 [[1.13940087e-10]]
# 2294 [[0.00029913]]
# 2295 [[2.33615286e-08]]
# 2296 [[5.07016576e-10]]
# 2297 [[4.46080866e-08]]
# 2298 [[6.12478106e-09]]
# 2299 [[6.29443948e-06]]
# 2300 [[2.9109853e-07]]
# 2301 [[7.36429456e-07]]
# 2302 [[2.84482667e-07]]
# 2303 [[1.82304138e-05]]
# 2304 [[1.27153285e-07]]
# 2305 [[1.00708334e-07]]
# 2306 [[1.61310978e-07]]
# 2307 [[2.86094898e-10]]
# 2308 [[1.17086989e-08]]
# 2309 [[6.39534647e-10]]
# 2310 [[1.17700807e-09]]
# 2311 [[2.6331326e-11]]
# 2312 [[4.23445983e-08]]
# 2313 [[2.30608665e-09]]
# 2314 [[2.38920487e-07]]
# 2315 [[3.84874378e-08]]
# 2316 [[1.49230061e-06]]
# 2317 [[3.47507005e-07]]
# 2318 [[1.46396288e-09]]
# 2319 [[1.47017766e-08]]
# 2320 [[8.62816025e-09]]
# 2321 [[3.20037388e-10]]
# 2322 [[2.28747443e-10]]
# 2323 [[0.00011408]]
# 2324 [[4.85841946e-06]]
# 2325 [[2.05598258e-07]]
# 2326 [[3.33753951e-06]]
# 2327 [[7.11824582e-05]]
# 2328 [[0.00010059]]
# 2329 [[1.31175141e-07]]
# 2330 [[5.6781568e-06]]
# 2331 [[2.75453508e-09]]
# 2332 [[2.57969549e-06]]
# 2333 [[8.61839463e-07]]
# 2334 [[2.40835669e-05]]
# 2335 [[4.92724684e-08]]
# 2336 [[9.09729012e-08]]
# 2337 [[1.32522769e-07]]
# 2338 [[1.1220125e-06]]
# 2339 [[6.92132216e-05]]
# 2340 [[8.15389394e-05]]
# 2341 [[2.80251991e-05]]
# 2342 [[1.14251393e-05]]
# 2343 [[1.34888782e-05]]
# 2344 [[1.86670135e-05]]
# 2345 [[1.42657177e-08]]
# 2346 [[1.94999994e-09]]
# 2347 [[2.7202175e-05]]
# 2348 [[2.27496856e-05]]
# 2349 [[7.22900005e-07]]
# 2350 [[6.43999988e-07]]
# 2351 [[2.4469208e-07]]
# 2352 [[4.16838699e-06]]
# 2353 [[2.34121051e-06]]
# 2354 [[0.00010803]]
# 2355 [[3.78824896e-09]]
# 2356 [[3.44745243e-06]]
# 2357 [[0.00722761]]
# 2358 [[0.00091325]]
# 2359 [[4.44139161e-05]]
# 2360 [[0.02244766]]
# 2361 [[3.25196816e-05]]
# 2362 [[4.25804812e-05]]
# 2363 [[0.09463406]]
# 2364 [[5.26026285e-08]]
# 2365 [[3.80313212e-09]]
# 2366 [[2.79801799e-10]]
# 2367 [[1.21839158e-06]]
# 2368 [[2.57359067e-08]]
# 2369 [[1.54822848e-08]]
# 2370 [[1.4222851e-06]]
# 2371 [[1.53142831e-06]]
# 2372 [[3.5444752e-08]]
# 2373 [[2.1919777]]
# 2374 [[0.02723973]]
# 2375 [[1.66100001e-07]]
# 2376 [[1.06407398e-07]]
# 2377 [[7.47044854e-06]]
# 2378 [[4.40483376e-05]]
# 2379 [[6.26619894e-06]]
# 2380 [[0.00341859]]
# 2381 [[0.0959542]]
# 2382 [[0.25884245]]
# 2383 [[119.62982672]]
# 2384 [[6.67032123e-05]]
# 2385 [[3.97588596]]
# 2386 [[13.88295447]]
# 2387 [[0.00545356]]
# 2388 [[0.18077036]]
# 2389 [[6.69352061e-07]]
# 2390 [[1.22946197e-05]]
# 2391 [[0.00358305]]
# 2392 [[2.72088611e-05]]
# 2393 [[6440.18289962]]
# 2394 [[0.02627099]]
# 2395 [[7.00000063e-06]]
# 2396 [[0.27595115]]
# 2397 [[52.48443717]]
# 2398 [[0.01995435]]
# 2399 [[0.52465818]]
# 2400 [[0.00069604]]
# 2401 [[66.86962288]]
# 2402 [[10420237.29197147]]
# 2403 [[0.00608215]]
# 2404 [[0.02756267]]
# 2405 [[301.11183584]]
# 2406 [[0.00465011]]
# 2407 [[247.37249455]]
# 2408 [[288.53324901]]
# 2409 [[6.3978664e-06]]
# 2410 [[0.01201686]]
# 2411 [[6.85759819]]
# 2412 [[2.09383687]]
# 2413 [[20300152.33214365]]
# 2414 [[3.32885574]]
# 2415 [[0.00026557]]
# 2416 [[8.34999431]]
# 2417 [[90681247.23443797]]
# 2418 [[4.99457677]]
# 2419 [[15.50916914]]

# %%
for x in list(np.argwhere(lca.in)):
    print(bw.get_activity(act_dict[x[0]])["name"])
# Out:
# market for cyanuric chloride
# market for silicon, multi-Si, casted
# treatment of waste plastic, industrial electronics, municipal incineration
# market for compressed air, 700 kPa gauge
# electricity production, photovoltaic, 570kWp open ground installation, multi-Si
# photovoltaic laminate production, a-Si
# electricity voltage transformation from medium to low voltage
# market for used locomotive
# market for bottom ash, MSWI-WWT, WW from medium density board production
# market for uranium hexafluoride
# maintenance, goods wagon
# market for sodium silicate, solid
# market for graphite
# market for gravel, crushed
# primary lead production from concentrate
# electricity voltage transformation from medium to low voltage
# market for aniline
# market for inorganic potassium fertiliser, as K2O
# calcareous marl production
# treatment of waste paper, unsorted, sorting
# treatment of waste graphical paper, unsanitary landfill, dry infiltration class (100mm)
# planing, beam, softwood, u=20%
# nutrient supply from urea ammonium nitrate mix
# natural gas production, liquefied
# electricity production, photovoltaic, 3kWp slanted-roof installation, single-Si, panel, mounted
# anode production, prebake, for aluminium electrolysis
# single-Si wafer production, for electronics
# tap water production, underground water without treatment
# electricity production, coal, aluminium industry
# market for waste polyvinylchloride
# electricity production, hydro, run-of-river
# electricity, high voltage, import from ME
# market for waste polystyrene
# natural gas pressure reduction, from high to low pressure
# polystyrene production, expandable
# market for electric arc furnace secondary metallurgy slag, for recovery
# chemical factory construction
# market for electricity, low voltage
# electricity production, oil
# electricity production, natural gas, conventional power plant
# wastewater treatment facility construction, capacity 5E9l/year
# treatment of waste bulk iron, excluding reinforcement, sorting plant
# electricity production, wind, <1MW turbine, onshore
# market for potato seed, for setting
# anodising, aluminium sheet
# transistor production, auxilliaries and energy use
# treatment of precious metal from electronics scrap, in anode slime, precious metal extraction
# natural gas, high pressure, import from FI
# water pump operation, electric
# treatment of bagasse, from sugarcane, in heat and power co-generation unit, 6400kW thermal
# diesel, low-sulfur, import from RoW
# market for electricity, low voltage
# electricity, high voltage, import from NL
# hot rolling, steel
# heat and power co-generation, diesel, 200kW electrical, SCR-NOx reduction
# purse seiner maintenance, steel
# heat and power co-generation unit construction, 200kW electrical, common components for heat+electricity
# electricity production, hard coal
# market for transport, pipeline, onshore, petroleum
# market for palm kernel meal
# treatment of waste graphical paper, open dump, very wet infiltration class (1000mm)
# phosphate rock beneficiation
# electricity production, wind, <1MW turbine, onshore
# treatment of waste mineral wool, collection for final disposal
# market for sewage sludge, 97% water, WWT, WW, average
# treatment of used beverage cans, for recycling, unsorted, sorting
# market for mounting, through-hole technology, Pb-containing solder
# market for synthetic graphite, battery grade
# heat and power co-generation, wood chips, 6667 kW
# selective coating, copper sheet, physical vapour deposition
# propylene production
# market for electricity, medium voltage
# market for condensate from light oil boiler
# electricity voltage transformation from medium to low voltage
# natural gas, liquefied, import from ID
# eucalyptus seedling production, in unheated greenhouse
# market for recultivation, ilmenite mine
# market for hard coal
# market for waste packaging paper
# burnt shale production
# nutrient supply from urea ammonium nitrate mix
# market for ceramic tile
# cement production, CEM II/B-V
# cement production, CEM V/A
# container production, for collection of post-consumer waste plastic for recycling
# transport, freight, lorry 16-32 metric ton, EURO5
# market for electricity, low voltage
# market for transport, freight, light commercial vehicle
# indium tin oxide powder production, nanoscale, for sputtering target
# fish oil to generic market for energy feed
# treatment of sewage sludge, 75% water, WWT, WW from LCD backlight production, sanitary landfill
# tillage, ploughing
# market for green manure, organic, until March
# market for sewage sludge, 75% water, WWT, rainwater mineral oil storage
# iron sinter production
# water pump operation, electric
# electricity production, oil
# market for inorganic nitrogen fertiliser, as N
# electricity production, wind, <1MW turbine, onshore
# electricity, high voltage, import from PY
# rare earth element mine operation and beneficiation, ion adsorption clays
# electricity production, wind, 1-3MW turbine, onshore
# market for electricity, low voltage
# forwarder production, with terrain chipper
# market for waste brick
# market for inorganic phosphorus fertiliser, as P2O5
# electricity, high voltage, import from BG
# treatment of precious metal from electronics scrap, in anode slime, precious metal extraction
# market for diode, glass-, for through-hole mounting
# textile production, cotton, weaving
# market for road
# land already in use, perennial cropland to perennial crop
# market for ceramic factory
# electricity production, oil
# retention aid production, for paper production
# market for limestone, crushed, for mill
# hardwood forestry, oak, sustainable forest management
# phosphorous chloride production
# market for plywood
# planing, board, softwood, u=10%
# purified terephthalic acid production
# municipal waste collection service by 21 metric ton lorry
# treatment of waste polypropylene, municipal incineration with fly ash extraction
# market for waste glass
# uranium production, centrifuge, enriched 4.0%
# pentane production
# market for residues, MSWI-WWT, WW from ceramic production
# boric acid production, anhydrous, powder
# cottonseed, organic to generic market for energy feed
# treatment of scrap copper, municipal incineration
# cement production, type IP/P
# market for sewage sludge, 97% water, WWT, WW, average
# market for hexafluoroethane
# treatment of bottom ash, MSWI-WWT, WW from hard fibreboard production, slag compartment
# market for display, liquid crystal, 17 inches
# market for capacitor, film type, for through-hole mounting
# market for electricity, medium voltage
# market for waste polyurethane
# assembly of generator and motor, auxilliaries and energy use, heat and power co-generation unit, 160kW electrical
# treatment of refractory spent pot liner from Al electrolysis, residual material landfill
# market for green manure, organic, until February
# electricity production, lignite
# market for asbestos, crysotile type
# transport, freight, small lorry with refrigeration machine, EURO4, R134a refrigerant, cooling to generic market
# market for maize seed, Swiss integrated production, for sowing
# aluminium, ingot, primary, import from South America
# tetrachloroethylene production
# pyrethroid-compound production
# lime production, milled, loose
# electricity production, natural gas, conventional power plant
# market for electricity, high voltage
# electricity production, oil
# market for clinker
# electricity voltage transformation from high to medium voltage
# tillage, currying, by weeder
# market for plaster mixing
# market for waste wood, untreated
# electricity production, hydro, reservoir, non-alpine region
# maintenance, lorry 28 metric ton
# cobalt sulfate production
# recultivation, limestone mine
# electricity production, wind, 1-3MW turbine, onshore
# recultivation, iron mine
# magnesium factory construction
# heat and power co-generation unit construction, organic Rankine cycle, 1000kW electrical
# market for sawnwood, board, hardwood, raw, dried (u=20%)
# kerosene production, petroleum refinery operation
# treatment of blast furnace gas, in power plant
# uranium production, centrifuge, enriched 4.2%
# treatment of blast furnace gas, in power plant
# treatment of spent activated carbon, granular from hard coal, reactivation
# market for electricity, high voltage
# vegetable oil esterification facility construction
# electricity voltage transformation from medium to low voltage
# board, hardwood, raw, air drying to u=20%
# electricity, high voltage, import from AT
# market for electricity, for reuse in municipal waste incineration only
# treatment of spent nuclear fuel, conditioning
# particleboard production, cement bonded
# market for ferrite
# combine harvesting
# trimethyl borate production
# hard coal, import from AU
# market for polyol
# market for light emitting diode
# market for nuclear fuel element, for pressure water reactor, UO2 4.0% & MOX
# market for inorganic nitrogen fertiliser, as N
# market for electricity, medium voltage
# market for ethyl benzene
# electricity production, oil
# machine construction, for treatment of waste electric and electronic equipment
# concrete production, 40MPa, for building construction, with cement, CEM III/A
# electricity, high voltage, import from ME
# market for foaming agent
# urea production
# market for waste concrete, not reinforced
# photovoltaic slanted-roof installation, 3kWp, multi-Si, laminated, integrated, on roof
# electricity production, hard coal
# electronic component machinery production, unspecified
# kenaf production, irrigated
# market for land use change, annual crop
# market for waste plastic, mixture
# electricity production, hydro, run-of-river
# market for cement, CP V RS
# water pump operation, electric
# market for energy requirement for assembly of heat and power co-generation unit, 160kW electrical
# cross-laminated timber production
# synthetic graphite production, battery grade
# market for waste polyurethane
# treatment of waste paint, sanitary landfill
# electricity production, oil
# market for irrigation
# market for blast furnace sludge, for recovery
# sugarcane processing, traditional annexed plant
# cobalt production
# furnace production, logs, average storage area, 100kW
# market for transport, freight, lorry >32 metric ton, EURO3
# market group for electricity, low voltage
# fibre production, cotton, organic, ginning
# mine construction, open cast, non-ferrous metal
# market for waste polyvinylchloride
# treatment of spent sawing slurry from Si-wafer cutting
# market for cement, Portland
# market for waste polyethylene terephthalate
# transport, freight, lorry 16-32 metric ton, unregulated
# hay production
# market for selective coat, copper sheet, physical vapour deposition
# transport, freight, conveyor belt
# market for containerboard, linerboard
# ultrafiltration module production, hollow fiber
# electricity voltage transformation from medium to low voltage
# market for concrete, medium strength
# market for soybean, feed
# clay pit construction
# market for sewage sludge, 97% water, WWT, WW from plywood production
# market for hoeing
# electricity production, natural gas, conventional power plant
# concrete production, 30MPa, for drilled piles, with cement, Portland
# aclonifen production
# treatment of waste polyurethane, sanitary landfill
# market for plasticiser, for concrete, based on sulfonated melamine formaldehyde
# heat, from municipal waste incineration to generic market for heat district or industrial, other than natural gas
# electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted
# clinker production
# heat and power co-generation, biogas, gas engine
# rape oil mill operation
# market for potato planting
# market for waste textile, soiled
# treatment of waste sealing sheet, polyethylene, municipal incineration with fly ash extraction
# electricity production, photovoltaic, 3kWp slanted-roof installation, single-Si, panel, mounted
# photovoltaic slanted-roof installation, 3kWp, CdTe, laminated, integrated, on roof
# electricity production, wind, 1-3MW turbine, offshore
# chlor-alkali electrolysis, mercury cell
# market for shredder fraction after manual dismantling of used electronic product
# electricity production, natural gas, combined cycle power plant
# petroleum and gas production, onshore
# market for electronics, for control units
# heat production, wood pellet, at furnace 25kW, state-of-the-art 2014
# market group for electricity, high voltage
# titanium dioxide production, sulfate process
# market for process-specific burdens, slag landfill
# electricity production, wind, <1MW turbine, onshore
# market for biogas
# heat production, softwood chips from forest, at furnace 50kW
# planing, beam, hardwood, u=20%
# market for waste concrete gravel
# board, softwood, raw, kiln drying to u=10%
# market for coal slurry
# heat and power co-generation, lignite
# market for wastewater from plywood production
# electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted
# market for waste plastic, mixture
# cable production, network cable, category 5, without plugs
# gypsum quarry operation
# market for used railway track
# water works construction, capacity 6.23E10l/year, seawater reverse osmosis, conventional pretreatment
# primary zinc production from concentrate
# transport, freight, lorry 3.5-7.5 metric ton, EURO5
# water production, completely softened
# market for steel removed by milling, average
# planing, board, hardwood, u=10%
# treatment of blast furnace gas, in power plant
# sodium pyrophosphate production
# market for electricity, for reuse in municipal waste incineration only
# market for sugarcane
# land already in use, perennial cropland to perennial crop
# market for waste plastic, mixture
# fibre cement facing tile production, small format
# market for lignite ash
# ammonia production, steam reforming, liquid
# suction, sawdust
# market group for electricity, low voltage
# sanitary ceramics production
# propanal production
# sowing
# heat and power co-generation, biogas, gas engine
# treatment of electric arc furnace dust, residual material landfill
# clinker production
# treatment of blast furnace gas, in power plant
# market for waste polyethylene terephthalate
# electricity production, natural gas, conventional power plant
# glued solid timber production
# treatment of waste sealing sheet, polyvinylchloride, municipal incineration with fly ash extraction
# heat and power co-generation, natural gas, 160kW electrical, lambda=1
# treatment of waste paint, municipal incineration
# electricity production, oil
# polymethyl methacrylate production, beads
# market group for electricity, low voltage
# market for triple superphosphate
# electricity production, oil
# acetaldehyde oxidation
# beam, softwood, raw, kiln drying to u=20%
# market for petrol, unleaded, burned in machinery
# processing of anode slime from electrorefining of copper, anode
# treatment of residue from mechanical treatment, industrial device, municipal incineration with fly ash extraction
# market for fatty acid methyl ester
# wax production, for lost-wax metal casting
# treatment of waste paint on wood, collection for final disposal
# heat and power co-generation, hard coal
# electricity production, hydro, pumped storage
# market for inorganic nitrogen fertiliser, as N
# electricity production, natural gas, conventional power plant
# aircraft production, dedicated freight aircraft, medium haul
# heavy water production
# deep well drilling, for deep geothermal power
# hard coal power plant construction, 500MW
# treatment of sewage sludge by anaerobic digestion
# ethylene glycol monoethyl ether production
# thermal storage system construction, solar tower power plant, 20 MW
# transport, pipeline, onshore, long distance, natural gas
# photovoltaic laminate production, multi-Si wafer
# heat production, softwood chips from forest, at furnace 5000kW
# market for polyurethane, rigid foam
# molecular sieve separation of naphtha
# market for sewage sludge, 70% water, WWT, WW from concrete production
# market for inorganic nitrogen fertiliser, as N
# market for electricity, high voltage
# market for acrylonitrile
# chemi-thermomechanical pulp production
# silicon production, multi-Si, casted
# barley production, organic
# sorting facility construction, for construction waste
# market for polyvinylfluoride
# heat and power co-generation, hard coal
# treatment of spent Formox catalyst base from formaldehyde production, residual material landfill
# electricity production, oil
# market for electricity, medium voltage
# oxidation of butane
# electricity production, oil
# electricity production, deep geothermal
# electricity production, oil
# electricity production, photovoltaic, 3kWp slanted-roof installation, single-Si, panel, mounted
# market for electricity, low voltage
# sulfate pulp production, from softwood, bleached
# dichloromethane production
# processing of anode slime from electrorefining of copper, anode
# market for diesel, burned in building machine
# treatment of scrap tin sheet, sanitary landfill
# heat, from municipal waste incineration to generic market for heat district or industrial, other than natural gas
# fish residues, Recycled Content cut-off
# electricity, high voltage, import from CN-NCGC
# market for ammonium nitrate phosphate
# market for waste polypropylene
# electricity production, hydro, pumped storage
# photovoltaic slanted-roof installation, 3kWp, a-Si, panel, mounted, on roof
# market for transport, freight, lorry >32 metric ton, unregulated
# printed wiring board production, surface mounted, unspecified, Pb free
# market for wood preservation, vacuum pressure method, inorganic salt, containing Cr, outdoor use, ground contact
# laminated timber element production, for outdoor use
# market group for electricity, medium voltage
# electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted
# market for benzoic acid
# heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical
# market for sodium amide
# ammonium carbonate production
# treatment of wastewater from grass refinery, wastewater treatment
# market for sewage sludge, 75% water, WWT, WW from particle board production
# petrol, low-sulfur, import from Europe
# electricity production, wind, <1MW turbine, onshore
# treatment of sewage sludge, 70% water, WWT, WW from liquid crystal production, municipal incineration
# electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted
# electricity production, photovoltaic, 570kWp open ground installation, multi-Si
# petroleum and gas production, offshore
# market for waste polyethylene terephthalate
# electricity, high voltage, import from BE
# electricity production, wind, <1MW turbine, onshore
# market for inorganic phosphorus fertiliser, as P2O5
# land already in use, perennial cropland to annual crop
# electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted
# market group for electricity, low voltage
# treatment of sewage sludge, 75% water, WWT[U], WW from lorry production, sanitary landfill
# electricity production, oil
# electricity voltage transformation from high to medium voltage
# heat and power co-generation, natural gas, conventional power plant, 100MW electrical
# irrigation, sprinkler
# furnace production, wood chips, with silo, 1000kW
# phosphoric acid production, dihydrate process
# market for sputtering, indium tin oxide, for liquid crystal display
# treatment of waste gypsum, sanitary landfill
# market for clover seed, Swiss integrated production, at farm
# market for waste glass
# market for isobutanol
# heat and power co-generation, wood chips, 6667 kW
# transport, freight, lorry with refrigeration machine, 3.5-7.5 ton, EURO6, carbon dioxide, liquid refrigerant, cooling
# aluminium oxide production
# petroleum and gas production, offshore
# electricity voltage transformation from medium to low voltage
# petroleum and gas production, onshore
# market for sodium silicate, without water, in 37% solution state
# market for transport, freight, lorry >32 metric ton, EURO1
# market for contouring, brass
# market for waste polypropylene
# hard coal, import from ID
# electricity voltage transformation from high to medium voltage
# electricity production, natural gas, combined cycle power plant
# electricity voltage transformation from high to medium voltage
# market for inorganic phosphorus fertiliser, as P2O5
# electricity production, wind, 1-3MW turbine, onshore
# treatment of spent anion exchange resin from potable water production, municipal incineration
# market for mowing, by rotary mower
# sugarcane processing, traditional annexed plant
# basic oxygen furnace slag to market for basic oxygen furnace slag, for recovery
# water pump operation, diesel
# fatty acid production, from palm kernel oil
# market for sewage sludge, 97% water, WWT, WW from PV cell production
# slab and siding, softwood, wet, measured as dry mass to generic market for residual softwood, wet
# market for electricity, high voltage
# primary zinc production from concentrate
# sodium sulfate production, from natural sources
# market for carbon dioxide, liquid
# clear-cutting, grassland to arable land, perennial crop
# market for ground granulated blast furnace slag
# hard coal mine operation and hard coal preparation
# drying of maize straw and whole-plant
# market for transport, freight, lorry 3.5-7.5 metric ton, unregulated
# market for maize seed, for sowing
# market for refinery sludge
# market for rainwater mineral oil storage
# heat and power co-generation, biogas, gas engine
# market for tin concentrate
# electricity voltage transformation from high to medium voltage
# heat production, mixed logs, at wood heater 6kW
# extrusion of plastic sheets and thermoforming, inline
# electricity production, oil
# municipal waste incineration facility construction
# compressed air production, 800 kPa gauge, <30kW, optimized generation
# electricity, high voltage, import from AT
# treatment of metal scrap, mixed, for recycling, unsorted, sorting
# market for waste graphical paper
# electricity production, photovoltaic, 3kWp slanted-roof installation, single-Si, panel, mounted
# market for land use change, perennial crop
# photovoltaic cell production, multi-Si wafer
# market for blast furnace slag
# market for waste yarn and waste textile
# market for municipal solid waste
# market for sewage sludge, 70% water, WWT, WW from LCD backlight production
# market for waste polystyrene
# sawing, hardwood
# steel production, converter, unalloyed
# market for irrigation
# electricity, high voltage, import from ZW
# market for wastewater from soft fibreboard production
# treatment of municipal solid waste, municipal incineration with fly ash extraction
# market for electricity, low voltage
# maintenance, reefer, intermodal shipping container, 40-foot, high-cube
# pipeline construction, natural gas, low pressure distribution network
# market for cadmium chloride, semiconductor-grade
# treatment of decommissioned road
# market for zeolite, slurry, without water, in 50% solution state
# lithium carbonate production, from spodumene
# market for waste polyethylene terephthalate
# market for urea
# market for light fuel oil
# treatment of residue from TiO2 production, sulfate process, residual material landfill
# esters of versatic acid production
# building construction, multi-storey
# treatment of residue from mechanical treatment, desktop computer, municipal incineration with fly ash extraction
# catalytic converter production, three-way, mini CHP plant
# tap water production, conventional treatment
# market for electricity, high voltage
# market for waste polyvinylfluoride
# transport, freight, lorry >32 metric ton, EURO2
# electricity, high voltage, import from IN-Western grid
# heat and power co-generation, natural gas, conventional power plant, 100MW electrical
# treatment of bottom ash, MSWI[F]-WWT, WW from LCD backlight production, slag compartment
# market for waste wood pole, chrome preserved
# market for transport, freight, train with reefer, cooling
# planting
# heat and power co-generation, hard coal
# market for electricity, medium voltage
# uranium hexafluoride production
# market for purge gas, rich in sodium nitrate
# market for waste polyethylene
# heat and power co-generation unit construction, 6400kW thermal, common components for heat+electricity
# electricity production, hydro, run-of-river
# electricity production, hydro, run-of-river
# market for feldspar
# sodium phenolate production
# treatment of bilge oil, hazardous waste incineration
# cement production, CEM V/B
# treatment of sewage sludge, 75% water, WWT, WW from hard fibreboard production, sanitary landfill
# market for transport, freight, lorry with refrigeration machine, 7.5-16 ton, EURO3, R134a refrigerant, cooling
# electricity production, natural gas, conventional power plant
# catalytic converter production, oxidation, 20 litre
# paraffin production
# market for bottom ash, MSWI[F]-WWT, WW from pig iron production
# market for inorganic potassium fertiliser, as K2O
# market for hard coal
# treatment of waste polyurethane, municipal incineration
# meat and bone meal to generic market for protein feed
# treatment of waste paint on wood, collection for final disposal
# market for anaerobic digestion plant, agriculture, with methane recovery
# electricity production, wind, 1-3MW turbine, onshore
# market for photovoltaic laminate, CdTe
# market group for electricity, medium voltage
# electricity production, hydro, reservoir, non-alpine region
# market for transport, freight, light commercial vehicle
# treatment of waste bulk iron, excluding reinforcement, sorting plant
# medium density fibreboard production, uncoated
# vinyl fluoride production
# market for storage, 10'000 l
# electricity production, wind, 1-3MW turbine, onshore
# market for scrap aluminium
# particleboard production, uncoated, average glue mix
# market for cement, type I (SM)
# market for 2-butanol
# market for nickel sulfate
# treatment of municipal solid waste, incineration
# electricity, high voltage, import from AT
# market for natural gas, low pressure
# heat and power co-generation, biogas, gas engine
# market for electricity, medium voltage
# market for sewage sludge, 70% water, WWT, WW from vegetable oil refinery
# folding boxboard carton production
# heat and power co-generation, natural gas, conventional power plant, 100MW electrical
# market for waste polyethylene
# polyvinylfluoride production, dispersion
# iron(III) chloride production, product in 40% solution state
# market for residues, MSWI[F]-WWT, WW, average
# electricity production, natural gas, conventional power plant
# cobalt production
# treatment of condensate from light oil boiler, wastewater treatment
# treatment of precious metal from electronics scrap, in anode slime, precious metal extraction
# fibre cement facing tile production
# market for harvesting, by complete harvester, ground crops
# market for electricity, for reuse in municipal waste incineration only
# market for wood preservative, creosote
# treatment of waste reinforcement steel, recycling
# market for wastewater from liquid crystal display backlight production
# tetrafluoroethylene production
# market for waste reinforcement steel
# heat and power co-generation, natural gas, conventional power plant, 100MW electrical
# electricity production, photovoltaic, 3kWp slanted-roof installation, single-Si, panel, mounted
# clay pit construction
# market for ethylene vinyl acetate copolymer
# photovoltaic laminate production, CdTe
# cement factory construction
# transport, freight, lorry >32 metric ton, EURO5
# treatment of sulfidic tailings, from silver mine operation, tailings impoundment
# market for inorganic phosphorus fertiliser, as P2O5
# pentaerythritol production in sodium hydroxide solution
# heat and power co-generation, natural gas, conventional power plant, 100MW electrical
# treatment of waste graphical paper, sanitary landfill
# market for hot rolling, steel
# electricity production, oil
# fibre production, cotton, ginning
# heat and power co-generation, biogas, gas engine
# land already in use, perennial cropland to perennial crop
# electricity production, natural gas, combined cycle power plant
# selective coating, copper sheet, black chrome
# electricity production, wind, <1MW turbine, onshore
# electricity production, wind, <1MW turbine, onshore
# electricity voltage transformation from high to medium voltage
# plastic processing factory construction
# electricity production, hydro, reservoir, non-alpine region
# sweet sorghum production
# shavings, hardwood, measured as dry mass to generic market for residual wood, dry
# market for triazine-compound, unspecified
# market for grass, Swiss integrated production
# fleece production, polyethylene
# board, hardwood, raw, kiln drying to u=20%
# heat production, hard coal coke, stove 5-15kW
# compressed air production, 1000 kPa gauge, <30kW, optimised generation
# market for electricity, medium voltage
# soybean meal and crude oil production, mechanical extraction
# treatment of precious metal from electronics scrap, in anode slime, precious metal extraction
# market for waste paperboard
# market for diesel
# esterification of palm oil
# iron(III) sulfate production, without water, in 12.5% iron solution state
# heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical
# ethylene vinyl acetate copolymer production
# treatment of waste building wood, chrome preserved, municipal incineration with fly ash extraction
# acrylic binder production, with water, in 54% solution state
# electricity, high voltage, import from CZ
# citric acid production
# green manure growing, Swiss integrated production, until March
# market for residues, MSWI-WWT, WW from maize starch production
# market for argon, liquid
# market for transport, freight, lorry 7.5-16 metric ton, EURO1
# market for water storage
# resistor production, surface-mounted
# kerosene, import from RoW
# heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical
# electricity production, oil
# market for non-Fe-Co-metals, from Li-ion battery, hydrometallurgical processing
# electricity production, natural gas, conventional power plant
# electricity voltage transformation from high to medium voltage
# transmission network construction, electricity, high voltage direct current subsea cable
# electricity production, photovoltaic, 3kWp slanted-roof installation, single-Si, panel, mounted
# market for glider, passenger car
# electricity production, nuclear, pressure water reactor, heavy water moderated
# drying of maize grain
# electricity production, natural gas, conventional power plant
# electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted
# section bar rolling, steel
# natural gas production, liquefied
# electricity voltage transformation from medium to low voltage
# market for waste paperboard
# rape oil mill operation
# market for calcareous marl
# ethylene production, average
# electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted
# hydrazine production
# treatment of sewage sludge, 70% water, WWT, WW from maize starch production, municipal incineration FAE
# heat production, wood chips from industry, at furnace 50kW, state-of-the-art 2014
# fibre production, kenaf, retting
# natural gas, high pressure, import from RU
# sound insulation construction, heat and power co-generation unit, 160kW electrical
# natural gas, high pressure, import from NL
# water works construction, capacity 1.1E10l/year, direct filtration treatment
# lithium manganese oxide production
# market for argon, liquid
# sweet sorghum production
# diammonium phosphate production
# zirconium and hafnium tetrachloride production, from zircon
# operation, housing system, cattle, loose
# land already in use, perennial cropland to perennial crop
# electricity production, oil
# market for sewage sludge, 75% water, WWT, WW from GGBFS production
# transport, tractor and trailer, agricultural
# market for sawnwood, hardwood, raw, dried (u=20%)
# market for butane
# maize grain production
# market for cottonseed oil, crude
# sodium chloride electrolysis
# market for waste glass
# potassium chloride production
# planing, beam, softwood, u=10%
# treatment of waste building wood, chrome preserved, municipal incineration
# treatment of sewage sludge, 70% water, WWT, WW from potato starch production, municipal incineration FAE
# land already in use, annual cropland to perennial crop
# uranium mill construction
# heat production, mixed logs, at furnace 100kW
# barley production
# electricity production, photovoltaic, 570kWp open ground installation, multi-Si
# biomethane production, high pressure from synthetic gas, wood, fluidised technology
# evacuated tube collector production
# dolomite production
# treatment of coal gas, in power plant
# deep well drilling, for deep geothermal power
# calcium ammonium nitrate production
# market group for waste wood, untreated
# limestone quarry construction
# electricity voltage transformation from high to medium voltage
# N,N-dimethylformamide production
# treatment of residue from mechanical treatment, liquid crystal display, municipal incineration with fly ash extraction
# soybean meal and crude oil production, mechanical extraction
# barley production, organic
# vanadium-titanomagnetite mine operation and beneficiation
# electricity production, deep geothermal
# market for triphenyl phosphate
# heat, from municipal waste incineration to generic market for heat district or industrial, other than natural gas
# anthraquinone production
# wheat production, organic
# propane, burned in building machine
# market for xylene
# market for waste polystyrene
# fluorination of sodium tetrahydridoborate
# electricity production, wind, >3MW turbine, onshore
# concrete production, 20MPa, self-construction, for building construction, with cement, type general use
# electricity, high voltage, import from VN
# market for waste plastic, mixture
# market for assembly of liquid crystal display, auxilliaries and energy use
# market for sanitary landfill facility
# market for electricity, for reuse in municipal waste incineration only
# cement production, CEM II/B
# electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted
# treatment of metal part of electronics scrap, in copper, anode, by electrolytic refining
# market for wooden board factory, organic bonded boards
# market for housing system, cattle, loose, per animal unit
# electricity production, hard coal
# cement production, CP V RS
# treatment of bilge oil, hazardous waste incineration, with energy recovery
# furnace production, wood chips, with silo, 1000kW
# market for passenger car, petrol/natural gas
# treatment of waste polyvinylchloride, unsanitary landfill, very wet infiltration class (1000mm)
# uranium production, centrifuge, enriched 3.8%
# drying of maize grain
# market for water, decarbonised
# market for bottom ash, MSWI-WWT, WW from GGBFS production
# building construction, hall, wood construction
# sulfur dioxide production, liquid
# electricity production, hydro, aluminium industry
# market for diesel
# clinker production
# natural gas, high pressure, import from NG
# ethanol production from whey
# refractory production, high aluminium oxide, packed
# market for residues, MSWI-WWT, WW from vegetable oil refinery
# market for captan
# transport, freight, aircraft, dedicated freight, long haul
# kerosene, import from RoW
# natural gas, high pressure, import from GB
# electricity production, natural gas, combined cycle power plant
# electricity production, hydro, pumped storage
# market for sewage sludge, 97% water, WWT, WW from particle board production
# irrigation, surface
# market for photovoltaic panel, CIS
# road construction, company, internal
# market for sulfur trioxide
# cottonseed oil, refined, to generic market for vegetable oil, refined
# electricity, high voltage, import from DE
# treatment of municipal solid waste, incineration
# treatment of sewage sludge, 70% water, WWT, WW from LCD production, municipal incineration FAE
# market for electricity, medium voltage
# electricity, high voltage, import from MZ
# electricity voltage transformation from medium to low voltage
# market for electricity, low voltage
# treatment of waste polyvinylchloride, open burning
# soybean production
# thermal storage system construction, solar thermal parabolic trough, 50 MW
# market for transport, freight, lorry 16-32 metric ton, EURO4
# electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted
# market for waste polystyrene
# treatment of waste mineral oil, hazardous waste incineration, with energy recovery
# ethylene glycol production
# petroleum and gas production, onshore
# electricity, high voltage, import from CA-SK
# pig iron production
# market for diesel, low-sulfur
# treatment of municipal solid waste, incineration
# market for sewage sludge, 97% water, WWT, WW from liquid crystal production
# market for land use change, annual crop
# market for waste plastic, mixture
# planing, beam, hardwood, u=10%
# electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted
# anti-reflex-coating, etching, solar glass
# market for photovoltaic panel, a-Si
# heat and power co-generation unit construction, 1MW electrical, components for heat only
# heat and power co-generation, oil
# strawberry production, in heated greenhouse
# market for bottom ash, MSWI-WWT, WW from hard fibreboard production
# sawnwood production, softwood, dried (u=10%), planed
# market for naphtha
# sawing, hardwood
# ammonium bicarbonate production
# market for inorganic nitrogen fertiliser, as N
# market for residue from Na-dichromate production
# treatment of waste graphical paper, open dump, moist infiltration class (300mm)
# goods wagon production
# market for rape meal
# treatment of municipal solid waste, incineration
# market for inorganic phosphorus fertiliser, as P2O5
# decarboxylative cyclization of adipic acid
# market for heat, for reuse in municipal waste incineration only
# heat and power co-generation, natural gas, conventional power plant, 100MW electrical
# electricity production, photovoltaic, 570kWp open ground installation, multi-Si
# concrete production, 20MPa, with cement, CEM II/B-V
# sunflower seed production, for sowing
# market for light fuel oil
# fruit tree seedling production, for planting
# market for dross from Al electrolysis
# market for residues, MSWI-WWT, WW from glass production
# glyphosate production
# cement production, CEM II/B
# market for light commercial vehicle
# cement production, CEM II/A
# citric acid production
# iron sulfate production
# lime production, hydrated, packed
# market for waste electric wiring
# market for inorganic potassium fertiliser, as K2O
# market for sawnwood, board, hardwood, dried (u=20%), planed
# market for waste packaging paper
# heat and power co-generation, hard coal
# market for electricity, for reuse in municipal waste incineration only
# captan production
# market for zinc in car shredder residue
# market for transport, freight, sea, bulk carrier for dry goods
# transport, freight, lorry 3.5-7.5 metric ton, EURO1
# market for concrete, 50MPa
# market for ozone, liquid
# market for wheat seed, for sowing
# heat and power co-generation, oil
# treatment of wastewater from liquid crystal production, wastewater treatment
# market for wastewater from black chrome coating
# packaging film production, low density polyethylene
# market for refractory, basic, packed
# planing, board, softwood, u=20%
# market for methanol, from biomass
# market for sewage sludge, 97% water, WWT, WW from plywood production
# gravel production, crushed
# treatment of residue from mechanical treatment, IT accessory, municipal waste incineration
# barley production, Swiss integrated production, intensive
# market for photovoltaic panel, ribbon-Si
# water pump operation, electric
# electricity production, hydro, reservoir, alpine region
# anodising, aluminium sheet
# printed wiring board production, for surface mounting, Pb containing surface
# residual material landfill construction
# electricity voltage transformation from high to medium voltage
# market for printed wiring board mounting facility
# petrol, unleaded, import from RoW
# market for concrete, medium strength
# electricity voltage transformation from high to medium voltage
# electricity production, hard coal
# cable production, ribbon cable, 20-pin, with plugs
# nutrient supply from diammonium phosphate
# electricity production, lignite
# glass fibre reinforced plastic production, polyester resin, hand lay-up
# market for electricity, high voltage
# market for oxygen, liquid
# zirconium oxide production
# treatment of sewage sludge, 70% water, WWT, WW from LCD backlight production, municipal incineration FAE
# electricity production, photovoltaic, 570kWp open ground installation, multi-Si
# photovoltaic laminate production, CIS
# potassium hydroxide production
# market for melamine formaldehyde resin
# rape seed production
# electricity production, photovoltaic, 3kWp slanted-roof installation, single-Si, panel, mounted
# treatment of waste glass, open dump, hyperarid infiltration class (-250mm)
# market for inorganic nitrogen fertiliser, as N
# heat pump production, 30kW
# market for electricity, high voltage
# synthetic gas factory construction
# packaging production for pesticide, per kilogram of packed product
# sugarcane processing, traditional annexed plant
# maize grain, feed production
# electricity production, wind, 1-3MW turbine, onshore
# treatment of waste polyethylene terephthalate, unsanitary landfill, hyperarid infiltration class (-250mm)
# electricity production, wind, 1-3MW turbine, onshore
# tillage, rotary cultivator
# natural gas, high pressure, import from NO
# gypsum quarry operation
# land already in use, annual cropland to perennial crop
# market for land use change, annual crop
# phosphoric acid production, dihydrate process
# furnace production, logs, 6kW
# chlor-alkali electrolysis, mercury cell
# market for transport, passenger aircraft, medium haul
# market for sulfuric acid
# electricity voltage transformation from high to medium voltage
# tillage, harrowing, by offset disc harrow
# heavy mineral sand quarry operation and titania slag production
# photovoltaic slanted-roof installation, 3kWp, single-Si, panel, mounted, on roof
# market for irrigation
# market for acetylene
# extrusion, plastic pipes
# treatment of municipal solid waste, incineration
# market for inorganic phosphorus fertiliser, as P2O5
# heat and power co-generation, wood chips, 6667 kW
# market for polyester resin, unsaturated
# market for skidder
# market for waste paperboard
# electronics production, for control units
# market for epoxy resin insulator, SiO2
# maintenance, container ship
# treatment of municipal solid waste, incineration
# electricity production, lignite
# market for wood pellet, measured as dry mass
# pipeline construction, petroleum, offshore
# market for cadmium, semiconductor-grade
# electricity voltage transformation from medium to low voltage
# market for land use change, perennial crop
# treatment of municipal solid waste, unsanitary landfill, very wet infiltration class (1000mm)
# market for refractory spent pot liner from Al electrolysis
# petroleum and gas production, offshore
# heat and power co-generation, natural gas, mini-plant 2KW electrical
# lignite mine operation
# treatment of lignite ash, municipal incineration
# land use change, perennial crop
# maize chop to generic market for energy feed
# heat, from municipal waste incineration to generic market for heat district or industrial, other than natural gas
# petroleum and gas production, offshore
# market for rape seed
# market for electricity, high voltage
# treatment of conditioned spent nuclear fuel, in interim storage
# electricity production, hydro, run-of-river
# petroleum and gas production, onshore
# water pump operation, diesel
# limestone production, crushed, for mill
# market for recultivation, shale quarry
# market for used lorry, 40 metric ton
# market for paper, woodfree, uncoated
# market for stucco
# explosives factory construction
# oxidation of butane
# treatment of metal scrap, mixed, for recycling, unsorted, sorting
# market for waste paint on wood
# shed construction
# electricity voltage transformation from high to medium voltage
# market for metal part of electronics scrap, in copper, anode
# market for conditioned spent nuclear fuel
# market for residues, MSWI[F]-WWT, WW from PV cell production
# hexafluoroethane production, from fluorination of tetrafluoroethane
# clear-cutting, grassland to arable land, perennial crop
# treatment of waste polyvinylchloride, municipal incineration
# market for trellis system, wooden poles, soft wood, tar impregnated
# market for used purse seiner, steel
# market for printed wiring board, for power supply unit, desktop computer, Pb free
# market for tap water
# market for water, deionised
# electrorefining of copper, anode
# market for wastewater, average
# greenhouse construction, glass walls and roof, plastic tubes
# market for silicone product
# heat production, heavy fuel oil, at industrial furnace 1MW
# trichloroethylene production
# heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical
# sawnwood production, hardwood, raw, dried (u=20%)
# electricity production, natural gas, combined cycle power plant
# electricity voltage transformation from high to medium voltage
# electricity, high voltage, import from CN-NWG
# ammonia production, steam reforming, liquid
# market for maintenance, lorry 16 metric ton
# treatment of waste wood, untreated, municipal incineration with fly ash extraction
# market for nitrogen, liquid
# treatment of municipal solid waste, incineration
# market for kerosene
# treatment of waste yarn and waste textile, unsanitary landfill
# market for polyethylene terephthalate, granulate, amorphous, recycled
# electricity, high voltage, import from RAF
# market for spodumene
# electricity, high voltage, import from MD
# lath, softwood, raw, air drying to u=20%
# heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical
# market for sewage sludge, 97% water, WWT, WW from hard fibreboard production
# planing, beam, softwood, u=20%
# rape seed production
# electricity production, hydro, run-of-river
# board, softwood, raw, kiln drying to u=20%
# combine harvesting
# heat pump production, heat and power co-generation unit, 160kW electrical
# market for furnace, pellets, 9kW
# electricity voltage transformation from high to medium voltage
# maize grain production, second crop
# electricity voltage transformation from high to medium voltage
# beam, softwood, raw, air drying to u=20%
# uranium mine operation, underground
# photovoltaic slanted-roof installation, 3kWp, ribbon-Si, panel, mounted, on roof
# market for solid manure loading and spreading, by hydraulic loader and spreader
# heat and power co-generation, biogas, gas engine
# fibre cement facing tile production, large format
# treatment of waste cement, hydrated, residual material landfill
# electricity voltage transformation from medium to low voltage
# sodium nitrate production
# market for electricity, high voltage
# treatment of sewage sludge, 75% water, WWT, WW from potato starch production, sanitary landfill
# electricity production, natural gas, conventional power plant
# treatment of waste gypsum, sanitary landfill
# market for packaging, for fertilisers
# stearic acid production
# market for decommissioned pipeline, natural gas
# electricity, high voltage, import from RS
# market for titanium dioxide
# treatment of digester sludge, municipal incineration
# market for electricity, high voltage
# treatment of blast furnace gas, in power plant
# Mannheim process
# feldspar production
# suction, shavings, hardwood
# treatment of blast furnace gas, in power plant
# market for irrigation
# electricity production, lignite
# heat pump production, for mini CHP plant
# market for sweet sorghum stem
# barley grain to generic market for energy feed
# electricity production, wind, 1-3MW turbine, onshore
# market for powder coat, steel
# electricity production, photovoltaic, 3kWp facade installation, multi-Si, panel, mounted
# market for waste polyurethane
# market for waste polystyrene
# treatment of used capacitor, to hazardous waste incineration
# market for waste glass
# anhydrite production
# natural gas, burned in gas turbine
# electricity production, hydro, run-of-river
# fibreboard production, hard
# transport, freight, sea, bulk carrier for dry goods
# heat and power co-generation, lignite
# wheat grain processing, dry milling
# market for electricity, high voltage
# market for metallization paste, back side
# market for residues, MSWI-WWT, WW, average
# market for sulfur dichloride
# market for waste wood, untreated
# market for electricity, medium voltage
# treatment of waste emulsion paint, municipal incineration with fly ash extraction
# treatment of automobile catalyst
# market for heat, for reuse in municipal waste incineration only
# market for sulfidic tailings, generic
# electricity production, photovoltaic, 3kWp slanted-roof installation, single-Si, panel, mounted
# market for natural gas, high pressure
# diesel-electric generating set production, 10MW
# ...
# market for maintenance, light commercial vehicle
# market for sodium silicate, solid
# transport, freight, lorry 16-32 metric ton, EURO1
# petroleum and gas production, onshore
# heat and power co-generation unit construction, 1MW electrical, common components for heat+electricity
# market for natural gas, high pressure
# treatment of spent solvent mixture, hazardous waste incineration
# electricity production, hydro, run-of-river
# market for metal working, average for chromium steel product manufacturing
# aluminium alloy production, Metallic Matrix Composite
# market for sweet sorghum grain
# quicklime production, milled, packed
# market for electricity, medium voltage
# electricity production, hydro, reservoir, non-alpine region
# chromium steel milling, average
# market for grass seed, Swiss integrated production, for sowing
# blast furnace sludge to market for blast furnace sludge, for recovery
# methylene diphenyl diisocyanate production
# market for transport, freight, light commercial vehicle, unregulated
# market for waste polyethylene terephthalate
# wood chips production, softwood, at sawmill
# electricity production, wind, >3MW turbine, onshore
# market for boric oxide
# sputtering, indium tin oxide, for liquid crystal display
# market for transport, freight, lorry 7.5-16 metric ton, EURO2
# market for sewage sludge, 70% water, WWT, WW from liquid crystal production
# market for cement, unspecified
# electricity, high voltage, import from CA-MB
# market for anode, for metal electrolysis
# market for waste polypropylene
# market for waste bitumen sheet
# furnace production, wood chips, with silo, 5000kW
# market for dithiocarbamate-compound
# market for sugar beet seed, for sowing
# market for transport, passenger car, EURO 5
# market for precious metal from electronics scrap, in anode slime
# Brown-Schlesinger process
# planning, heat and power co-generation unit, 160kW electrical
# nylon 6-6 production
# market for municipal solid waste
# hardwood forestry, oak, sustainable forest management
# diesel, import from RoW
# market for rye seed, organic, for sowing
# treatment of tallow to esterquat
# electricity voltage transformation from high to medium voltage
# purse seiner construction, wood
# liquid storage tank production, chemicals, organics
# electricity production, wind, <1MW turbine, onshore
# paper production, woodcontaining, lightweight coated
# suction, shavings, hardwood
# water works construction, capacity 6.23E10l/year, seawater reverse osmosis, ultrafiltration pretreatment
# market for concrete, normal strength
# electricity production, oil
# market for slag landfill
# transport, freight, lorry with refrigeration machine, 7.5-16 ton, EURO4, R134a refrigerant, cooling
# electricity production, natural gas, combined cycle power plant
# market for electricity, medium voltage
# market for inorganic nitrogen fertiliser, as N
# market for chromite ore concentrate
# helium purification
# electricity production, oil
# market for inorganic phosphorus fertiliser, as P2O5
# market for waste polyethylene terephthalate, for recycling, sorted
# market for waste glass
# linseed seed production, for sowing
# electricity, high voltage, import from AT
# market for municipal solid waste
# cement production, type IS
# treatment of waste textile, soiled, municipal incineration
# electricity voltage transformation from medium to low voltage
# market for epoxy resin, liquid
# electricity, high voltage, import from SK
# market for heavy fuel oil
# electricity voltage transformation from high to medium voltage
# market for sulfidic tailings, from gold mine operation
# heat and power co-generation, biogas, gas engine
# market for spoil from hard coal mining
# electricity production, hydro, reservoir, non-alpine region
# electricity production, photovoltaic, 570kWp open ground installation, multi-Si
# treatment of sewage sludge, 70% water, WWT, WW from hard fibreboard production, municipal incineration
# bale loading
# treatment of sewage sludge, 70% water, WWT, WW from potato starch production, municipal incineration
# sugarcane processing, traditional annexed plant
# treatment of waste textile, soiled, municipal incineration
# fatty alcohol production, from palm oil
# sawing, hardwood
# treatment of sewage sludge, 70% water, WWT, WW from medium density board production, municipal incineration
# market for inorganic potassium fertiliser, as K2O
# white spirit production, petroleum refinery operation
# market for tube insulation, elastomere
# market for hay
# uranium fuel element production, enriched 3.8%, for light water reactor
# lath, hardwood, raw, air drying to u=20%
# electricity production, wind, >3MW turbine, onshore
# synthetic rubber production
# market for phosphorus trichloride
# market for residues, MSWI-WWT, WW from GGBFS production
# market for wastewater, average
# heat production, natural gas, at industrial furnace >100kW
# coconut oil production, crude
# treatment of steel in car shredder residue, municipal incineration
# market for peat
# treatment of waste paperboard, municipal incineration with fly ash extraction
# oil storage production, 3000l
# natural gas, burned in gas turbine
# sugarcane vinasse application, by wheel reel irrigation equipment
# gold refinery operation
# treatment of waste paperboard, municipal incineration
# tap water production, conventional treatment
# treatment of residue from mechanical treatment, laser printer, municipal incineration with fly ash extraction
# market for dust collector, electrostatic precipitator, for industrial use
# electricity production, hard coal
# market for electricity, low voltage
# market for waste graphical paper
# market for dinitroaniline-compound
# market for bottom ash, MSWI-WWT, WW from liquid crystal production
# treatment of waste polyvinylfluoride, municipal incineration
# electricity production, deep geothermal
# electricity voltage transformation from high to medium voltage, aluminium industry
# electricity, high voltage, import from BY
# heat and power co-generation, oil
# heat and power co-generation, wood chips, 6667 kW
# heat and power co-generation, diesel, 200kW electrical, SCR-NOx reduction
# transport, pipeline, long distance, natural gas
# hydraulic digger production
# container production, for collection of post-consumer waste plastic for recycling
# limestone production, crushed, for mill
# heat and power co-generation, biogas, gas engine
# treatment of waste reinforced concrete, collection for final disposal
# electricity production, photovoltaic, 3kWp slanted-roof installation, single-Si, panel, mounted
# treatment of coal gas, in power plant
# market for sodium sulfate, anhydrite
# concrete production, 40MPa, for civil engineering, with cement, CEM II/B
# electricity production, wind, 1-3MW turbine, onshore
# market for metaldehyde
# treatment of waste plastic, mixture, open dump, hyperarid infiltration class (-250mm)
# electricity production, wind, 1-3MW turbine, onshore
# market for waste graphical paper
# housing system construction, cattle, tied
# ozone production, liquid
# market for transport, passenger car, EURO 4
# market for power sawing, without catalytic converter
# electricity production, natural gas, conventional power plant
# electrolysis of lithium chloride
# market for transport, passenger aircraft, very short haul
# market for municipal solid waste
# packaging box factory construction
# electricity production, photovoltaic, 570kWp open ground installation, multi-Si
# treatment of sewage sludge, 70% water, WWT, WW from vegetable oil refinery, municipal incineration
# market for calcium nitrate
# containerboard production, unspecified
# aluminium, ingot, primary, import from Rest of Europe
# beam, hardwood, raw, kiln drying to u=20%
# market for electricity, medium voltage
# electricity production, deep geothermal
# treatment of waste reinforcement steel, sorting plant
# market for p-dichlorobenzene
# glued laminated timber production, average glue mix
# sheet rolling, aluminium
# market for concrete, 20MPa
# market for bottom ash, MSWI-WWT, rainwater mineral oil storage
# market for transport, passenger car, medium size, petrol, EURO 4
# concrete production, 40MPa, for civil engineering, with cement, type IP
# electricity production, wind, 1-3MW turbine, onshore
# treatment of sludge, NaCl electrolysis, residual material landfill
# electricity production, photovoltaic, 3kWp slanted-roof installation, single-Si, panel, mounted
# nutrient supply from ammonium nitrate
# market for land use change, annual crop
# treatment of bottom ash, MSWI-WWT, rainwater mineral oil storage, slag compartment
# basic oxygen furnace secondary metallurgy slag to market for basic oxygen furnace secondary metallurgy slag for recovery
# platinum group metal, extraction and refinery operations
# uranium fuel element production, enriched 4%, for light water reactor
# market for ammonium nitrate
# treatment of waste mineral wool, recycling
# market for waste wood, untreated
# market for pipeline, petroleum
# goods wagon production
# heat production, mixed logs, at wood heater 6kW, state-of-the-art 2014
# electricity production, oil
# sewer grid construction, 5E9l/year, 110 km
# electricity production, wind, 1-3MW turbine, onshore
# market for electricity, low voltage
# transport, pipeline, offshore, long distance, natural gas
# photovoltaic slanted-roof installation, 3kWp, multi-Si, panel, mounted, on roof
# waste paper sorting facility construction
# natural gas production, unprocessed, at extraction
# market for hydrogen, liquid
# market for ethylene dichloride
# paper production, woodfree, coated, at non-integrated mill
# treatment of waste reinforced concrete, recycling
# treatment of waste polyvinylchloride, unsanitary landfill, wet infiltration class (500mm)
# sugarcane processing, modern annexed plant
# cottonseed, organic to generic market for energy feed
# market for electric parts, heat and power co-generation unit, 160kW electrical
# beam, softwood, raw, kiln drying to u=10%
# market for printed wiring board, surface mounted, unspecified, Pb free
# treatment of residues, MSWI-WWT, rainwater mineral oil storage, residual material landfill
# treatment of non-Fe-Co-metals, from used Li-ion battery, hydrometallurgical processing
# photovoltaic module production, building-integrated, for facade installation
# market for magnesium, for reuse in titanium sponge production
# electricity, high voltage, import from SA
# market for bipyridylium-compound
# lath, hardwood, raw, air drying to u=20%
# market for waste graphical paper
# market for waste wood, untreated
# treatment of decommissioned pipeline, natural gas, inert material landfill
# storage production, 650 l mini CHP plant
# electricity, high voltage, import from LV
# magnesium production, electrolysis
# market for sodium chlorate, powder
# solid manure loading and spreading, by hydraulic loader and spreader
# nitric acid production, product in 50% solution state
# market for inorganic potassium fertiliser, as K2O
# wood preservative production, organic salts, Cr-free, outdoor use, ground contact
# heat and power co-generation, biogas, gas engine
# heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014
# market group for heat, central or small-scale, natural gas
# treatment of sewage sludge, 70% water, WWT, rainwater mineral oil storage, municipal incineration
# market for electricity, high voltage
# synthetic fuel production, from coal, high temperature Fisher-Tropsch operations
# shed construction, large, wood, non-insulated, fire-unprotected
# market for waste plastic, mixture
# treatment of wood ash mixture, pure, sanitary landfill
# heat and power co-generation, natural gas, conventional power plant, 100MW electrical
# market for electricity, high voltage
# electricity production, hard coal
# methyl acrylate production
# concrete production, 45MPa, for building construction, with cement, CEM II/B
# chlor-alkali electrolysis, membrane cell
# market for naphtha
# market for electricity, high voltage
# treatment of wastewater from wafer fabrication, wastewater treatment
# market for concrete block
# land already in use, perennial cropland to annual crop
# furnace production, logs, average storage area, 100kW
# debarking, softwood, in forest
# sugarcane processing, traditional annexed plant
# hard coal, run-of-mine to market for hard coal
# electricity production, lignite
# market for pitch despergents, in paper production
# electricity voltage transformation from medium to low voltage
# market for phosphorus oxychloride
# market for nitrobenzene
# market for light fuel oil
# electricity production, coal, aluminium industry
# market for concrete, 35MPa
# assembly of generator and motor, auxilliaries and energy use, for mini CHP plant
# heat production, lignite briquette, at stove 5-15kW
# batter wheat mix production
# treatment of residues, MSWI-WWT, WW from LCD backlight production, residual material landfill
# market for printed wiring board, for through-hole mounting, Pb containing surface
# market for transmission network, electricity, medium voltage
# mini CHP plant construction, common components for heat+electricity
# treatment of waste polypropylene, municipal incineration
# treatment of used desktop computer, manual dismantling
# market for inorganic phosphorus fertiliser, as P2O5
# market for pyridazine-compound
# electricity production, nuclear, boiling water reactor
# electricity production, photovoltaic, 3kWp slanted-roof installation, single-Si, panel, mounted
# electricity, high voltage, import from BA
# maize starch production
# treatment of sludge from pulp and paper production, sanitary landfill
# electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted
# electricity, high voltage, import from UZ
# electricity voltage transformation from high to medium voltage
# market for waste polyethylene terephthalate
# aluminium hydroxide production
# treatment of sewage sludge, 97% water, WWT, WW from PV cell production, landfarming
# chlor-alkali electrolysis, membrane cell
# concrete, all types to generic market for concrete, medium strength
# electricity production, lignite
# electricity production, hard coal
# market for gold
# natural gas, high pressure, import from RU
# market for sulfate pulp, bleached
# market for o-dichlorobenzene
# treatment of waste concrete, inert material landfill
# treatment of metal part of electronics scrap, in copper, anode, by electrolytic refining
# petroleum and gas production, onshore
# electricity, high voltage, import from US-TRE
# land use change, perennial crop
# fibre cement facing tile production, small format
# market for blow moulding
# maintenance, tanker, for petroleum
# electricity production, deep geothermal
# plywood production
# electricity production, hard coal
# treatment of coal slurry, impoundment
# electricity production, natural gas, conventional power plant
# market for residues, MSWI-WWT, WW, average
# liquid storage tank production, chemicals, organics
# heat and power co-generation, natural gas, 160kW electrical, lambda=1
# beam, hardwood, raw, kiln drying to u=20%
# market group for waste graphical paper
# bark chips, wet, measured as dry mass to generic market for residual hardwood, wet
# market for transport, freight, lorry 16-32 metric ton, EURO5
# maize grain production, first crop
# electricity production, wind, 1-3MW turbine, onshore
# heat and power co-generation, oil
# market for waste building wood, chrome preserved
# aluminium, ingot, primary, import from Asia (excluding China)
# benzaldehyde production
# electricity, high voltage, import from CA-AB
# ethoxylated alcohol (AE3) production, palm kernel oil
# sowing
# pipeline construction, petroleum
# white spirit production
# treatment of waste glass, sanitary landfill
# heating and sanitary equipment production, mini CHP plant
# heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical
# electricity voltage transformation from high to medium voltage
# treatment of waste wood, untreated, municipal incineration
# purse seiner construction, wood
# market for mine infrastructure, gold and silver
# MOX fuel element production, for light water reactor
# tantalum powder production, capacitor-grade
# market for electricity, low voltage
# market for petrol, unleaded
# shavings, hardwood, measured as dry mass to generic market for residual wood, dry
# treatment of waste expanded polystyrene, municipal incineration with fly ash extraction
# pyrethroid-compound production

# %% [markdown]
# ### 2.2) the `demand` attribute

# %%
lca.biosphere_matrix
# Out:
# <2420x21238 sparse matrix of type '<class 'numpy.float64'>'
# 	with 407351 stored elements in Compressed Sparse Row format>

# %% [markdown]
# To access the actual activity from the demand, you would do this:

# %% [markdown]
# There are also other attributes that have simply not been built yet, such as the `demand_array` and the `score`. To generate them, we first need to actually build the matrices. This will be done when calling the `.lci()` method.

# %% [markdown]
# ### 2.3) Reminder of the system that needs to be solved in calculating an LCI

# %% [markdown]
# Before actually running the `.lci()` method, here's a quick refresher of the actual calculation that Brightway will need to do to calculate the inventory:
#
# $g=BA^{-1}f$
#
# where:
#
#   - $A$ = the technosphere matrix
#   - $B$ = the biosphere matrix (matrix with elementary flows)
#   - $f$ = the final demand vector
#   - $g$ = the inventory

# %% [markdown]
# **Discussion:** Knowing what you do about the structure of Brightway (notably, activities and exchanges), what needs to happen to generate these matrices?

# %% [markdown]
# To consider:
#   - how should the order of the rows and columns be determined?
#   - how should we keep track of what is in each row and column?
#   - The parameters in the matrices are sometimes actually probability distribution functions - how should we consider this uncertainty information?
#   - The matrices are *sparse*, i.e. they are mostly made up of zeros. Should we consider this? Why? How?

# %% [markdown]
# ### 2.4) Building the matrices

# %% [markdown]
# #### Structured arrays

# %% [markdown]
# LCI data imported in Brightway is stored in the `databases.db` database, discussed above.
# It is also stored in [numpy *structured arrays*](https://docs.scipy.org/doc/numpy/user/basics.rec.html).

# %% [markdown]
# **Exercise**(not core): Load the structured array of the ecoinvent database you are working with now.

# %% [markdown]
# In this array:
#   - `input` and `output` columns are integers that map to an activity. This mapping is found in the `mapping.pickle` file in the `project` directory and it looks something like this:

# %% [markdown]
#   - `row` and `col`store *dummy* placeholder information about the location of the parameter in the matrices.
#   - the `type` indicates whether the exchange is a reference flow (`type`=0), technosphere exchange (`type`=1) or elementary flow (`type`=2).
#   - the other columns deal with uncertainty data. We'll cover that later, but one can always read about these columns in the [`stats_arrays` documentation](http://stats-arrays.readthedocs.io/en/latest/)

# %% [markdown]
# When the `.lci()` method is called, the structured arrayas are used to build matrices. The code responsible to do this is in the [`MatrixBuilder` class methods](https://2.docs.brightway.dev/technical/bw2calc.html#matrix-builder).
#
# The method `MatrixBuilder.build_dictionary` is used to take input and output values, respectively, and figure out which rows and columns they correspond to. The actual code is succinct - only one line - but what it does is:
#   - Get all unique values, as each value will appear multiple times
#   - Sort these values
#   - Give them integer indices, starting with zero
# This information on row and column indices is sufficient to build matrices. These matrices are build in a [COOrdinate sparse matrix](https://docs.scipy.org/doc/scipy/reference/generated/scipy.sparse.coo_matrix.html) format, where, for each exchange, three values are required: row position, column position, and amount (the actual value). The sparse matrices are actually stored in [CSR format](https://docs.scipy.org/doc/scipy/reference/generated/scipy.sparse.csr_matrix.html#scipy.sparse.csr_matrix), but this is a detail.
#
# Some more details are are found [here](https://2.docs.brightway.dev/technical/bw2calc.html#matrix-builders).

# %% [markdown]
# Let's now finally run the `.lci()`.

# %% [markdown]
# Here's what the structured arrays *now* look like:

# %% [markdown]
# We see that the row and col numbers are no longer dummy variables, but that they actually have real matrix indices.

# %% [markdown]
# #### Dictionaries that map between incides and activities

# %% [markdown]
# One of the useful things that the `MatrixBuilder` produces are `dictionaries` that map row and column numbers to the keys of activities.  There are three such dictionaries, all directly accessible as attributes of the LCA object:
#  - `activity_dict`: Columns in the technosphere matrix $A$ or biosphere matrix $B$
#  - `product_dict` : Rows in the technosphere matrix $A$
#  - `biosphere_dict`: Rows in the biosphere matrix $B$

# %%
list(lca.demand.keys())[0].key
# Out:
# ('ecoinvent 3.9.1 cutoff', 'f30c46c44c2292cee46f9af3c1b8aca5')

# %%
lca.activity_dict[('ecoinvent 3.9.1 cutoff', 'f30c46c44c2292cee46f9af3c1b8aca5')]
# Out:
# 18990

# %% [markdown]
# Here what this dictionary looks like:

# %%
actitivty_dict, product_dict, biosphere_dict = lca.

# %% [markdown]
# So, if I know the key to my activity (which, again,  is a `tuple` consisting of the database name and the activity code), I can read the column index (from `activity_dict`) or row index (from `product_dict` or `biosphere_dict` for the $A$ or $B$ matrices, respectively).
#
# Let's find out what column is associated with the activity that is producing our final demand as reference flow.

# %% [markdown]
# While this is useful, it is often more useful to determine what a row or column in the matrices actually refers to. In these cases, we need a dictionary that maps row or column indices to activity keys, and not the opposite.
# We can do this by reversing our dictionaries:

# %% [markdown]
# As a convenience, Brightway offers a method that will generate the three reverse dictionaries simultaneously.
# `.reverse_dict()` returns three reverse dicts (reverse activity dict,  reverse product dict,  reverse biosphere dict) *in that order*. The syntax for creating and assigning these reverse dicts is therefore:

# %% [markdown]
# #### $A$ and $B$ Matrices

# %% [markdown]
# We can also access the matrices that were constructed. Let's look at the technosphere matrix ($A$).
# The ** $A$ matrix**, with each element $a_{ij}$ provides information on the amount of input or output of product $i$ from activity $j$. When $i=j$, the element $a_{ij}$ is the *reference flow* for the activity described in the column.

# %% [markdown]
# I am told that the dimensions of the matrix is $n*n$ where $n$ is the number of activities in my product system, and that the amount of actually stored elements is much less than $n^2$ (because the matrix is *sparse* and zero values are not stored).

# %% [markdown]
# We can have an idea of what it stores by printing it out:

# %% [markdown]
# It therefore stores both the coordinates and the values (as expected).
# We can slice this matrix using coordinates. For example, let's say we wanted a view of the exchanges associated with the unit process providing our functional unit.
# We already know found the column number for that activity:

# %% [markdown]
# To return the whole column from the $A$ matrix, we therefore slice the $A$ matrix.
# Python notes:
#   - In Python, slicing is done using []
#   - We specify rows first, then columns
#   - `:` refers to "the whole row" or "the whole column" (depending if it is passed first or second in the [])

# %% [markdown]
# Printing this out gives:

# %% [markdown]
# Not too useful: it would be better to get the *names* to these exchanges.
# We need to do two things:
#   - Get the indices from the CSR matrix (we can do this by converting it to a sparse matrix in `COOrdinate` format first)
#   - Get the activity code for the each index (we can do this using the reverse of the `activity_dict`)
#   - Use `get_activity` to access the actual names of the activities.

# %% [markdown]
# 1) Converting the CSR matrix to a COO matrix:

# %% [markdown]
# It is still a sparse matrix with the same number of elements, and it looks quite like the CSR version when we print it out:

# %% [markdown]
# However, we can directly access the rows and column indices using `row` and `col`:

# %% [markdown]
# 2) Get the activity code for each element using the **reverse** product dictionary we produced above:

# %% [markdown]
# It would be even nicer to get the names for these:

# %% [markdown]
# We can put these in a neat Pandas Series, with actual names and amounts:

# %% [markdown]
# Alternative way to generate similar information without even looking at the matrices:

# %% [markdown]
# Note the differences:
#   - The reference flow is not there (activity.technosphere() only returns technoshere exchanges where the input is not equal to the output)
#   - The values are positive, not negative (because the $A$ matrix is $I-Z$ where $Z$ contains the information on these inputs.

# %% [markdown]
# **Exercise**: Create a Pandas Series with the elementary flows of the activity supplying the reference flow for myFirstLCA.

# %% [markdown]
# #### Demand array $f$

# %% [markdown]
# The demand array is the $f$ in $As=f$.
# It is an attribute of the LCA object:

# %% [markdown]
# Looks like it is all zeros, but not so:

# %% [markdown]
# So where is the one? We can know this by using our `activity_dict`.

# %% [markdown]
# ### 2.5) Solution to the inventory calculation

# %% [markdown]
# We saw above how `.lci()` produced the $A$ and $B$ matrices.
# `.lci()` also *solves* the equation $As=f$ and calculated the inventory by multiplying the solution to this equation by the biosphere matrix.

# %% [markdown]
# #### Supply array

# %% [markdown]
# Vector containing the amount each activity will need to provide to meet the functional demand, i.e. $s=A^{-1}f$.

# %% [markdown]
# **Inventory matrix**
# Contains the inventory *by activity* (i.e. not summed). In other words, we do not have $g=BA^{-1}f$, but rather $G=B \cdot diag(A^{-1}f)$

# %% [markdown]
# We can aggregate the LCI results along the columns (i.e. calculate the cradle-to-gate inventory):

# %% [markdown]
# **Exercise:** Get the total (cradle-to-gate) emissions of nitrous oxide emitted to air in the "urban air" subcompartment.

# %% [markdown]
# ### 2.7) LCIA

# %% [markdown]
# The LCIA calculation is done via the `.lcia()` method.

# %% [markdown]
# A number of other matrices are now available:

# %% [markdown]
# Question: would there be more, less or just as many elements in the inventory matrix as there are in the characterized inventory matrix?

# %% [markdown]
# The overall score is now an attribute of the LCA object:

# %% [markdown]
# We also could have determined what this score was by summing the elements of our `characterized_inventory` matrix:

# %% [markdown]
# We could also have calculated it by multiplying the inventory and characterization factors ourselves:

# %% [markdown]
# We could also calculate the score by elementary flow (summing columns for each rows), irrespective of the unit process that produced it:

# %% [markdown]
# Notice that is has **two** dimensions. The result is in fact a one-dimensional matrix:

# %% [markdown]
# To convert it to an array (probably more useful for many purposes), you can use any of the following approaches:

# %% [markdown]
# **Exercise:** Create a Pandas series that has the scores per unit process, sorted by value (contribution analysis)

# %% [markdown]
# ## 3) My second LCA: Comparative LCA

# %% [markdown]
# Let's choose two activities to compare, say Swiss electricity produced from respectively a run-of-river hydropower plant and a wind turbine.

# %% [markdown]
# **Exercise**: assign the two activities to variables `hydro` and `wind` respectively.

# %% [markdown]
# Let's also compare these according to their carbon footprint as measured with the IPCC method we already selected above:

# %% [markdown]
# #### One at a time approach:

# %% [markdown]
# **Exercise:** Do the LCA for `wind`:

# %% [markdown]
# Do one "delta" LCA:

# %% [markdown]
# ## 4) My third LCA - Multiple impact categories

# %% [markdown]
# Say we want to evaluate the indicator results for our randomAct for all EF v3 categories (with long-term emissions).

# %% [markdown]
# Simplest way: for loop, using `switch method`

# %% [markdown]
# ## Revising my second and third LCA with `MultiLCA`

# %% [markdown]
# The `MultiLCA` allows the calculation of LCA results for multiple functional units and impact categories.
# One simply needs to create a `calculation setup`, i.e. a named set of functional units and LCIA methods.

# %% [markdown]
# Calculation setups: dictionary with lists of functional units and methods.

# %% [markdown]
# You can also create "fuller" DataFrames. Here is with code from [here](http://stackoverflow.com/questions/42984831/create-a-dataframe-from-multilca-results-in-brightway2):

# %% [markdown]
# ## Uncertainty

# %% [markdown]
# Values of exchanges in datasets may come with uncertainty.
# See [documentation](https://stats-arrays.readthedocs.io/en/latest/) of `stats_array`.
#
# Let's find out how uncertainty is defined in ecoinvent:

# %% [markdown]
# ### Running a stochastic analysis (Monte Carlo)

# %% [markdown]
# Let's visualize the results:

# %% [markdown]
# ## Let's now look at the import and export of data
#
# Open the second notebook.
